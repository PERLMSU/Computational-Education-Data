# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import seaborn as sns

# %%
#importing the data in two different formats
data_excel=pd.ExcelFile('Computational Data Without Identifiers.xlsx')
data_csv=pd.read_csv('Computational Data Without Identifiers.csv')
data=pd.read_excel('PERL Research Data.xlsx')

# %% [markdown]
# # Question 3 b in relation to question 2

# %%
# if question 2 a was answered who said yes and no for question 3 b

Deg_Comp_Phy_YN = []
for row in data.values[:,2]:
    Deg_Comp_Phy_YN.append(row)
How_Taught_Advanced_Course = []
for row in data.values[:,11]:
    How_Taught_Advanced_Course.append(row)

# %%
Deg_Comp_Phy_Y = Deg_Comp_Phy_YN.count("Checked") #The number of respondents who said their institution offers a degree in Computiational Physics
Deg_Comp_Phy_Y
Adv_Yes= How_Taught_Advanced_Course.count("Checked")
Adv_No= How_Taught_Advanced_Course.count("Unchecked")

yes=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Deg_Comp_Phy_N = Deg_Comp_Phy_YN.count("Unchecked") 
Deg_Comp_Phy_N
yes1=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Deg_Comp_Phy_Y_Adv_Y = yes/(yes+no)
Percent_Deg_Comp_Phy_N_Adv_Y = yes1/(yes1+no1)
Percent_Deg_Comp_Phy_Y_Adv_N = no/(yes+no)
Percent_Deg_Comp_Phy_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Deg_Comp_Phy_Y_Adv_Y,Percent_Deg_Comp_Phy_Y_Adv_N]
y1=[Percent_Deg_Comp_Phy_N_Adv_Y,Percent_Deg_Comp_Phy_N_Adv_N]
# Out:
# 75
# 460
# 5
# 148

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Degree Offered')
ax2.set_title('Degree Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a653f56531da> in <module>()
#       1 # Table of survival vs passenger class
# ----> 2 survived_class = pd.crosstab(index=titanic_train["Survived"],
#       3                             columns='ban',
#       4                              margins=True)   # Include row and column totals
#       5
#
# NameError: name 'titanic_train' is not defined

# %%
test=[{Adv_Yes, Deg_Comp_Phy_Y},
     {Adv_No, Deg_Comp_Phy_N}]
df= pd.DataFrame(test)
print(Adv_Yes, Adv_No, Deg_Comp_Phy_Y,Deg_Comp_Phy_N)
df

s=pd.Series([Deg_Comp_Phy_Y,Deg_Comp_Phy_N],[Adv_Yes,Adv_No])
s
# Out:
# 536 154 82 636
#           class1  aww  rowtotal
# died           0    1         1
# survived       1    0         1
# coltotal       1    1         2

# %%
# if question 2 a was answered who said yes and no for question 3 b

Minor_Comp_Phy_YN = []
for row in data.values[:,3]:
    Minor_Comp_Phy_YN.append(row)

# %%
Minor_Comp_Phy_Y = Minor_Comp_Phy_YN.count("Checked")  
Minor_Comp_Phy_Y
yes=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Minor_Comp_Phy_N = Minor_Comp_Phy_YN.count("Unchecked")  
Minor_Comp_Phy_N
yes1=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
Minor_Comp_Phy_N
no=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Minor_Comp_Phy_Y_Adv_Y = yes/(yes+no)
Percent_Minor_Comp_Phy_N_Adv_Y = yes1/(yes1+no1)
Percent_Minor_Comp_Phy_Y_Adv_N = no/(yes+no)
Percent_Minor_Comp_Phy_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Minor_Comp_Phy_Y_Adv_Y,Percent_Minor_Comp_Phy_Y_Adv_N]
y1=[Percent_Minor_Comp_Phy_N_Adv_Y,Percent_Minor_Comp_Phy_N_Adv_N]
# Out:
# 26
# 509
# 1
# 152

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Minor Offered')
ax2.set_title('Minor Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Cert_Comp_Phy_YN = []
for row in data.values[:,4]:
    Cert_Comp_Phy_YN.append(row)

# %%
Cert_Comp_Phy_Y = Cert_Comp_Phy_YN.count("Checked")  
Cert_Comp_Phy_Y
yes=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Cert_Comp_Phy_N = Cert_Comp_Phy_YN.count("Checked")  
Cert_Comp_Phy_N
yes1=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Cert_Comp_Phy_Y_Adv_Y = yes/(yes+no)
Percent_Cert_Comp_Phy_N_Adv_Y = yes1/(yes1+no1)
Percent_Cert_Comp_Phy_Y_Adv_N = no/(yes+no)
Percent_Cert_Comp_Phy_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Cert_Comp_Phy_Y_Adv_Y,Percent_Cert_Comp_Phy_Y_Adv_N]
y1=[Percent_Cert_Comp_Phy_N_Adv_Y,Percent_Cert_Comp_Phy_N_Adv_N]
# Out:
# 13
# 522
# 2
# 151

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Certificate Offered')
ax2.set_title('Certificate Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Other_Comp_Phy_YN = []
for row in data.values[:,5]:
    Other_Comp_Phy_YN.append(row)

# %%
Other_Comp_Phy_Y = Other_Comp_Phy_YN.count("Checked")  
Other_Comp_Phy_Y
yes=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Other_Comp_Phy_N = Other_Comp_Phy_YN.count("Unchecked")  
Other_Comp_Phy_N
yes1=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Other_Comp_Phy_Y_Adv_Y = yes/(yes+no)
Percent_Other_Comp_Phy_N_Adv_Y = yes1/(yes1+no1)
Percent_Other_Comp_Phy_Y_Adv_N = no/(yes+no)
Percent_Other_Comp_Phy_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Other_Comp_Phy_Y_Adv_Y,Percent_Other_Comp_Phy_Y_Adv_N]
y1=[Percent_Other_Comp_Phy_N_Adv_Y,Percent_Other_Comp_Phy_N_Adv_N]
# Out:
# 61
# 474
# 17
# 136

# %%
 fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other Thing Offered')
ax2.set_title('Other Thing Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
None_Above_Prog = []
for row in data.values[:,6]:
    None_Above_Prog.append(row)

# %%
None_Above_Prog_Y = None_Above_Prog.count("Checked")  
None_Above_Prog_Y
yes=0
for i,j in zip(None_Above_Prog, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
None_Above_Prog_N = None_Above_Prog.count("Unchecked")  
None_Above_Prog_N
yes1=0
for i,j in zip(None_Above_Prog, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(None_Above_Prog, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(None_Above_Prog, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_None_Above_Prog_Comp_Phy_Y_Adv_Y = yes/(yes+no)
Percent_None_Above_Prog_Comp_Phy_N_Adv_Y = yes1/(yes1+no1)
Percent_None_Above_Prog_Comp_Phy_Y_Adv_N = no/(yes+no)
Percent_None_Above_Prog_Comp_Phy_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_None_Above_Prog_Comp_Phy_Y_Adv_Y,Percent_None_Above_Prog_Comp_Phy_Y_Adv_N]
y1=[Percent_None_Above_Prog_Comp_Phy_N_Adv_Y,Percent_None_Above_Prog_Comp_Phy_N_Adv_N]
# Out:
# 379
# 156
# 128
# 25

# %%
 fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Something Offered')
ax2.set_title('Nothing Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # Question 3 c in relation to question 2

# %%
#This is for column O
How_Taught_Research_Experience = []
for row in data.values[:,14]:
    How_Taught_Research_Experience.append(row)

# %%
Deg_Comp_Phy_YN
yes=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Deg_Comp_Phy_YN
yes1=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Deg_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Deg_Comp_Phy_Y_Research_Y = yes/(yes+no)
Percent_Deg_Comp_Phy_N_Research_Y = yes1/(yes1+no1)
Percent_Deg_Comp_Phy_Y_Research_N = no/(yes+no)
Percent_Deg_Comp_Phy_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Deg_Comp_Phy_Y_Research_Y,Percent_Deg_Comp_Phy_Y_Research_N]
y1=[Percent_Deg_Comp_Phy_N_Research_Y,Percent_Deg_Comp_Phy_N_Research_N]
# Out:
# 71
# 484
# 9
# 124

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Degree Offered')
ax2.set_title('Degree Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Minor_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Minor_Comp_Phy_Y_Research_Y = yes/(yes+no)
Percent_Minor_Comp_Phy_N_Research_Y = yes1/(yes1+no1)
Percent_Minor_Comp_Phy_Y_Research_N = no/(yes+no)
Percent_Minor_Comp_Phy_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Minor_Comp_Phy_Y_Research_Y,Percent_Minor_Comp_Phy_Y_Research_N]
y1=[Percent_Minor_Comp_Phy_N_Research_Y,Percent_Minor_Comp_Phy_N_Research_N]
# Out:
# 24
# 531
# 3
# 130

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Minor Offered')
ax2.set_title('Minor Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Cert_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Cert_Comp_Phy_Y_Research_Y = yes/(yes+no)
Percent_Cert_Comp_Phy_N_Research_Y = yes1/(yes1+no1)
Percent_Cert_Comp_Phy_Y_Research_N = no/(yes+no)
Percent_Cert_Comp_Phy_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Cert_Comp_Phy_Y_Research_Y,Percent_Cert_Comp_Phy_Y_Research_N]
y1=[Percent_Cert_Comp_Phy_N_Research_Y,Percent_Cert_Comp_Phy_N_Research_N]
# Out:
# 14
# 541
# 1
# 132

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Certificate Offered')
ax2.set_title('Certificate Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Other_Comp_Phy_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Other_Comp_Phy_Y_Research_Y = yes/(yes+no)
Percent_Other_Comp_Phy_N_Research_Y = yes1/(yes1+no1)
Percent_Other_Comp_Phy_Y_Research_N = no/(yes+no)
Percent_Other_Comp_Phy_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Other_Comp_Phy_Y_Research_Y,Percent_Other_Comp_Phy_Y_Research_N]
y1=[Percent_Other_Comp_Phy_N_Research_Y,Percent_Other_Comp_Phy_N_Research_N]
# Out:
# 65
# 490
# 13
# 120

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other Thing Offered')
ax2.set_title('Other Thing Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(None_Above_Prog, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(None_Above_Prog, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(None_Above_Prog, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(None_Above_Prog, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_None_Above_Prog_Comp_Phy_Y_Research_Y = yes/(yes+no)
Percent_None_Above_Prog_Comp_Phy_N_Research_Y = yes1/(yes1+no1)
Percent_None_Above_Prog_Comp_Phy_Y_Research_N = no/(yes+no)
Percent_None_Above_Prog_Comp_Phy_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_None_Above_Prog_Comp_Phy_Y_Research_Y,Percent_None_Above_Prog_Comp_Phy_Y_Research_N]
y1=[Percent_None_Above_Prog_Comp_Phy_N_Research_Y,Percent_None_Above_Prog_Comp_Phy_N_Research_N]
# Out:
# 397
# 158
# 110
# 23

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Something Offered')
ax2.set_title(' Nothing Offered')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # Question 3 b in relation to question 4

# %%
Comp_Use_Envir_YN = []
for row in data.values[:,20]:
    Comp_Use_Envir_YN.append(row)
Comp_Use_Envir_Y = Comp_Use_Envir_YN.count("Checked")
yes=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Comp_Use_Envir_N = Comp_Use_Envir_YN.count("Unchecked")
yes1=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Envir_Y_Adv_Y = yes/(yes+no)
Percent_Comp_Use_Envir_N_Adv_Y = yes1/(yes1+no1)
Percent_Comp_Use_Envir_Y_Adv_N = no/(yes+no)
Percent_Comp_Use_Envir_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Envir_Y_Adv_Y,Percent_Comp_Use_Envir_Y_Adv_N]
y1=[Percent_Comp_Use_Envir_N_Adv_Y,Percent_Comp_Use_Envir_N_Adv_N]
# Out:
# 346
# 185
# 75
# 71

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Computing Environments (Intro Phys)')
ax2.set_title('Computing Environments')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Comp_Use_Scripting_YN = []
for row in data.values[:,21]:
    Comp_Use_Scripting_YN.append(row)
Comp_Use_Scripting_Y = Comp_Use_Scripting_YN.count("Checked")
yes=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
Comp_Use_Scripting_N = Comp_Use_Scripting_YN.count("Unchecked")
yes1=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Scripting_Y_Adv_Y = yes/(yes+no)
Percent_Comp_Use_Scripting_N_Adv_Y = yes1/(yes1+no1)
Percent_Comp_Use_Scripting_Y_Adv_N = no/(yes+no)
Percent_Comp_Use_Scripting_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Scripting_Y_Adv_Y,Percent_Comp_Use_Scripting_Y_Adv_N]
y1=[Percent_Comp_Use_Scripting_N_Adv_Y,Percent_Comp_Use_Scripting_N_Adv_N]
# Out:
# 250
# 281
# 42
# 104

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Scripting Languages (Intro Phys)')
ax2.set_title('Scripting Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Comp_Use_Compiled_YN = []
for row in data.values[:,22]:
    Comp_Use_Compiled_YN.append(row)
Comp_Use_Compiled_Y = Comp_Use_Compiled_YN.count("Checked")
yes=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Compiled_Y_Adv_Y = yes/(yes+no)
Percent_Comp_Use_Compiled_N_Adv_Y = yes1/(yes1+no1)
Percent_Comp_Use_Compiled_Y_Adv_N = no/(yes+no)
Percent_Comp_Use_Compiled_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Compiled_Y_Adv_Y,Percent_Comp_Use_Compiled_Y_Adv_N]
y1=[Percent_Comp_Use_Compiled_N_Adv_Y,Percent_Comp_Use_Compiled_N_Adv_N]
# Out:
# 152
# 379
# 33
# 113

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Compiled Languages (Intro Phys)')
ax2.set_title('Compiled Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Comp_Use_Excel_YN = []
for row in data.values[:,23]:
    Comp_Use_Excel_YN.append(row)
Comp_Use_Excel_Y = Comp_Use_Excel_YN.count("Checked") 
yes=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Excel_Y_Adv_Y = yes/(yes+no)
Percent_Comp_Use_Excel_N_Adv_Y = yes1/(yes1+no1)
Percent_Comp_Use_Excel_Y_Adv_N = no/(yes+no)
Percent_Comp_Use_Excel_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Excel_Y_Adv_Y,Percent_Comp_Use_Excel_Y_Adv_N]
y1=[Percent_Comp_Use_Excel_N_Adv_Y,Percent_Comp_Use_Excel_N_Adv_N]
# Out:
# 328
# 203
# 95
# 51

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Excel/Spreadsheets (Intro Phys)')
ax2.set_title('Excel/Spreadsheets')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Comp_Use_Other_YN = []
for row in data.values[:,24]:
    Comp_Use_Other_YN.append(row)
Comp_Use_Other_Y = Comp_Use_Other_YN.count("Checked")
yes=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Other_Y_Adv_Y = yes/(yes+no)
Percent_Comp_Use_Other_N_Adv_Y = yes1/(yes1+no1)
Percent_Comp_Use_Other_Y_Adv_N = no/(yes+no)
Percent_Comp_Use_Other_N_Adv_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Other_Y_Adv_Y,Percent_Comp_Use_Other_Y_Adv_N]
y1=[Percent_Comp_Use_Other_N_Adv_Y,Percent_Comp_Use_Other_N_Adv_N]
# Out:
# 48
# 483
# 29
# 117

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other (Intro Phys)')
ax2.set_title('Other')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # Question 3 c in relation to question 4

# %%
yes=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Envir_Y_Research_Y = yes/(yes+no)
Percent_Comp_Use_Envir_N_Research_Y = yes1/(yes1+no1)
Percent_Comp_Use_Envir_Y_Research_N = no/(yes+no)
Percent_Comp_Use_Envir_N_Research_N = no1/(yes1+no1)
x=[1,2]
y=[Percent_Comp_Use_Envir_Y_Research_Y,Percent_Comp_Use_Envir_Y_Research_N]
y1=[Percent_Comp_Use_Envir_N_Research_Y,Percent_Comp_Use_Envir_N_Research_N]
# Out:
# 365
# 184
# 56
# 72

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Computing Environments (Intro Phys)')
ax2.set_title('Computing Environments')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Comp_Use_Scripting_YN , How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Scripting_YN , How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Scripting_Y_Research_Y = yes/(yes+no) 
Percent_Comp_Use_Scripting_N_Research_Y = yes1/(yes1+no1) 
Percent_Comp_Use_Scripting_Y_Research_N = no/(yes+no) 
Percent_Comp_Use_Scripting_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Comp_Use_Scripting_Y_Research_Y,Percent_Comp_Use_Scripting_Y_Research_N] 
y1=[Percent_Comp_Use_Scripting_N_Research_Y,Percent_Comp_Use_Scripting_N_Research_N]
# Out:
# 250
# 299
# 42
# 86

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Scripting Languages (Intro Phys)')
ax2.set_title('Scripting Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Comp_Use_Compiled_YN , How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Compiled_YN , How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Compiled_Y_Research_Y = yes/(yes+no) 
Percent_Comp_Use_Compiled_N_Research_Y = yes1/(yes1+no1) 
Percent_Comp_Use_Compiled_Y_Research_N = no/(yes+no) 
Percent_Comp_Use_Compiled_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Comp_Use_Compiled_Y_Research_Y,Percent_Comp_Use_Compiled_Y_Research_N] 
y1=[Percent_Comp_Use_Compiled_N_Research_Y,Percent_Comp_Use_Compiled_N_Research_N]
# Out:
# 158
# 391
# 27
# 101

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Compiled Languages (Intro Phys)')
ax2.set_title('Compiled Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Comp_Use_Excel_YN , How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Excel_YN , How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Excel_Y_Research_Y = yes/(yes+no) 
Percent_Comp_Use_Excel_N_Research_Y = yes1/(yes1+no1) 
Percent_Comp_Use_Excel_Y_Research_N = no/(yes+no) 
Percent_Comp_Use_Excel_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Comp_Use_Excel_Y_Research_Y,Percent_Comp_Use_Excel_Y_Research_N] 
y1=[Percent_Comp_Use_Excel_N_Research_Y,Percent_Comp_Use_Excel_N_Research_N]
# Out:
# 346
# 203
# 77
# 51

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Excel/Spreadsheets (Intro Phys)')
ax2.set_title('Excel/Spreadsheets')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Comp_Use_Other_YN , How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Comp_Use_Other_YN , How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Comp_Use_Other_Y_Research_Y = yes/(yes+no) 
Percent_Comp_Use_Other_N_Research_Y = yes1/(yes1+no1) 
Percent_Comp_Use_Other_Y_Research_N = no/(yes+no) 
Percent_Comp_Use_Other_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Comp_Use_Other_Y_Research_Y,Percent_Comp_Use_Other_Y_Research_N] 
y1=[Percent_Comp_Use_Other_N_Research_Y,Percent_Comp_Use_Other_N_Research_N]
# Out:
# 54
# 495
# 23
# 105

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other (Intro Phys)')
ax2.set_title('Other')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # Question 3 b in relation to question 5

# %%
Adv_Course_Comp_Use_Envir_YN = []
for row in data.values[:,26]:
    Adv_Course_Comp_Use_Envir_YN.append(row)
yes=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Envir_Y_Adv_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Envir_N_Adv_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Envir_Y_Adv_N = no/(yes+no) 
Percent_Adv_Comp_Use_Envir_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Envir_Y_Adv_Y,Percent_Adv_Comp_Use_Envir_Y_Adv_N] 
y1=[Percent_Adv_Comp_Use_Envir_N_Adv_Y,Percent_Adv_Comp_Use_Envir_N_Adv_N]
# Out:
# 439
# 88
# 52
# 90

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Computing Environments(Adv Phys)')
ax2.set_title('Computing Environments')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Adv_Course_Comp_Use_Scripting_YN = []
for row in data.values[:,27]:
    Adv_Course_Comp_Use_Scripting_YN.append(row)
yes=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Scripting_Y_Adv_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Scripting_N_Adv_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Scripting_Y_Adv_N = no/(yes+no) 
Percent_Adv_Comp_Use_Scripting_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Scripting_Y_Adv_Y,Percent_Adv_Comp_Use_Scripting_Y_Adv_N] 
y1=[Percent_Adv_Comp_Use_Scripting_N_Adv_Y,Percent_Adv_Comp_Use_Scripting_N_Adv_N]
# Out:
# 303
# 224
# 26
# 116

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Scripting Languages(Adv Phys)')
ax2.set_title('Scripting Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Adv_Course_Comp_Use_Compiled_YN = []
for row in data.values[:,28]:
    Adv_Course_Comp_Use_Compiled_YN.append(row)
yes=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Compiled_Y_Adv_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Compiled_N_Adv_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Compiled_Y_Adv_N = no/(yes+no) 
Percent_Adv_Comp_Use_Compiled_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Compiled_Y_Adv_Y,Percent_Adv_Comp_Use_Compiled_Y_Adv_N] 
y1=[Percent_Adv_Comp_Use_Compiled_N_Adv_Y,Percent_Adv_Comp_Use_Compiled_N_Adv_N]
# Out:
# 255
# 272
# 28
# 114

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Compiled Languages(Adv Phys)')
ax2.set_title('Compiled Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Adv_Course_Comp_Use_Excel_YN = []
for row in data.values[:,29]:
    Adv_Course_Comp_Use_Excel_YN.append(row)
yes=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Excel_Y_Adv_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Excel_N_Adv_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Excel_Y_Adv_N = no/(yes+no) 
Percent_Adv_Comp_Use_Excel_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Excel_Y_Adv_Y,Percent_Adv_Comp_Use_Excel_Y_Adv_N] 
y1=[Percent_Adv_Comp_Use_Excel_N_Adv_Y,Percent_Adv_Comp_Use_Excel_N_Adv_N]
# Out:
# 254
# 273
# 35
# 107

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Excel/Spreadsheet(Adv Phys)')
ax2.set_title('Excel/Spreadsheet')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %%
Adv_Course_Comp_Use_Other_YN = []
for row in data.values[:,30]:
    Adv_Course_Comp_Use_Other_YN.append(row)
yes=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Advanced_Course):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Other_Y_Adv_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Other_N_Adv_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Other_Y_Adv_N = no/(yes+no) 
Percent_Adv_Comp_Use_Other_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Other_Y_Adv_Y,Percent_Adv_Comp_Use_Other_Y_Adv_N] 
y1=[Percent_Adv_Comp_Use_Other_N_Adv_Y,Percent_Adv_Comp_Use_Other_N_Adv_N]
# Out:
# 52
# 475
# 8
# 134

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other(Adv Phys)')
ax2.set_title('Other')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.show()

# %% [markdown]
# # Question 3 c in relation to Question 5

# %%
yes=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Envir_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Envir_Y_Research_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Envir_N_Research_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Envir_Y_Research_N = no/(yes+no) 
Percent_Adv_Comp_Use_Envir_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Envir_Y_Research_Y,Percent_Adv_Comp_Use_Envir_Y_Research_N] 
y1=[Percent_Adv_Comp_Use_Envir_N_Research_Y,Percent_Adv_Comp_Use_Envir_N_Research_N]
# Out:
# 439
# 104
# 52
# 74

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Computing Environments(Adv Phys)')
ax2.set_title('Computing Environments')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Scripting_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Scripting_Y_Research_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Scripting_N_Research_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Scripting_Y_Research_N = no/(yes+no) 
Percent_Adv_Comp_Use_Scripting_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Scripting_Y_Research_Y,Percent_Adv_Comp_Use_Scripting_Y_Research_N] 
y1=[Percent_Adv_Comp_Use_Scripting_N_Research_Y,Percent_Adv_Comp_Use_Scripting_N_Research_N]
# Out:
# 297
# 246
# 32
# 94

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Scripting Languages(Adv Phys)')
ax2.set_title('Scripting Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.show()

# %%
yes=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Compiled_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Compiled_Y_Research_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Compiled_N_Research_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Compiled_Y_Research_N = no/(yes+no) 
Percent_Adv_Comp_Use_Compiled_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Compiled_Y_Research_Y,Percent_Adv_Comp_Use_Compiled_Y_Research_N] 
y1=[Percent_Adv_Comp_Use_Compiled_N_Research_Y,Percent_Adv_Comp_Use_Compiled_N_Research_N]
# Out:
# 258
# 285
# 25
# 101

# %%
 fig = plt.figure(figsize=(6,4))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Compiled Languages(Adv Phys)')
ax2.set_title('Compiled Languages')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Excel_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Excel_Y_Research_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Excel_N_Research_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Excel_Y_Research_N = no/(yes+no) 
Percent_Adv_Comp_Use_Excel_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Excel_Y_Research_Y,Percent_Adv_Comp_Use_Excel_Y_Research_N] 
y1=[Percent_Adv_Comp_Use_Excel_N_Research_Y,Percent_Adv_Comp_Use_Excel_N_Research_N]
# Out:
# 260
# 283
# 29
# 97

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Excel/Spreadsheets(Adv Phys)')
ax2.set_title('Excel/Spreadsheets')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Checked" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Adv_Course_Comp_Use_Other_YN, How_Taught_Research_Experience):
    if i == "Unchecked" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Adv_Comp_Use_Other_Y_Research_Y = yes/(yes+no) 
Percent_Adv_Comp_Use_Other_N_Research_Y = yes1/(yes1+no1) 
Percent_Adv_Comp_Use_Other_Y_Research_N = no/(yes+no) 
Percent_Adv_Comp_Use_Other_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Adv_Comp_Use_Other_Y_Research_Y,Percent_Adv_Comp_Use_Other_Y_Research_N] 
y1=[Percent_Adv_Comp_Use_Other_N_Research_Y,Percent_Adv_Comp_Use_Other_N_Research_N]
# Out:
# 53
# 490
# 7
# 119

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other(Adv Phys)')
ax2.set_title('Other')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 b in relation to 6

# %%
Hw_About_Computation = []
for row in data.values[:,32]:
    Hw_About_Computation.append(row)
yes=0
for i,j in zip(Hw_About_Computation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Hw_About_Computation, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Hw_About_Computation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Hw_About_Computation, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Hw_About_Computation_Y_Adv_Y = yes/(yes+no) 
Percent_Hw_About_Computation_N_Adv_Y = yes1/(yes1+no1) 
Percent_Hw_About_Computation_Y_Adv_N = no/(yes+no) 
Percent_Hw_About_Computation_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Hw_About_Computation_Y_Adv_Y,Percent_Hw_About_Computation_Y_Adv_N] 
y1=[Percent_Hw_About_Computation_N_Adv_Y,Percent_Hw_About_Computation_N_Adv_N]
# Out:
# 290
# 202
# 63
# 64

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Hw Questions')
ax2.set_title('Yes Hw Questions')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Interactive_Activities = []
for row in data.values[:,33]:
    Interactive_Activities.append(row)
yes=0
for i,j in zip(Interactive_Activities, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Interactive_Activities, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Interactive_Activities, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Interactive_Activities, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Interactive_Activities_Y_Adv_Y = yes/(yes+no) 
Percent_Interactive_Activities_N_Adv_Y = yes1/(yes1+no1) 
Percent_Interactive_Activities_Y_Adv_N = no/(yes+no) 
Percent_Interactive_Activities_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Interactive_Activities_Y_Adv_Y,Percent_Interactive_Activities_Y_Adv_N] 
y1=[Percent_Interactive_Activities_N_Adv_Y,Percent_Interactive_Activities_N_Adv_N]
# Out:
# 95
# 377
# 37
# 87

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Interactive Activities')
ax2.set_title('Yes Interactive Activities')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Exam_Questions = []
for row in data.values[:,34]:
    Exam_Questions.append(row)
yes=0
for i,j in zip(Exam_Questions, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Exam_Questions, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Exam_Questions, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Exam_Questions, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Exam_Questions_Y_Adv_Y = yes/(yes+no) 
Percent_Exam_Questions_N_Adv_Y = yes1/(yes1+no1) 
Percent_Exam_Questions_Y_Adv_N = no/(yes+no) 
Percent_Exam_Questions_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Exam_Questions_Y_Adv_Y,Percent_Exam_Questions_Y_Adv_N] 
y1=[Percent_Exam_Questions_N_Adv_Y,Percent_Exam_Questions_N_Adv_N]
# Out:
# 107
# 366
# 25
# 96

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Exam Questions')
ax2.set_title('Yes Exam Questions')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Hw_Simulation = []
for row in data.values[:,35]:
    Hw_Simulation.append(row)
yes=0
for i,j in zip(Hw_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Hw_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Hw_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Hw_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Hw_Simulation_Y_Adv_Y = yes/(yes+no) 
Percent_Hw_Simulation_N_Adv_Y = yes1/(yes1+no1) 
Percent_Hw_Simulation_Y_Adv_N = no/(yes+no) 
Percent_Hw_Simulation_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Hw_Simulation_Y_Adv_Y,Percent_Hw_Simulation_Y_Adv_N] 
y1=[Percent_Hw_Simulation_N_Adv_Y,Percent_Hw_Simulation_N_Adv_N]
# Out:
# 254
# 226
# 64
# 59

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Hw Simulation')
ax2.set_title('Yes Hw Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Class_Simulation = []
for row in data.values[:,36]:
    Class_Simulation.append(row)
yes=0
for i,j in zip(Class_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Class_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Class_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Class_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Class_Simulation_Y_Adv_Y = yes/(yes+no) 
Percent_Class_Simulation_N_Adv_Y = yes1/(yes1+no1) 
Percent_Class_Simulation_Y_Adv_N = no/(yes+no) 
Percent_Class_Simulation_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Class_Simulation_Y_Adv_Y,Percent_Class_Simulation_Y_Adv_N] 
y1=[Percent_Class_Simulation_N_Adv_Y,Percent_Class_Simulation_N_Adv_N]
# Out:
# 225
# 252
# 54
# 70

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Class Simulation')
ax2.set_title('Yes Class Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Outside_Class_Simulation = []
for row in data.values[:,37]:
    Outside_Class_Simulation.append(row)
yes=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Outside_Class_Simulation_Y_Adv_Y = yes/(yes+no) 
Percent_Outside_Class_Simulation_N_Adv_Y = yes1/(yes1+no1) 
Percent_Outside_Class_Simulation_Y_Adv_N = no/(yes+no) 
Percent_Outside_Class_Simulation_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Outside_Class_Simulation_Y_Adv_Y,Percent_Outside_Class_Simulation_Y_Adv_N] 
y1=[Percent_Outside_Class_Simulation_N_Adv_Y,Percent_Outside_Class_Simulation_N_Adv_N]
# Out:
# 302
# 174
# 52
# 72

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Out of Class Simulation')
ax2.set_title('Yes Out of Class Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Course_Project = []
for row in data.values[:,38]:
    Course_Project.append(row)
yes=0
for i,j in zip(Course_Project, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Course_Project, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Course_Project, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Course_Project, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Course_Project_Y_Adv_Y = yes/(yes+no) 
Percent_Course_Project_N_Adv_Y = yes1/(yes1+no1) 
Percent_Course_Project_Y_Adv_N = no/(yes+no) 
Percent_Course_Project_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Course_Project_Y_Adv_Y,Percent_Course_Project_Y_Adv_N] 
y1=[Percent_Course_Project_N_Adv_Y,Percent_Course_Project_N_Adv_N]
# Out:
# 294
# 183
# 56
# 68

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Course Project')
ax2.set_title('Yes Course Project')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Solve_Computation_Other = []
for row in data.values[:,39]:
    Solve_Computation_Other.append(row)
yes=0
for i,j in zip(Solve_Computation_Other, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Solve_Computation_Other, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Solve_Computation_Other, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Solve_Computation_Other, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Solve_Computation_Other_Y_Adv_Y = yes/(yes+no) 
Percent_Solve_Computation_Other_N_Adv_Y = yes1/(yes1+no1) 
Percent_Solve_Computation_Other_Y_Adv_N = no/(yes+no) 
Percent_Solve_Computation_Other_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Solve_Computation_Other_Y_Adv_Y,Percent_Solve_Computation_Other_Y_Adv_N] 
y1=[Percent_Solve_Computation_Other_N_Adv_Y,Percent_Solve_Computation_Other_N_Adv_N]
# Out:
# 61
# 50
# 11
# 18

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other Computation')
ax2.set_title('Yes Other Computation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced ','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 c in relation to 6

# %%
yes=0
for i,j in zip(Hw_About_Computation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Hw_About_Computation, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Hw_About_Computation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Hw_About_Computation, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Hw_About_Computation_Y_Research_Y = yes/(yes+no) 
Percent_Hw_About_Computation_N_Research_Y = yes1/(yes1+no1) 
Percent_Hw_About_Computation_Y_Research_N = no/(yes+no) 
Percent_Hw_About_Computation_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Hw_About_Computation_Y_Research_Y,Percent_Hw_About_Computation_Y_Research_N] 
y1=[Percent_Hw_About_Computation_N_Research_Y,Percent_Hw_About_Computation_N_Research_N]
# Out:
# 293
# 208
# 60
# 58

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Hw Questions')
ax2.set_title('Yes Hw Questions')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Interactive_Activities, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Interactive_Activities, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Interactive_Activities, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Interactive_Activities, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Interactive_Activities_Y_Research_Y = yes/(yes+no) 
Percent_Interactive_Activities_N_Research_Y = yes1/(yes1+no1) 
Percent_Interactive_Activities_Y_Research_N = no/(yes+no) 
Percent_Interactive_Activities_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Interactive_Activities_Y_Research_Y,Percent_Interactive_Activities_Y_Research_N] 
y1=[Percent_Interactive_Activities_N_Research_Y,Percent_Interactive_Activities_N_Research_N]
# Out:
# 94
# 390
# 38
# 74

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Interactive Activities')
ax2.set_title('Yes Interactive Activities')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Exam_Questions, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Exam_Questions, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Exam_Questions, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Exam_Questions, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Exam_Questions_Y_Research_Y = yes/(yes+no) 
Percent_Exam_Questions_N_Research_Y = yes1/(yes1+no1) 
Percent_Exam_Questions_Y_Research_N = no/(yes+no) 
Percent_Exam_Questions_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Exam_Questions_Y_Research_Y,Percent_Exam_Questions_Y_Research_N] 
y1=[Percent_Exam_Questions_N_Research_Y,Percent_Exam_Questions_N_Research_N]
# Out:
# 97
# 384
# 35
# 78

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Exam Questions')
ax2.set_title('Yes Exam Questions')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Hw_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Hw_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Hw_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Hw_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Hw_Simulation_Y_Research_Y = yes/(yes+no) 
Percent_Hw_Simulation_N_Research_Y = yes1/(yes1+no1) 
Percent_Hw_Simulation_Y_Research_N = no/(yes+no) 
Percent_Hw_Simulation_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Hw_Simulation_Y_Research_Y,Percent_Hw_Simulation_Y_Research_N] 
y1=[Percent_Hw_Simulation_N_Research_Y,Percent_Hw_Simulation_N_Research_N]
# Out:
# 263
# 231
# 55
# 54

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Hw Simulation')
ax2.set_title('Yes Hw Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Class_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Class_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Class_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Class_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Class_Simulation_Y_Research_Y = yes/(yes+no) 
Percent_Class_Simulation_N_Research_Y = yes1/(yes1+no1) 
Percent_Class_Simulation_Y_Research_N = no/(yes+no) 
Percent_Class_Simulation_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Class_Simulation_Y_Research_Y,Percent_Class_Simulation_Y_Research_N] 
y1=[Percent_Class_Simulation_N_Research_Y,Percent_Class_Simulation_N_Research_N]
# Out:
# 232
# 258
# 47
# 64

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Class Simulation')
ax2.set_title('Yes Class Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Outside_Class_Simulation, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Outside_Class_Simulation_Y_Research_Y = yes/(yes+no) 
Percent_Outside_Class_Simulation_N_Research_Y = yes1/(yes1+no1) 
Percent_Outside_Class_Simulation_Y_Research_N = no/(yes+no) 
Percent_Outside_Class_Simulation_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Outside_Class_Simulation_Y_Research_Y,Percent_Outside_Class_Simulation_Y_Research_N] 
y1=[Percent_Outside_Class_Simulation_N_Research_Y,Percent_Outside_Class_Simulation_N_Research_N]
# Out:
# 309
# 180
# 45
# 66

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Out of Class Simulation')
ax2.set_title('Yes Out of Class Simulation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Course_Project, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Course_Project, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Course_Project, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Course_Project, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
no1=0
for i,j in zip(Solve_Computation_Other, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
x=[1,2]
y=[yes,no]
y1=[yes1,no1]
# Out:
# 298
# 191
# 52
# 60

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Course Project')
ax2.set_title('Yes Course Project')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Solve_Computation_Other, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Solve_Computation_Other, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Solve_Computation_Other, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Solve_Computation_Other, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Solve_Computation_Other_Y_Research_Y = yes/(yes+no) 
Percent_Solve_Computation_Other_N_Research_Y = yes1/(yes1+no1) 
Percent_Solve_Computation_Other_Y_Research_N = no/(yes+no) 
Percent_Solve_Computation_Other_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Solve_Computation_Other_Y_Research_Y,Percent_Solve_Computation_Other_Y_Research_N] 
y1=[Percent_Solve_Computation_Other_N_Research_Y,Percent_Solve_Computation_Other_N_Research_N]
# Out:
# 61
# 51
# 11
# 17

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('No Other Computation')
ax2.set_title('Yes Other Computation')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research ','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 b in relation to Question 7

# %%
Teach_Doc_Code_YN = []
for row in data.values[:,41]:
    Teach_Doc_Code_YN.append(row)
yes=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Doc_Code_Y_Adv_Y = yes/(yes+no) 
Percent_Teach_Doc_Code_N_Adv_Y = yes1/(yes1+no1) 
Percent_Teach_Doc_Code_Y_Adv_N = no/(yes+no) 
Percent_Teach_Doc_Code_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Doc_Code_Y_Adv_Y,Percent_Teach_Doc_Code_Y_Adv_N] 
y1=[Percent_Teach_Doc_Code_N_Adv_Y,Percent_Teach_Doc_Code_N_Adv_N]
# Out:
# 216
# 282
# 38
# 96

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Documenting Code No')
ax2.set_title('Teach Documenting Code Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Teach_Debug_Code_YN = []
for row in data.values[:,42]:
    Teach_Debug_Code_YN.append(row)
yes=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Debug_Code_Y_Adv_Y = yes/(yes+no) 
Percent_Teach_Debug_Code_N_Adv_Y = yes1/(yes1+no1) 
Percent_Teach_Debug_Code_Y_Adv_N = no/(yes+no) 
Percent_Teach_Debug_Code_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Debug_Code_Y_Adv_Y,Percent_Teach_Debug_Code_Y_Adv_N] 
y1=[Percent_Teach_Debug_Code_N_Adv_Y,Percent_Teach_Debug_Code_N_Adv_N]
# Out:
# 243
# 256
# 46
# 86

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Debugging Code No')
ax2.set_title('Teach Debugging Code Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
Teach_Con_Ver_YN = []
for row in data.values[:,43]:
    Teach_Con_Ver_YN.append(row)
yes=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Con_Ver_Y_Adv_Y = yes/(yes+no) 
Percent_Teach_Con_Ver_N_Adv_Y = yes1/(yes1+no1) 
Percent_Teach_Con_Ver_Y_Adv_N = no/(yes+no) 
Percent_Teach_Con_Ver_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Con_Ver_Y_Adv_Y,Percent_Teach_Con_Ver_Y_Adv_N] 
y1=[Percent_Teach_Con_Ver_N_Adv_Y,Percent_Teach_Con_Ver_N_Adv_N]
# Out:
# 57
# 425
# 11
# 116

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Version Control No')
ax2.set_title('Teach Version Control Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 c in relation to Question 7

# %%
yes=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Doc_Code_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Doc_Code_Y_Research_Y = yes/(yes+no) 
Percent_Teach_Doc_Code_N_Research_Y = yes1/(yes1+no1) 
Percent_Teach_Doc_Code_Y_Research_N = no/(yes+no) 
Percent_Teach_Doc_Code_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Doc_Code_Y_Research_Y,Percent_Teach_Doc_Code_Y_Research_N] 
y1=[Percent_Teach_Doc_Code_N_Research_Y,Percent_Teach_Doc_Code_N_Research_N]
# Out:
# 213
# 300
# 41
# 78

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Documenting Code No')
ax2.set_title('Teach Documenting Code Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Debug_Code_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Debug_Code_Y_Research_Y = yes/(yes+no) 
Percent_Teach_Debug_Code_N_Research_Y = yes1/(yes1+no1) 
Percent_Teach_Debug_Code_Y_Research_N = no/(yes+no) 
Percent_Teach_Debug_Code_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Debug_Code_Y_Research_Y,Percent_Teach_Debug_Code_Y_Research_N] 
y1=[Percent_Teach_Debug_Code_N_Research_Y,Percent_Teach_Debug_Code_N_Research_N]
# Out:
# 245
# 268
# 44
# 74

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Debugging Code No')
ax2.set_title('Teach Debugging Code Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %%
yes=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Teach_Con_Ver_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Teach_Con_Ver_Y_Research_Y = yes/(yes+no) 
Percent_Teach_Con_Ver_N_Research_Y = yes1/(yes1+no1) 
Percent_Teach_Con_Ver_Y_Research_N = no/(yes+no) 
Percent_Teach_Con_Ver_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Teach_Con_Ver_Y_Research_Y,Percent_Teach_Con_Ver_Y_Research_N] 
y1=[Percent_Teach_Con_Ver_N_Research_Y,Percent_Teach_Con_Ver_N_Research_N]
# Out:
# 53
# 443
# 15
# 98

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Teach Version Control No')
ax2.set_title('Teach Version Control Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 b in relation to question 8

# %%
Soft_Access_YN = []
for row in data.values[:,44]:
    Soft_Access_YN.append(row)
yes=0
for i,j in zip(Soft_Access_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Soft_Access_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Soft_Access_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Soft_Access_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Soft_Access_Y_Adv_Y = yes/(yes+no) 
Percent_Soft_Access_N_Adv_Y = yes1/(yes1+no1) 
Percent_Soft_Access_Y_Adv_N = no/(yes+no) 
Percent_Soft_Access_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Soft_Access_Y_Adv_Y,Percent_Soft_Access_Y_Adv_N] 
y1=[Percent_Soft_Access_N_Adv_Y,Percent_Soft_Access_N_Adv_N]
# Out:
# 479
# 31
# 113
# 27

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Access to Software No')
ax2.set_title('Access to Software Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 c in relation to question 8

# %%
yes=0
for i,j in zip(Soft_Access_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(Soft_Access_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(Soft_Access_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(Soft_Access_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_Soft_Access_Y_Research_Y = yes/(yes+no) 
Percent_Soft_Access_N_Research_Y = yes1/(yes1+no1) 
Percent_Soft_Access_Y_Research_N = no/(yes+no) 
Percent_Soft_Access_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_Soft_Access_Y_Research_Y,Percent_Soft_Access_Y_Research_N] 
y1=[Percent_Soft_Access_N_Research_Y,Percent_Soft_Access_N_Research_N]
# Out:
# 486
# 40
# 106
# 18

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Access to Software No')
ax2.set_title('Access to Software Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 b in relation to question 9

# %%
HPC_Access_YN = []
for row in data.values[:,47]:
    HPC_Access_YN.append(row)
yes=0
for i,j in zip(HPC_Access_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(HPC_Access_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(HPC_Access_YN, How_Taught_Advanced_Course):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(HPC_Access_YN, How_Taught_Advanced_Course):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_HPC_Access_Y_Adv_Y = yes/(yes+no) 
Percent_HPC_Access_N_Adv_Y = yes1/(yes1+no1) 
Percent_HPC_Access_Y_Adv_N = no/(yes+no) 
Percent_HPC_Access_N_Adv_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_HPC_Access_Y_Adv_Y,Percent_HPC_Access_Y_Adv_N] 
y1=[Percent_HPC_Access_N_Adv_Y,Percent_HPC_Access_N_Adv_N]
# Out:
# 244
# 259
# 30
# 109

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Access to HPC No')
ax2.set_title('Access to HPC Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
ax2.set(xticklabels=['','Yes Advanced','','','','','No Advanced'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 3 c in relation to question 9

# %%
yes=0
for i,j in zip(HPC_Access_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Checked":
        yes+=1
print(yes)
yes1=0
for i,j in zip(HPC_Access_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Checked":
        yes1+=1
print(yes1)
no=0
for i,j in zip(HPC_Access_YN, How_Taught_Research_Experience):
    if i == "Yes" and j == "Unchecked":
        no+=1
print(no)
no1=0
for i,j in zip(HPC_Access_YN, How_Taught_Research_Experience):
    if i == "No" and j == "Unchecked":
        no1+=1
print(no1)
Percent_HPC_Access_Y_Research_Y = yes/(yes+no) 
Percent_HPC_Access_N_Research_Y = yes1/(yes1+no1) 
Percent_HPC_Access_Y_Research_N = no/(yes+no) 
Percent_HPC_Access_N_Research_N = no1/(yes1+no1) 
x=[1,2] 
y=[Percent_HPC_Access_Y_Research_Y,Percent_HPC_Access_Y_Research_N] 
y1=[Percent_HPC_Access_N_Research_Y,Percent_HPC_Access_N_Research_N]
# Out:
# 254
# 263
# 20
# 105

# %%
fig = plt.figure(figsize=(8,6))
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(20,10))
ax1.bar(x,y1,width=.25)
ax2.bar(x,y,width=.25)
ax1.set_title('Access to HPC No')
ax2.set_title('Access to HPC Yes')
ax1.set( ylabel='Percent')
ax1.set(xticklabels=['','Yes Research','','','','','No Research'])
ax2.set(xticklabels=['','Yes Research','','','','','No Research'])
sns.set(font_scale=2)
plt.tight_layout()
plt.show()
