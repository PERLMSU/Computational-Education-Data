# %% [markdown]
# # Set Up

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats

# %%
# #importing the uncleaned data
# data_uncleaned=pd.read_csv('Computational Data Without Identifiers.csv')
# #importing the cleaned data
# data=pd.read_csv(r'C:\Users\Grant\Desktop\Cleaned PERL Research data.csv', encoding='latin1')

# %%
#importing the data in two different formats
data_excel=pd.ExcelFile('Computational Data Without Identifiers.xlsx')
data_csv=pd.read_csv('Computational Data Without Identifiers.csv')
data=pd.read_excel('PERL Research Data.xlsx')

# %% [markdown]
# ## Question 1

# %%
Comp_Teaching_Exp_YN = [] #Creates an empty list to be used with the first question
for row in data.values[:,1]:
    Comp_Teaching_Exp_YN.append(row) #Fills the list

# %%
Comp_Teaching_Exp_Y = Comp_Teaching_Exp_YN.count("Yes")
Comp_Teaching_Exp_N = Comp_Teaching_Exp_YN.count("No")
Ans1=['Yes','No']
Tick1=[1,2]
Ans1_dist=[Comp_Teaching_Exp_Y/1246,Comp_Teaching_Exp_N/1246]
plt.xticks(Tick1,Ans1)
plt.bar(Tick1,Ans1_dist)
plt.title('Computaional Teaching Experience')
plt.ylabel('Proportion')

# %%
print('The number of respondents who have experience teaching computational modeling is:', Ans1_dist[0]*1246)
# Out:
# The number of respondents who have experience teaching computational modeling is: 751.0

# %% [markdown]
# ## Question 2

# %%
Deg_Comp_Phy_YN = []
for row in data.values[:,2]:
    Deg_Comp_Phy_YN.append(row)

# %%
Deg_Comp_Phy_Y = Deg_Comp_Phy_YN.count("Checked") #The number of respondents who said their institution offers a degree in Computiational Physics
print('The number of respondents who said their institution offers a degree in computational modeling is:', Deg_Comp_Phy_Y)
Prop_Deg_Comp_Phy_Y = Deg_Comp_Phy_Y/(Deg_Comp_Phy_YN.count("Unchecked")+Deg_Comp_Phy_Y)
print('Of those who answered, the proportion of respondents who said their institution offers a degree in computational modeling is:', Prop_Deg_Comp_Phy_Y)
# Out:
# The number of respondents who said their institution offers a degree in computational modeling is: 82
# Of those who answered, the proportion of respondents who said their institution offers a degree in computational modeling is: 0.11420612813370473

# %%
Minor_Comp_Phy_YN = []
for row in data.values[:,3]:
    Minor_Comp_Phy_YN.append(row)

# %%
Minor_Comp_Phy_Y = Minor_Comp_Phy_YN.count("Checked") #The Number of Respondents who answered that their institution offers a minor in Computational Physics
print('The number of respondents who said their institution offers a minor in computational modeling is:', Minor_Comp_Phy_Y)
Prop_Minor_Comp_Phy_Y = Minor_Comp_Phy_Y/(Minor_Comp_Phy_Y+Minor_Comp_Phy_YN.count("Unchecked"))
print('Of those who answered, the proportion who said their institution offers a minor in computational modeling is:', Prop_Minor_Comp_Phy_Y)
# Out:
# The number of respondents who said their institution offers a minor in computational modeling is: 29
# Of those who answered, the proportion who said their institution offers a minor in computational modeling is: 0.0403899721448468

# %%
Cert_Comp_Phy_YN = []
for row in data.values[:,4]:
    Cert_Comp_Phy_YN.append(row)
Cert_Comp_Phy_Y = Cert_Comp_Phy_YN.count("Checked") #Number of respondents who answered that their institution offers a certificate in Computational Physics
print('The number of respondents who said their institution offers a certificate in computational modeling is:',Cert_Comp_Phy_Y)
Prop_Cert_Comp_Phy_Y = Cert_Comp_Phy_Y/(Cert_Comp_Phy_Y+Cert_Comp_Phy_YN.count("Unchecked"))
print('Of those who answered, the proportion who said their institution offers a certificate in computational modeling is:', Prop_Cert_Comp_Phy_Y)
# Out:
# The number of respondents who said their institution offers a certificate in computational modeling is: 15
# Of those who answered, the proportion who said their institution offers a certificate in computational modeling is: 0.020891364902506964

# %%
Other_Comp_Phy_YN = []
for row in data.values[:,5]:
    Other_Comp_Phy_YN.append(row)
Other_Comp_Phy_Y = Other_Comp_Phy_YN.count("Checked") #Number of respondents who answered that their institution offers some other program in Computational Physics
print('The number of respondents who said their institution offers some other program in computational modeling is:',Other_Comp_Phy_Y)
Prop_Other_Comp_Phy_Y = Other_Comp_Phy_Y/(Other_Comp_Phy_Y+Other_Comp_Phy_YN.count("Unchecked"))
print('Of those who responded, the proportion who said their institution offers some other program in computational modeling is:', Prop_Other_Comp_Phy_Y)
# Out:
# The number of respondents who said their institution offers some other program in computational modeling is: 82
# Of those who responded, the proportion who said their institution offers some other program in computational modeling is: 0.11420612813370473

# %%
None_Above_Prog = []
for row in data.values[:,6]:
    None_Above_Prog.append(row)
None_Above_Prog_Y = None_Above_Prog.count("Checked") #Number of respondents who answered that their institution offers none of the above programs in Computational Physics
print('The number of respondents that answered that their institution offers none of the above programs is:', None_Above_Prog_Y)
Prop_None_Above_Prog = None_Above_Prog_Y/(None_Above_Prog_Y+None_Above_Prog.count("Unchecked"))
print('Of those who responded, the proportion who said their institution offers none of the above programs is:', Prop_None_Above_Prog)
# Out:
# The number of respondents that answered that their institution offers none of the above programs is: 531
# Of those who responded, the proportion who said their institution offers none of the above programs is: 0.7395543175487466

# %%
Ans2 = ['Degree', 'Minor', 'Certificate', 'Other', 'None of the Above']
Tick2 = [1,2,3,4,5]
Ans2_dist = [Prop_Deg_Comp_Phy_Y, Prop_Minor_Comp_Phy_Y, Prop_Cert_Comp_Phy_Y, Prop_Other_Comp_Phy_Y, Prop_None_Above_Prog]
plt.xticks(Tick2, Ans2)
plt.bar(Tick2,Ans2_dist)
plt.title('Proportion of Offerings in Computational Modeling')
plt.ylabel('Proportion')
plt.xlabel('Type of Offering')

# %%
Non_Ans = []
for row in data_uncleaned.values[:,3]:
    Non_Ans.append(row)
Non_Ans_num = 1246 - Non_Ans.count("Checked") - Non_Ans.count("Unchecked") - Non_Ans.count("Valid Skip") #Number of respondents who answered that their institution offers none of the above programs in Computational Physics
print('The number of non-responses is:', Non_Ans_num)
Prop_Non_Ans = Non_Ans_num/(1246-Non_Ans.count("Valid Skip"))
print('The response rate to question 1 iss:', 1-Prop_Non_Ans)
# Out:
# The number of non-responses is: 32
# The response rate to question 1 iss: 0.9573901464713716

# %% [markdown]
# ## Question 3
# How is computation taught to your undergraduate physics majors?

# %%
#This is for column I
How_Taught_Intro_Course = []
for row in data.values[:,8]:
    How_Taught_Intro_Course.append(row)
How_Taught_Intro_Course_Y = How_Taught_Intro_Course.count("Checked") #Introductory undergraduate physics courses that use computation
Percentage_Yes_Intro=100*How_Taught_Intro_Course_Y/(How_Taught_Intro_Course_Y+How_Taught_Intro_Course.count("Unchecked"))
print("Of the",How_Taught_Intro_Course_Y+How_Taught_Intro_Course.count("Unchecked"),"people who answered this question",Percentage_Yes_Intro,"percent said they teach computation using introductory physics courses. That is",How_Taught_Intro_Course_Y,"people.")
x=[1,2]
y=[How_Taught_Intro_Course_Y,How_Taught_Intro_Course.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Teach Using Introductory Physics Course?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 690 people who answered this question 59.27536231884058 percent said they teach computation using introductory physics courses. That is 409 people.
# ([<matplotlib.axis.XTick at 0xa7694a8>, <matplotlib.axis.XTick at 0xa784f28>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column J
Intro_Course_Required = []
for row in data.values[:,9]:
    Intro_Course_Required.append(row)
Intro_Course_Required_Y = Intro_Course_Required.count("Checked") #Required introductory undergraduate physics courses that use computation
Percentage_Required_Intro=100*Intro_Course_Required_Y/How_Taught_Intro_Course_Y
print("There are" ,Intro_Course_Required_Y, "that teach computation from required introductory physics courses.")
print("That is",Percentage_Required_Intro,"percent of the 409 that that said they teach computation in introductory physics courses")
# Out:
# There are 328 that teach computation from required introductory physics courses.
# That is 80.19559902200488 percent of the 409 that that said they teach computation in introductory physics courses

# %%
#This is for column K
Intro_Course_Elective = []
for row in data.values[:,10]:
    Intro_Course_Elective.append(row)
Intro_Course_Elective_Y = Intro_Course_Elective.count("Checked") #Required introductory undergraduate physics courses that use computation
Percentage_Elective_Intro=100*Intro_Course_Elective_Y/How_Taught_Intro_Course_Y
print("There are" ,Intro_Course_Elective_Y, "that teach computation from elective introductory physics courses.")
print("That is",Percentage_Elective_Intro,"percent of the 409 that that said they teach computation in introductory physics courses")
x=[1,2]
y=[Percentage_Required_Intro,Percentage_Elective_Intro]
plt.bar(x,y,width=.25)
labels=['required','elective']
plt.xticks(x,labels)
plt.ylabel('Percentage')
plt.title('Intro courses that use computational modeling')
# Out:
# There are 106 that teach computation from elective introductory physics courses.
# That is 25.91687041564792 percent of the 409 that that said they teach computation in introductory physics courses

# %%
#This is for column L
How_Taught_Advanced_Course = []
for row in data.values[:,11]:
    How_Taught_Advanced_Course.append(row)
How_Taught_Advanced_Course_Y = How_Taught_Advanced_Course.count("Checked") #Advanced undergraduate physics courses that use computation
Percentage_Yes_Advanced=100*How_Taught_Advanced_Course_Y/(How_Taught_Advanced_Course_Y+How_Taught_Advanced_Course.count("Unchecked"))
print("Of the",How_Taught_Advanced_Course_Y+How_Taught_Advanced_Course.count("Unchecked"),"people who answered this question",Percentage_Yes_Advanced,"percent said they teach computation using advanced physics courses. That is",How_Taught_Advanced_Course_Y,"people.")
x=[1,2]
y=[How_Taught_Advanced_Course_Y,How_Taught_Advanced_Course.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Teach Using Advanced Physics Course?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 690 people who answered this question 77.68115942028986 percent said they teach computation using advanced physics courses. That is 536 people.
# ([<matplotlib.axis.XTick at 0xa50a550>, <matplotlib.axis.XTick at 0xa88dbe0>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column M
Advanced_Course_Required = []
for row in data.values[:,12]:
    Advanced_Course_Required.append(row)
Advanced_Course_Required_Y = Advanced_Course_Required.count("Checked") #Required advanced undergraduate physics courses that use computation
Percentage_Required_Advanced=100*Advanced_Course_Required_Y/How_Taught_Advanced_Course_Y
print("There are" ,Advanced_Course_Required_Y, "that teach computation from required advanced physics courses.")
print("That is",Percentage_Required_Advanced,"percent of the 536 that that said they teach computation in advanced physics courses")
# Out:
# There are 353 that teach computation from required advanced physics courses.
# That is 65.85820895522389 percent of the 536 that that said they teach computation in advanced physics courses

# %%
#This is for column N
Advanced_Course_Elective = []
for row in data.values[:,13]:
    Advanced_Course_Elective.append(row)
Advanced_Course_Elective_Y = Advanced_Course_Elective.count("Checked") #elective advanced undergraduate physics courses that use computation
Percentage_Elective_Advanced=100*Advanced_Course_Elective_Y/How_Taught_Advanced_Course_Y
print("There are" ,Advanced_Course_Elective_Y, "that teach computation from required advanced physics courses.")
print("That is",Percentage_Elective_Advanced,"percent of the 536 that that said they teach computation in advanced physics courses")
x=[1,2]
y=[Percentage_Required_Advanced,Percentage_Elective_Advanced]
plt.bar(x,y,width=.25)
labels=['required','elective']
plt.xticks(x,labels)
plt.ylabel('Percentage')
plt.title('Advanced courses that use computational modeling')
# Out:
# There are 293 that teach computation from required advanced physics courses.
# That is 54.66417910447761 percent of the 536 that that said they teach computation in advanced physics courses

# %%
#This is for column O
How_Taught_Research_Experience = []
for row in data.values[:,14]:
    How_Taught_Research_Experience.append(row)
How_Taught_Research_Experience_Y = How_Taught_Research_Experience.count("Checked") #Undergraduate physics research that use computation
Percentage_Yes_Research=100*How_Taught_Research_Experience_Y/(How_Taught_Research_Experience_Y+How_Taught_Research_Experience.count("Unchecked"))
print("Of the",How_Taught_Research_Experience_Y+How_Taught_Research_Experience.count("Unchecked"),"people who answered this question",Percentage_Yes_Research,"percent said they teach computation using research experience. That is",How_Taught_Research_Experience_Y,"people.")
x=[1,2]
y=[How_Taught_Research_Experience_Y,How_Taught_Research_Experience.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Teach Using Research experience?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 690 people who answered this question 80.72463768115942 percent said they teach computation using research experience. That is 557 people.
# ([<matplotlib.axis.XTick at 0xac1e748>, <matplotlib.axis.XTick at 0xac5b630>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column P
Research_Required = []
for row in data.values[:,15]:
    Research_Required.append(row)
Research_Required_Y = Research_Required.count("Checked") #Required research that uses computation
Percentage_Required_Research=100*Research_Required_Y/How_Taught_Research_Experience_Y
print("There are" ,Research_Required_Y, "that teach computation from required physics research.")
print("That is",Percentage_Required_Research,"percent of the 557 that said they teach computation in research")
# Out:
# There are 100 that teach computation from required physics research.
# That is 17.953321364452425 percent of the 557 that said they teach computation in research

# %%
#This is for column Q
Research_Elective = []
for row in data.values[:,16]:
    Research_Elective.append(row)
Research_Elective_Y = Research_Elective.count("Checked") #elective research that uses computation
Percentage_Elective_Research=100*Research_Elective_Y/How_Taught_Research_Experience_Y
print("There are" ,Research_Elective_Y, "that teach computation from elective physics research.")
print("That is",Percentage_Elective_Research,"percent of the 557 that said they teach computation in research")
x=[1,2]
y=[Percentage_Required_Research,Percentage_Elective_Research]
plt.bar(x,y,width=.25)
labels=['required','elective']
plt.xticks(x,labels)
plt.ylabel('Percentage')
plt.title('Research Experience that use computational modeling')
# Out:
# There are 386 that teach computation from elective physics research.
# That is 69.29982046678636 percent of the 557 that said they teach computation in research

# %%
#This is for column R
How_Taught_Not_Taught = []
for row in data.values[:,17]:
    How_Taught_Not_Taught.append(row)
How_Taught_Not_Taught_Y = How_Taught_Not_Taught.count("Checked") #Undergraduate physics research that do not use computation
Percentage_Not=100*How_Taught_Not_Taught_Y/(How_Taught_Not_Taught_Y+How_Taught_Not_Taught.count("Unchecked"))
print("Of the",How_Taught_Not_Taught_Y+How_Taught_Not_Taught.count("Unchecked"),"people who answered this question",Percentage_Not,"percent said they do not teach computation. That is",How_Taught_Not_Taught_Y,"people.")
x=[1,2]
y=[How_Taught_Not_Taught_Y,How_Taught_Not_Taught.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Teach computation?')
labels=['no','yes']
plt.xticks(x,labels)
# Out:
# Of the 690 people who answered this question 1.4492753623188406 percent said they do not teach computation. That is 10 people.
# ([<matplotlib.axis.XTick at 0xad1ecc0>, <matplotlib.axis.XTick at 0xad3add8>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column S
How_Taught_Other = []
for row in data.values[:,18]:
    How_Taught_Other.append(row)
How_Taught_Other_Y = How_Taught_Other.count("Checked") #Undergraduate physics research that do computation an other way
Percentage_Other=100*How_Taught_Other_Y/(How_Taught_Other_Y+How_Taught_Other.count("Unchecked"))
print("Of the",How_Taught_Other_Y+How_Taught_Other.count("Unchecked"),"people who answered this question",Percentage_Other,"percent said they teach computation some other way. That is",How_Taught_Other_Y,"people.")
x=[1,2]
y=[How_Taught_Other_Y,How_Taught_Other.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Teach Some Other Way?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 690 people who answered this question 7.246376811594203 percent said they teach computation some other way. That is 50 people.
# ([<matplotlib.axis.XTick at 0xa6c9978>, <matplotlib.axis.XTick at 0xadfd278>],
#  <a list of 2 Text xticklabel objects>)

# %%
#yes intro percent
Percentage_Yes_Intro
#yes advanced percent
Percentage_Yes_Advanced
#yes research percent
Percentage_Yes_Research
#none percent
Percentage_Not
#Other percent
Percentage_Other
x=[1,2,3,4,5]
y=[Percentage_Yes_Intro,Percentage_Yes_Advanced,Percentage_Yes_Research,Percentage_Not,Percentage_Other]
fig=plt.figure(figsize=(10,6))
plt.bar(x,y)
labels=['Intro Course','Advanced Course','Research Experience','None','Other']
plt.xticks(x,labels)
plt.title('Percentage that use computational modeling')
plt.ylabel('Percentage out of 100')

# %%
x=[1,2,3,4,5,6]
y=[Percentage_Required_Intro,Percentage_Elective_Intro,Percentage_Required_Advanced,Percentage_Elective_Advanced,Percentage_Required_Research,Percentage_Elective_Research]
fig=plt.figure(figsize=(10,5))
plt.bar(x,y,width=.45)
labels=['required Intro','elective Intro','required Advanced','elective Advanced','required research','elective research']
plt.xticks(x,labels,rotation=20)
plt.ylabel('Percentage')
plt.title('percentage for required and elective')

# %% [markdown]
# ## Question 4

# %%
Comp_Use_Envir_YN = []
#Column U
for row in data.values[:,20]:
    Comp_Use_Envir_YN.append(row)
#Number of respondents who answered that their institution uses envirenments such as Matlab, Mathmatica, etc for teaching computation 
Comp_Use_Envir_Y = Comp_Use_Envir_YN.count("Checked") 
print('The number of repondents who said their institution uses computing envirnments to teach computation is:', Comp_Use_Envir_Y)
#Proportion
Prop_Comp_Use_Envir_Y = Comp_Use_Envir_Y/(Comp_Use_Envir_Y+Comp_Use_Envir_YN.count("Unchecked"))
print('Of those who responded, the proportion of repondents who said their institution uses computing envirnments to teach computation is:', Prop_Comp_Use_Envir_Y)
# Out:
# The number of repondents who said their institution uses computing envirnments to teach computation is: 422
# Of those who responded, the proportion of repondents who said their institution uses computing envirnments to teach computation is: 0.6215022091310751

# %%
Comp_Use_Scripting_YN = []
#Collumn V
for row in data.values[:,21]:
    Comp_Use_Scripting_YN.append(row)
#Number of respondents who answered that their institution uses scripting languages such as Python or VPython for teaching computation 
Comp_Use_Scripting_Y = Comp_Use_Scripting_YN.count("Checked")
print('The number of repondents who said their institution uses scripting languages to teach computation is:', Comp_Use_Scripting_Y)
#Proportion
Prop_Comp_Use_Scripting_Y = Comp_Use_Scripting_Y/(Comp_Use_Scripting_Y+Comp_Use_Scripting_YN.count("Unchecked"))
print('Of those who responded, the proportion who said their institution uses scripting languages to teach computation is:', Prop_Comp_Use_Scripting_Y)
# Out:
# The number of repondents who said their institution uses scripting languages to teach computation is: 293
# Of those who responded, the proportion who said their institution uses scripting languages to teach computation is: 0.43151693667157587

# %%
Comp_Use_Compiled_YN = []
#Collumn W
for row in data.values[:,22]:
    Comp_Use_Compiled_YN.append(row)
#Number of respondents who answered that their institution uses Compiled languages such as C++, Java for teaching computation 
Comp_Use_Compiled_Y = Comp_Use_Compiled_YN.count("Checked") 
print('The number of repondents who said their institution uses compiled languages to teach computation is:', Comp_Use_Compiled_Y)
#Proportion
Prop_Comp_Use_Compiled_Y = Comp_Use_Compiled_Y/(Comp_Use_Compiled_Y+Comp_Use_Compiled_YN.count("Unchecked"))
print('Of those who responded, The proportion who said their institution uses compiled languages to teach computation is:', Prop_Comp_Use_Compiled_Y)
# Out:
# The number of repondents who said their institution uses compiled languages to teach computation is: 185
# Of those who responded, The proportion who said their institution uses compiled languages to teach computation is: 0.27245949926362295

# %%
Comp_Use_Excel_YN = []
#Collumn X
for row in data.values[:,23]:
    Comp_Use_Excel_YN.append(row)
#Number of respondents who answered that their institution uses Excel for teaching computation 
Comp_Use_Excel_Y = Comp_Use_Excel_YN.count("Checked") 
print('The number of respondents who said thier institution uses excel to teach computational modeling is:', Comp_Use_Excel_Y)
#Proportion
Prop_Comp_Use_Excel_Y = Comp_Use_Excel_Y/(Comp_Use_Excel_Y+Comp_Use_Excel_YN.count("Unchecked"))
print('Of those who responded, the proportion who said thier institution uses excel to teach computational modeling is:', Prop_Comp_Use_Excel_Y)
# Out:
# The number of respondents who said thier institution uses excel to teach computational modeling is: 424
# Of those who responded, the proportion who said thier institution uses excel to teach computational modeling is: 0.6244477172312224

# %%
Comp_Use_Other_YN = []
#Collumn Y
for row in data.values[:,24]:
    Comp_Use_Other_YN.append(row)
#Number of respondents who answered that their institution uses other mediums of teaching for teaching computation 
Comp_Use_Other_Y = Comp_Use_Other_YN.count("Checked") 
print('The number of responents who said thier institution uses some other medium to teach computational modeling is:', Comp_Use_Other_Y)
#Proportion
Prop_Comp_Use_Other_Y = Comp_Use_Other_Y/(Comp_Use_Other_Y+Comp_Use_Other_YN.count("Unchecked"))
print('Of those who responded, The proportion who said thier institution uses some other medium to teach computational modeling is:', Prop_Comp_Use_Other_Y)
# Out:
# The number of responents who said thier institution uses some other medium to teach computational modeling is: 78
# Of those who responded, The proportion who said thier institution uses some other medium to teach computational modeling is: 0.11487481590574374

# %%
Ans4 = ['Computing Envirnments', 'Scripting Languages', 'Compiled Languages', 'Excel', 'Other']
Tick4 = [1,2,3,4,5]
Ans4_dist = [Prop_Comp_Use_Envir_Y, Prop_Comp_Use_Scripting_Y, Prop_Comp_Use_Compiled_Y, Prop_Comp_Use_Excel_Y, Prop_Comp_Use_Other_Y]
plt.xticks(Tick4, Ans4, rotation=45)
plt.bar(Tick2, Ans4_dist)
plt.title('Use of Computing Tools for Teaching')
plt.ylabel('Proportion')
plt.xlabel('Type of Tool')

# %%
Non_Ans_4 = []
for row in data_uncleaned.values[:,24]:
    Non_Ans_4.append(row)
Non_Ans_4_num = 1246 - Non_Ans_4.count("Valid Skip") - Comp_Use_Other_YN.count("Checked") - Comp_Use_Other_YN.count("Unchecked")
print('The Number of non-responses for question 4 is:', Non_Ans_4_num)
Prop_Non_Ans_4 = Non_Ans_4_num/(1246 - Non_Ans_4.count("Valid Skip"))
print('The Proportion of non-responses for question 4 is:', Prop_Non_Ans_4)
# Out:
# The Number of non-responses for question 4 is: 72
# The Proportion of non-responses for question 4 is: 0.09587217043941411

# %% [markdown]
# ## Question 5

# %%
Adv_Course_Comp_Use_Envir_YN = []
#Column AA
for row in data.values[:,26]:
    Adv_Course_Comp_Use_Envir_YN.append(row)
#Number of respondents who answered that their institution uses envirenments such as Matlab, Mathmatica, etc for advanced courses 
Adv_Course_Comp_Use_Envir_Y = Adv_Course_Comp_Use_Envir_YN.count("Checked") 
print('The number of repondents who said their institution uses computing envirnments for advanced courses is:', Adv_Course_Comp_Use_Envir_Y)
#Proportion
Prop_Adv_Course_Comp_Use_Envir_Y = Adv_Course_Comp_Use_Envir_Y/(Adv_Course_Comp_Use_Envir_Y+Adv_Course_Comp_Use_Envir_YN.count("Unchecked"))
print('Of those who responded, the proportion of repondents who said their institution uses computing envirnments for advanced courses is:', Prop_Adv_Course_Comp_Use_Envir_Y)
# Out:
# The number of repondents who said their institution uses computing envirnments for advanced courses is: 493
# Of those who responded, the proportion of repondents who said their institution uses computing envirnments for advanced courses is: 0.7336309523809523

# %%
Adv_Course_Comp_Use_Scripting_YN = []
#Collumn AB
for row in data.values[:,27]:
    Adv_Course_Comp_Use_Scripting_YN.append(row)
#Number of respondents who answered that their institution uses scripting languages such as Python or VPython for advanced courses 
Adv_Course_Comp_Use_Scripting_Y = Adv_Course_Comp_Use_Scripting_YN.count("Checked")
print('The number of repondents who said their institution uses scripting languages for advanced courses is:', Adv_Course_Comp_Use_Scripting_Y)
#Proportion
Adv_Course_Prop_Comp_Use_Scripting_Y = Adv_Course_Comp_Use_Scripting_Y/(Adv_Course_Comp_Use_Scripting_Y+Adv_Course_Comp_Use_Scripting_YN.count("Unchecked"))
print('Of those who responded, the proportion who said their institution uses scripting languages for advanced courses is:', Adv_Course_Prop_Comp_Use_Scripting_Y)
# Out:
# The number of repondents who said their institution uses scripting languages for advanced courses is: 330
# Of those who responded, the proportion who said their institution uses scripting languages for advanced courses is: 0.49107142857142855

# %%
Adv_Course_Comp_Use_Compiled_YN = []
#Collumn AC
for row in data.values[:,28]:
    Adv_Course_Comp_Use_Compiled_YN.append(row)
#Number of respondents who answered that their institution uses Compiled languages such as C++, Java for teaching computation 
Adv_Course_Comp_Use_Compiled_Y = Adv_Course_Comp_Use_Compiled_YN.count("Checked") 
print('The number of repondents who said their institution uses compiled languages for advanced courses is:', Adv_Course_Comp_Use_Compiled_Y)
#Proportion
Adv_Course_Prop_Comp_Use_Compiled_Y = Adv_Course_Comp_Use_Compiled_Y/(Adv_Course_Comp_Use_Compiled_Y+Adv_Course_Comp_Use_Compiled_YN.count("Unchecked"))
print('Of those who responded, The proportion who said their institution uses compiled languages for advanced courses is:', Adv_Course_Prop_Comp_Use_Compiled_Y)
# Out:
# The number of repondents who said their institution uses compiled languages for advanced courses is: 283
# Of those who responded, The proportion who said their institution uses compiled languages for advanced courses is: 0.4211309523809524

# %%
Adv_Course_Comp_Use_Excel_YN = []
#Collumn AD
for row in data.values[:,29]:
    Adv_Course_Comp_Use_Excel_YN.append(row)
#Number of respondents who answered that their institution uses Excel for teaching computation 
Adv_Course_Comp_Use_Excel_Y = Adv_Course_Comp_Use_Excel_YN.count("Checked") 
print('The number of respondents who said thier institution uses excel for advanced courses is:', Adv_Course_Comp_Use_Excel_Y)
#Proportion
Adv_Course_Prop_Comp_Use_Excel_Y = Adv_Course_Comp_Use_Excel_Y/(Adv_Course_Comp_Use_Excel_Y+Adv_Course_Comp_Use_Excel_YN.count("Unchecked"))
print('Of those who responded, the proportion who said thier institution uses excel for advanced courses is:', Adv_Course_Prop_Comp_Use_Excel_Y)
# Out:
# The number of respondents who said thier institution uses excel for advanced courses is: 290
# Of those who responded, the proportion who said thier institution uses excel for advanced courses is: 0.43154761904761907

# %%
Adv_Course_Comp_Use_Other_YN = []
#Collumn AE
for row in data.values[:,30]:
    Adv_Course_Comp_Use_Other_YN.append(row)
#Number of respondents who answered that their institution uses other mediums of teaching for teaching computation 
Adv_Course_Comp_Use_Other_Y = Adv_Course_Comp_Use_Other_YN.count("Checked") 
print('The number of responents who said thier institution uses some other medium for advanced courses is:', Adv_Course_Comp_Use_Other_Y)
#Proportion
Adv_Course_Prop_Comp_Use_Other_Y = Adv_Course_Comp_Use_Other_Y/(Adv_Course_Comp_Use_Other_Y+Adv_Course_Comp_Use_Other_YN.count("Unchecked"))
print('Of those who responded, The proportion who said thier institution uses some other medium for advanced courses is:', Adv_Course_Prop_Comp_Use_Other_Y)
# Out:
# The number of responents who said thier institution uses some other medium for advanced courses is: 60
# Of those who responded, The proportion who said thier institution uses some other medium for advanced courses is: 0.08928571428571429

# %%
Ans5 = ['Computing Envirnments', 'Scripting Languages', 'Compiled Languages', 'Excel', 'Other']
Tick5 = [1,2,3,4,5]
Ans5_dist = [Prop_Adv_Course_Comp_Use_Envir_Y, Adv_Course_Prop_Comp_Use_Scripting_Y, Adv_Course_Prop_Comp_Use_Compiled_Y, Adv_Course_Prop_Comp_Use_Excel_Y, Adv_Course_Prop_Comp_Use_Other_Y]
plt.xticks(Tick5, Ans5, rotation=45)
plt.bar(Tick5, Ans5_dist)
plt.title('Use of Computing Tools for Advanced Courses')
plt.ylabel('Proportion')
plt.xlabel('Type of Tool')

# %%
Non_Ans_5 = []
for row in data_uncleaned.values[:,30]:
    Non_Ans_5.append(row)
Non_Ans_5_num = 1246 - Non_Ans_5.count("Valid Skip") - Adv_Course_Comp_Use_Other_YN.count("Checked") - Adv_Course_Comp_Use_Other_YN.count("Unchecked")
print('The Number of non-responses for question 5 is:', Non_Ans_5_num)
Prop_Non_Ans_5 = Non_Ans_5_num/(1246 - Non_Ans_5.count("Valid Skip"))
print('The Proportion of non-responses for question 5 is:', Prop_Non_Ans_5)
# Out:
# The Number of non-responses for question 5 is: 79
# The Proportion of non-responses for question 5 is: 0.1051930758988016

# %% [markdown]
# ## Question 6
# Think about the class you most recently taught that included computation. Did the students use computation to solve physics problems in your undergraduate course?

# %%
# Column AG column 32
Hw_About_Computation = []
for row in data.values[:,32]:
    Hw_About_Computation.append(row)
Hw_About_Computation_Y = Hw_About_Computation.count("Yes")
Percentage_Hw=100*Hw_About_Computation_Y/(Hw_About_Computation_Y+Hw_About_Computation.count("No"))
print("Of the",Hw_About_Computation_Y+Hw_About_Computation.count("No"),"people who answered this question",Percentage_Hw,"percent said the undergads solved physics problems in the undergraduate course by answering homework questions about computation. That is",Hw_About_Computation_Y,"people.")
x=[1,2]
y=[Hw_About_Computation_Y,Hw_About_Computation.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with homework questions about computation')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AH column 33 Through completing interactive activities in class
Interactive_Activities = []
for row in data.values[:,33]:
    Interactive_Activities.append(row)
Interactive_Activities_Y = Interactive_Activities.count("Yes")
Percentage_Interactive_Activities=100*Interactive_Activities_Y/(Interactive_Activities_Y+Interactive_Activities.count("No"))
print("Of the",Interactive_Activities_Y+Interactive_Activities.count("No"),"people who answered this question",Percentage_Interactive_Activities,"percent said the undergads solved physics problems in the undergraduate course by having interactive activities about computation. That is",Interactive_Activities_Y,"people.")
x=[1,2]
y=[Interactive_Activities_Y,Interactive_Activities.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with Interactive Activites about computation')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AI column 34 Answering exam questions about computation
Exam_Questions = []
for row in data.values[:,34]:
    Exam_Questions.append(row)
Exam_Questions_Y = Exam_Questions.count("Yes")
Percentage_Exam_Questions=100*Exam_Questions_Y/(Exam_Questions_Y+Exam_Questions.count("No"))
print("Of the",Exam_Questions_Y+Exam_Questions.count("No"),"people who answered this question",Percentage_Exam_Questions,"percent said the undergads solved physics problems in the undergraduate course by having Exam questions about computation. That is",Exam_Questions_Y,"people.")
x=[1,2]
y=[Exam_Questions_Y,Exam_Questions.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with Exam Questions about computation')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AJ column 35 Using a pre-constructed simulation to solve homework problems
Hw_Simulation = []
for row in data.values[:,35]:
    Hw_Simulation.append(row)
Hw_Simulation_Y = Hw_Simulation.count("Yes")
Percentage_Hw_Simulation=100*Hw_Simulation_Y/(Hw_Simulation_Y+Hw_Simulation.count("No"))
print("Of the",Hw_Simulation_Y+Hw_Simulation.count("No"),"people who answered this question",Percentage_Hw_Simulation,"percent said the undergads solved physics problems in the undergraduate course by having a pre-constructed simulation to solve homework problems about computation. That is",Hw_Simulation_Y,"people.")
x=[1,2]
y=[Hw_Simulation_Y,Hw_Simulation.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with pre-constructed simulation')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AK column 36 Creating/developing a simulation of some physical phenomenon in class
Class_Simulation = []
for row in data.values[:,36]:
    Class_Simulation.append(row)
Class_Simulation_Y = Class_Simulation.count("Yes")
Percentage_Class_Simulation=100*Class_Simulation_Y/(Class_Simulation_Y+Class_Simulation.count("No"))
print("Of the",Class_Simulation_Y+Class_Simulation.count("No"),"people who answered this question",Percentage_Class_Simulation,"percent said the undergads solved physics problems in the undergraduate course by having an in class simulation involving computation. That is",Class_Simulation_Y,"people.")
x=[1,2]
y=[Class_Simulation_Y,Class_Simulation.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with simulation in class')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AL column 37 Creating/developing a simulation of some physical phenomenon outside of class
Outside_Class_Simulation = []
for row in data.values[:,37]:
    Outside_Class_Simulation.append(row)
Outside_Class_Simulation_Y = Outside_Class_Simulation.count("Yes")
Percentage_Outside_Class_Simulation=100*Outside_Class_Simulation_Y/(Outside_Class_Simulation_Y+Outside_Class_Simulation.count("No"))
print("Of the",Outside_Class_Simulation_Y+Outside_Class_Simulation.count("No"),"people who answered this question",Percentage_Outside_Class_Simulation,"percent said the undergads solved physics problems in the undergraduate course by having an out of class simulation involving computation. That is",Outside_Class_Simulation_Y,"people.")
x=[1,2]
y=[Outside_Class_Simulation_Y,Outside_Class_Simulation.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with simulation out of class')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AM column 38 Completing a course project where they model some physical phenomenon with computation
Course_Project = []
for row in data.values[:,38]:
    Course_Project.append(row)
Course_Project_Y = Course_Project.count("Yes")
Percentage_Course_Project=100*Course_Project_Y/(Course_Project_Y+Course_Project.count("No"))
print("Of the",Course_Project_Y+Course_Project.count("No"),"people who answered this question",Percentage_Course_Project,"percent said the undergads solved physics problems in the undergraduate course by having a course project involving computation. That is",Course_Project_Y,"people.")
x=[1,2]
y=[Course_Project_Y,Course_Project.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Courses with Course Project')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column AN column 39 Other
Solve_Computation_Other = []
for row in data.values[:,39]:
    Solve_Computation_Other.append(row)
Solve_Computation_Other_Y = Solve_Computation_Other.count("Yes")
Percentage_Solve_Computation_Other=100*Solve_Computation_Other_Y/(Solve_Computation_Other_Y+Solve_Computation_Other.count("No"))
print("Of the",Solve_Computation_Other_Y+Solve_Computation_Other.count("No"),"people who answered this question",Percentage_Solve_Computation_Other,"percent said the undergads solved physics problems in the undergraduate course some other way involving computation. That is",Solve_Computation_Other_Y,"people.")
x=[1,2]
y=[Solve_Computation_Other_Y,Solve_Computation_Other.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Some other way')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#hw
Percentage_Hw
#interactive activites
Percentage_Interactive_Activities
#exam questions
Percentage_Exam_Questions
#hw simulation
Percentage_Hw_Simulation
#class simulation
Percentage_Class_Simulation
#outside class simulation
Percentage_Outside_Class_Simulation
#course project
Percentage_Course_Project
#other
Percentage_Solve_Computation_Other
x=[1,2,3,4,5,6,7,8]
y=[Percentage_Hw, Percentage_Interactive_Activities, Percentage_Exam_Questions, Percentage_Hw_Simulation, Percentage_Class_Simulation, Percentage_Outside_Class_Simulation, Percentage_Course_Project, Percentage_Solve_Computation_Other]
fig=plt.figure(figsize=(15,7))
plt.bar(x,y,width=.5)
labels=['Homework','Interactive Activities','Exam Questions','HW Simulation','Class Simulation','Outside class Simulation','Course Project','Other']
plt.xticks(x,labels,rotation=25)
plt.title('Percentage of the students that use computation to solve physics problems in the undergraduate course')
plt.ylabel('Percentage out of 100')

# %% [markdown]
# ## Question 7

# %%
Teach_Doc_Code_YN = []
#Collumn AP
for row in data.values[:,41]:
    Teach_Doc_Code_YN.append(row)
#Number of respondents who answered that they taught documenting code 
Teach_Doc_Code_Y = Teach_Doc_Code_YN.count("Yes") 
print('The number of responents who said they taught documenting code in the last undergraduate physics course they taught that utilized programming:', Teach_Doc_Code_Y)
#Proportion
Prop_Teach_Doc_Code_Y = Teach_Doc_Code_Y/(Teach_Doc_Code_Y+Teach_Doc_Code_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Doc_Code_Y)
# Out:
# The number of responents who said they taught documenting code in the last undergraduate physics course they taught that utilized programming: 254
# Of those who responded, The proportion who said this is: 0.4

# %%
Teach_Debug_Code_YN = []
#Collumn AQ
for row in data.values[:,42]:
    Teach_Debug_Code_YN.append(row)
#Number of respondents who answered that they taught debugging code 
Teach_Debug_Code_Y = Teach_Debug_Code_YN.count("Yes") 
print('The number of responents who said they taught debugging code in the last undergraduate physics course they taught that utilized programming:', Teach_Debug_Code_Y)
#Proportion
Prop_Teach_Debug_Code_Y = Teach_Debug_Code_Y/(Teach_Debug_Code_Y+Teach_Debug_Code_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Debug_Code_Y)
# Out:
# The number of responents who said they taught debugging code in the last undergraduate physics course they taught that utilized programming: 289
# Of those who responded, The proportion who said this is: 0.4558359621451104

# %%
Teach_Con_Ver_YN = []
#Collumn AR
for row in data.values[:,43]:
    Teach_Con_Ver_YN.append(row)
#Number of respondents who answered that they taught controlling versions
Teach_Con_Ver_Y = Teach_Con_Ver_YN.count("Yes") 
print('The number of responents who said they taught controlling versions in the last undergraduate physics course they taught that utilized programming:', Teach_Con_Ver_Y)
#Proportion
Prop_Teach_Con_Ver_Y = Teach_Con_Ver_Y/(Teach_Con_Ver_Y+Teach_Con_Ver_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Con_Ver_Y)
# Out:
# The number of responents who said they taught controlling versions in the last undergraduate physics course they taught that utilized programming: 68
# Of those who responded, The proportion who said this is: 0.1111111111111111

# %%
Ans7 = ['Documenting Code', 'Debugging Code', 'Controlling Versions']
Tick7 = [1,2,3]
Ans7_dist = [Prop_Teach_Doc_Code_Y, Prop_Teach_Debug_Code_Y, Prop_Teach_Con_Ver_Y]
plt.xticks(Tick7, Ans7, rotation=45)
plt.bar(Tick7, Ans7_dist)
plt.title('Proportion of Coding Practices Taught')
plt.ylabel('Proportion')
plt.xlabel('Type of Coding Practice')

# %%
Non_Ans_7 = []
for row in data_uncleaned.values[:,41]:
    Non_Ans_7.append(row)
Non_Ans_7_num = 1246 - Non_Ans_7.count("Valid Skip") - Teach_Debug_Code_YN.count("Yes") - Teach_Debug_Code_YN.count("No")
print('The Number of non-responses for question 7 is:', Non_Ans_7_num)
Prop_Non_Ans_7 = Non_Ans_7_num/(1246 - Non_Ans_7.count("Valid Skip"))
print('The Proportion of non-responses for question 7 is:', Prop_Non_Ans_7)
# Out:
# The Number of non-responses for question 7 is: 117
# The Proportion of non-responses for question 7 is: 0.15579227696404793

# %% [markdown]
# ## Question 8

# %%
Soft_Access_YN = []
#Collumn AS
for row in data.values[:,44]:
    Soft_Access_YN.append(row)
#Number of respondents who answered that undergraduate students have access to university owned computational software
Soft_Access_Y = Soft_Access_YN.count("Yes") 
print('The number of responents who said that their institution allows undergraduate students access to university owned comutational software is:', Soft_Access_Y)
#Proportion
Prop_Soft_Access_Y = Soft_Access_Y/(Soft_Access_Y+Soft_Access_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Soft_Access_Y)
# Out:
# The number of responents who said that their institution allows undergraduate students access to university owned comutational software is: 594
# Of those who responded, The proportion who said this is: 0.911042944785276

# %%
Soft_Use_Course_Freq = []
#Collumn AT
for row in data.values[:,45]:
    Soft_Use_Course_Freq.append(row)
Soft_Use_Course_Never = Soft_Use_Course_Freq.count("Never")
Soft_Use_Course_Sometimes = Soft_Use_Course_Freq.count("Sometimes")
Soft_Use_Course_Often = Soft_Use_Course_Freq.count("Often")
Soft_Use_Course_Dist = [Soft_Use_Course_Never, Soft_Use_Course_Sometimes, Soft_Use_Course_Often]
print('The number of respondents who answered that students never utilize their access to university computing software for coursework is:', Soft_Use_Course_Dist[0])
print('The number of respondents who answered that students sometimes utilize their access to university computing software for coursework is:', Soft_Use_Course_Dist[1])
print('The number of respondents who answered that students  utilize their access to university computing software for coursework is:', Soft_Use_Course_Dist[2])
Prop_Soft_Use_Course_Dist = Soft_Use_Course_Dist/(np.sum(Soft_Use_Course_Dist))
print('The proportion of respondents who answered that students never utilize their access to university computing software for coursework is:', Prop_Soft_Use_Course_Dist[0])
print('The proportion of respondents who answered that students sometimes utilize their access to university computing software for coursework is:', Prop_Soft_Use_Course_Dist[1])
print('The proportion of respondents who answered that students often utilize their access to university computing software for coursework is:', Prop_Soft_Use_Course_Dist[2])
# Out:
# The number of respondents who answered that students never utilize their access to university computing software for coursework is: 17
# The number of respondents who answered that students sometimes utilize their access to university computing software for coursework is: 362
# The number of respondents who answered that students  utilize their access to university computing software for coursework is: 197
# The proportion of respondents who answered that students never utilize their access to university computing software for coursework is: 0.0295138888889
# The proportion of respondents who answered that students sometimes utilize their access to university computing software for coursework is: 0.628472222222
# The proportion of respondents who answered that students often utilize their access to university computing software for coursework is: 0.342013888889

# %%
Ans8a = ['Never', 'Sometimes', 'Often']
Tick8a = [1,2,3]
Ans8a_dist = Prop_Soft_Use_Course_Dist
plt.xticks(Tick8a, Ans8a, rotation=45)
plt.bar(Tick8a, Ans8a_dist)
plt.title('Frequency of Software Use in Coursework')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Soft_Use_Reas_Freq = []
#Collumn AU
for row in data.values[:,45]:
    Soft_Use_Reas_Freq.append(row)
Soft_Use_Reas_Never = Soft_Use_Reas_Freq.count("Never")
Soft_Use_Reas_Sometimes = Soft_Use_Reas_Freq.count("Sometimes")
Soft_Use_Reas_Often = Soft_Use_Reas_Freq.count("Often")
Soft_Use_Reas_Dist = [Soft_Use_Reas_Never, Soft_Use_Reas_Sometimes, Soft_Use_Reas_Often]
print('The number of respondents who answered that students never utilize their access to university computing software for research is:', Soft_Use_Reas_Dist[0])
print('The number of respondents who answered that students sometimes utilize their access to university computing software for research is:', Soft_Use_Reas_Dist[1])
print('The number of respondents who answered that students  utilize their access to university computing software for research is:', Soft_Use_Reas_Dist[2])
Prop_Soft_Use_Reas_Dist = Soft_Use_Reas_Dist/(np.sum(Soft_Use_Reas_Dist))
print('The proportion of respondents who answered that students never utilize their access to university computing software for research is:', Prop_Soft_Use_Reas_Dist[0])
print('The proportion of respondents who answered that students sometimes utilize their access to university computing software for research is:', Prop_Soft_Use_Reas_Dist[1])
print('The proportion of respondents who answered that students often utilize their access to university computing software for research is:', Prop_Soft_Use_Reas_Dist[2])
# Out:
# The number of respondents who answered that students never utilize their access to university computing software for research is: 17
# The number of respondents who answered that students sometimes utilize their access to university computing software for research is: 362
# The number of respondents who answered that students  utilize their access to university computing software for research is: 197
# The proportion of respondents who answered that students never utilize their access to university computing software for research is: 0.0295138888889
# The proportion of respondents who answered that students sometimes utilize their access to university computing software for research is: 0.628472222222
# The proportion of respondents who answered that students often utilize their access to university computing software for research is: 0.342013888889

# %%
Ans8b = ['Never', 'Sometimes', 'Often']
Tick8b = [1,2,3]
Ans8b_dist = Prop_Soft_Use_Reas_Dist
plt.xticks(Tick8b, Ans8b, rotation=45)
plt.bar(Tick8a, Ans8a_dist)
plt.title('Frequency of Software Use in Research')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Non_Ans_8 = []
for row in data_uncleaned.values[:,44]:
    Non_Ans_8.append(row)
Non_Ans_8_num = 1246 - Non_Ans_8.count("Valid Skip") - Soft_Access_YN.count("Yes") - Soft_Access_YN.count("No")
print('The Number of non-responses for question 8 is:', Non_Ans_8_num)
Prop_Non_Ans_8 = Non_Ans_8_num/(1246 - Non_Ans_8.count("Valid Skip"))
print('The Proportion of non-responses for question 8 is:', Prop_Non_Ans_8)
# Out:
# The Number of non-responses for question 8 is: 99
# The Proportion of non-responses for question 8 is: 0.1318242343541944

# %% [markdown]
# ## Question 9

# %%
HPC_Access_YN = []
#Collumn AV
for row in data.values[:,47]:
    HPC_Access_YN.append(row)
#Number of respondents who answered that undergraduate students have access to HPCs/supercomputing clusters
HPC_Access_Y = HPC_Access_YN.count("Yes") 
print('The number of responents who said that their institution allows undergraduate students access to HPCs is:', HPC_Access_Y)
#Proportion
Prop_HPC_Access_Y = HPC_Access_Y/(HPC_Access_Y+HPC_Access_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_HPC_Access_Y)
# Out:
# The number of responents who said that their institution allows undergraduate students access to HPCs is: 274
# Of those who responded, The proportion who said this is: 0.4261275272161742

# %%
HPC_Use_Course_Freq = []
#Collumn AW
for row in data.values[:,48]:
    HPC_Use_Course_Freq.append(row)
HPC_Use_Course_Never = HPC_Use_Course_Freq.count("Never")
HPC_Use_Course_Sometimes = HPC_Use_Course_Freq.count("Sometimes")
HPC_Use_Course_Often = HPC_Use_Course_Freq.count("Often")
HPC_Use_Course_Dist = [HPC_Use_Course_Never, HPC_Use_Course_Sometimes, HPC_Use_Course_Often]
print('The number of respondents who answered that students never utilize their access to HPCs for coursework is:', HPC_Use_Course_Dist[0])
print('The number of respondents who answered that students sometimes utilize their access to HPCs for coursework is:', HPC_Use_Course_Dist[1])
print('The number of respondents who answered that students  utilize their access to university HPCs coursework is:', HPC_Use_Course_Dist[2])
Prop_HPC_Use_Course_Dist = HPC_Use_Course_Dist/(np.sum(HPC_Use_Course_Dist))
print('The proportion of respondents who answered that students never utilize their access to HPCs for coursework is:', Prop_HPC_Use_Course_Dist[0])
print('The proportion of respondents who answered that students sometimes utilize their access to HPCs for coursework is:', Prop_HPC_Use_Course_Dist[1])
print('The proportion of respondents who answered that students often utilize their access to HPCs for coursework is:', Prop_HPC_Use_Course_Dist[2])
# Out:
# The number of respondents who answered that students never utilize their access to HPCs for coursework is: 118
# The number of respondents who answered that students sometimes utilize their access to HPCs for coursework is: 142
# The number of respondents who answered that students  utilize their access to university HPCs coursework is: 10
# The proportion of respondents who answered that students never utilize their access to HPCs for coursework is: 0.437037037037
# The proportion of respondents who answered that students sometimes utilize their access to HPCs for coursework is: 0.525925925926
# The proportion of respondents who answered that students often utilize their access to HPCs for coursework is: 0.037037037037

# %%
Ans9a = ['Never', 'Sometimes', 'Often']
Tick9a = [1,2,3]
Ans9a_dist = Prop_HPC_Use_Course_Dist
plt.xticks(Tick9a, Ans9a, rotation=45)
plt.bar(Tick9a, Ans9a_dist)
plt.title('Frequency of HPC Use in Coursework')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
HPC_Use_Reas_Freq = []
#Collumn AX
for row in data.values[:,49]:
    HPC_Use_Reas_Freq.append(row)
HPC_Use_Reas_Never = HPC_Use_Reas_Freq.count("Never")
HPC_Use_Reas_Sometimes = HPC_Use_Reas_Freq.count("Sometimes")
HPC_Use_Reas_Often = HPC_Use_Reas_Freq.count("Often")
HPC_Use_Reas_Dist = [HPC_Use_Reas_Never, HPC_Use_Reas_Sometimes, HPC_Use_Reas_Often]
print('The number of respondents who answered that students never utilize their access to HPCs for research is:', HPC_Use_Reas_Dist[0])
print('The number of respondents who answered that students sometimes utilize their access to HPCs for research is:', HPC_Use_Reas_Dist[1])
print('The number of respondents who answered that students  utilize their access to university HPCs research is:', HPC_Use_Reas_Dist[2])
Prop_HPC_Use_Reas_Dist = HPC_Use_Reas_Dist/(np.sum(HPC_Use_Reas_Dist))
print('The proportion of respondents who answered that students never utilize their access to HPCs for research is:', Prop_HPC_Use_Reas_Dist[0])
print('The proportion of respondents who answered that students sometimes utilize their access to HPCs for research is:', Prop_HPC_Use_Reas_Dist[1])
print('The proportion of respondents who answered that students often utilize their access to HPCs for research is:', Prop_HPC_Use_Reas_Dist[2])
# Out:
# The number of respondents who answered that students never utilize their access to HPCs for research is: 16
# The number of respondents who answered that students sometimes utilize their access to HPCs for research is: 211
# The number of respondents who answered that students  utilize their access to university HPCs research is: 41
# The proportion of respondents who answered that students never utilize their access to HPCs for research is: 0.0597014925373
# The proportion of respondents who answered that students sometimes utilize their access to HPCs for research is: 0.787313432836
# The proportion of respondents who answered that students often utilize their access to HPCs for research is: 0.152985074627

# %%
Ans9b = ['Never', 'Sometimes', 'Often']
Tick9b = [1,2,3]
Ans9b_dist = Prop_HPC_Use_Reas_Dist
plt.xticks(Tick9b, Ans9b, rotation=45)
plt.bar(Tick9b, Ans9b_dist)
plt.title('Frequency of HPC Use in Research')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Non_Ans_9 = []
for row in data_uncleaned.values[:,47]:
    Non_Ans_9.append(row)
Non_Ans_9_num = 1246 - Non_Ans_9.count("Valid Skip") - HPC_Access_YN.count("Yes") - HPC_Access_YN.count("No")
print('The Number of non-responses for question 9 is:', Non_Ans_9_num)
Prop_Non_Ans_9 = Non_Ans_9_num/(1246 - Non_Ans_9.count("Valid Skip"))
print('The Proportion of non-responses for question 9 is:', Prop_Non_Ans_9)
# Out:
# The Number of non-responses for question 9 is: 108
# The Proportion of non-responses for question 9 is: 0.14380825565912117

# %% [markdown]
# ## Question 10

# %%
Teach_Use_Script_Freq = []
#Collumn AY
for row in data.values[:,50]:
    Teach_Use_Script_Freq.append(row)
#Number of responents who used scripting languages such as Python in the last class they taught
Teach_Use_Script_Not = Teach_Use_Script_Freq.count("Not used at all")
Teach_Use_Script_Rare = Teach_Use_Script_Freq.count("Used rarely")
Teach_Use_Script_Sometimes = Teach_Use_Script_Freq.count("Used sometimes")
Teach_Use_Script_Often = Teach_Use_Script_Freq.count("Used often")
Teach_Use_Script_Dist = [Teach_Use_Script_Not, Teach_Use_Script_Rare, Teach_Use_Script_Sometimes, Teach_Use_Script_Often]
print('The number of respondents who answered that they do not use scripting languages in courses is:', Teach_Use_Script_Dist[0])
print('The number of respondents who answered that they rarely use scripting languages in courses is:', Teach_Use_Script_Dist[1])
print('The number of respondents who answered that they sometimes use scripting languages in courses is:', Teach_Use_Script_Dist[2])
print('The number of respondents who answered that they often use scripting languages in courses is:', Teach_Use_Script_Dist[3])
Prop_Teach_Use_Script_Dist = Teach_Use_Script_Dist/(np.sum(Teach_Use_Script_Dist))
print('The proportion of respondents who answered that they do not use scripting languages in courses is:', Prop_Teach_Use_Script_Dist[0])
print('The proportion of respondents who answered that they rarely use scripting languages in courses is:', Prop_Teach_Use_Script_Dist[1])
print('The proportion of respondents who answered that they sometimes use scripting languages in courses is:', Prop_Teach_Use_Script_Dist[2])
print('The proportion of respondents who answered that they often use scripting languages in courses is:', Prop_Teach_Use_Script_Dist[3])
# Out:
# The number of respondents who answered that they do not use scripting languages in courses is: 218
# The number of respondents who answered that they rarely use scripting languages in courses is: 105
# The number of respondents who answered that they sometimes use scripting languages in courses is: 160
# The number of respondents who answered that they often use scripting languages in courses is: 114
# The proportion of respondents who answered that they do not use scripting languages in courses is: 0.365159128978
# The proportion of respondents who answered that they rarely use scripting languages in courses is: 0.175879396985
# The proportion of respondents who answered that they sometimes use scripting languages in courses is: 0.268006700168
# The proportion of respondents who answered that they often use scripting languages in courses is: 0.190954773869

# %%
Ans10a = ['Not Used at All', 'Used Rarely', 'Used Sometimes', 'Used Often']
Tick10a = [1,2,3,4]
Ans10a_dist = Prop_Teach_Use_Script_Dist
plt.xticks(Tick10a, Ans10a, rotation=45)
plt.bar(Tick10a, Ans10a_dist)
plt.title('Frequency of Scripting Languages Used in Teaching')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Teach_Use_Comp_Freq = []
#Collumn AZ
for row in data.values[:,51]:
    Teach_Use_Comp_Freq.append(row)
#Number of responents who used compiled languages such as C++ in the last class they taught
Teach_Use_Comp_Not = Teach_Use_Comp_Freq.count("Not used at all")
Teach_Use_Comp_Rare = Teach_Use_Comp_Freq.count("Used rarely")
Teach_Use_Comp_Sometimes = Teach_Use_Comp_Freq.count("Used sometimes")
Teach_Use_Comp_Often = Teach_Use_Comp_Freq.count("Used often")
Teach_Use_Comp_Dist = [Teach_Use_Comp_Not, Teach_Use_Comp_Rare, Teach_Use_Comp_Sometimes, Teach_Use_Comp_Often]
print('The number of respondents who answered that they do not use compiled languages in courses is:', Teach_Use_Comp_Dist[0])
print('The number of respondents who answered that they rarely use compiled languages in courses is:', Teach_Use_Comp_Dist[1])
print('The number of respondents who answered that they sometimes use compiled languages in courses is:', Teach_Use_Comp_Dist[2])
print('The number of respondents who answered that they often use compiled languages in courses is:', Teach_Use_Comp_Dist[3])
Prop_Teach_Use_Comp_Dist = Teach_Use_Comp_Dist/(np.sum(Teach_Use_Comp_Dist))
print('The proportion of respondents who answered that they do not use compiled languages in courses is:', Prop_Teach_Use_Comp_Dist[0])
print('The proportion of respondents who answered that they rarely use compiled languages in courses is:', Prop_Teach_Use_Comp_Dist[1])
print('The proportion of respondents who answered that they sometimes use compiled languages in courses is:', Prop_Teach_Use_Comp_Dist[2])
print('The proportion of respondents who answered that they often use compiled languages in courses is:', Prop_Teach_Use_Comp_Dist[3])
# Out:
# The number of respondents who answered that they do not use compiled languages in courses is: 251
# The number of respondents who answered that they rarely use compiled languages in courses is: 136
# The number of respondents who answered that they sometimes use compiled languages in courses is: 140
# The number of respondents who answered that they often use compiled languages in courses is: 62
# The proportion of respondents who answered that they do not use compiled languages in courses is: 0.426146010187
# The proportion of respondents who answered that they rarely use compiled languages in courses is: 0.230899830221
# The proportion of respondents who answered that they sometimes use compiled languages in courses is: 0.237691001698
# The proportion of respondents who answered that they often use compiled languages in courses is: 0.105263157895

# %%
Ans10b = ['Not Used at All', 'Used Rarely', 'Used Sometimes', 'Used Often']
Tick10b = [1,2,3,4]
Ans10b_dist = Prop_Teach_Use_Comp_Dist
plt.xticks(Tick10b, Ans10b, rotation=45)
plt.bar(Tick10b, Ans10b_dist)
plt.title('Frequency of Compiled Languages Used in Teaching')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Teach_Use_Excel_Freq = []
#Collumn BA
for row in data.values[:,52]:
    Teach_Use_Excel_Freq.append(row)
#Number of responents who used Excel/Spreadsheets in the last class they taught
Teach_Use_Excel_Not = Teach_Use_Excel_Freq.count("Not used at all")
Teach_Use_Excel_Rare = Teach_Use_Excel_Freq.count("Used rarely")
Teach_Use_Excel_Sometimes = Teach_Use_Excel_Freq.count("Used sometimes")
Teach_Use_Excel_Often = Teach_Use_Excel_Freq.count("Used often")
Teach_Use_Excel_Dist = [Teach_Use_Excel_Not, Teach_Use_Excel_Rare, Teach_Use_Excel_Sometimes, Teach_Use_Excel_Often]
print('The number of respondents who answered that they do not use Excel in courses is:', Teach_Use_Excel_Dist[0])
print('The number of respondents who answered that they rarely use Excel in courses is:', Teach_Use_Excel_Dist[1])
print('The number of respondents who answered that they sometimes use Excel in courses is:', Teach_Use_Excel_Dist[2])
print('The number of respondents who answered that they often use Excel in courses is:', Teach_Use_Excel_Dist[3])
Prop_Teach_Use_Excel_Dist = Teach_Use_Excel_Dist/(np.sum(Teach_Use_Excel_Dist))
print('The proportion of respondents who answered that they do not use Excel in courses is:', Prop_Teach_Use_Excel_Dist[0])
print('The proportion of respondents who answered that they rarely use Excel in courses is:', Prop_Teach_Use_Excel_Dist[1])
print('The proportion of respondents who answered that they sometimes use Excel in courses is:', Prop_Teach_Use_Excel_Dist[2])
print('The proportion of respondents who answered that they often use Excel in courses is:', Prop_Teach_Use_Excel_Dist[3])
# Out:
# The number of respondents who answered that they do not use Excel in courses is: 101
# The number of respondents who answered that they rarely use Excel in courses is: 96
# The number of respondents who answered that they sometimes use Excel in courses is: 211
# The number of respondents who answered that they often use Excel in courses is: 194
# The proportion of respondents who answered that they do not use Excel in courses is: 0.167774086379
# The proportion of respondents who answered that they rarely use Excel in courses is: 0.159468438538
# The proportion of respondents who answered that they sometimes use Excel in courses is: 0.35049833887
# The proportion of respondents who answered that they often use Excel in courses is: 0.322259136213

# %%
Ans10c = ['Not Used at All', 'Used Rarely', 'Used Sometimes', 'Used Often']
Tick10c = [1,2,3,4]
Ans10c_dist = Prop_Teach_Use_Excel_Dist
plt.xticks(Tick10c, Ans10c, rotation=45)
plt.bar(Tick10b, Ans10c_dist)
plt.title('Frequency of Excel Used in Teaching')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Teach_Use_Envir_Freq = []
#Collumn BB
for row in data.values[:,53]:
    Teach_Use_Envir_Freq.append(row)
#Number of responents who used computing envirnments such as Matlab in the last class they taught
Teach_Use_Envir_Not = Teach_Use_Envir_Freq.count("Not used at all")
Teach_Use_Envir_Rare = Teach_Use_Envir_Freq.count("Used rarely")
Teach_Use_Envir_Sometimes = Teach_Use_Envir_Freq.count("Used sometimes")
Teach_Use_Envir_Often = Teach_Use_Envir_Freq.count("Used often")
Teach_Use_Envir_Dist = [Teach_Use_Envir_Not, Teach_Use_Envir_Rare, Teach_Use_Envir_Sometimes, Teach_Use_Envir_Often]
print('The number of respondents who answered that they do not use computing envirnments in courses is:', Teach_Use_Envir_Dist[0])
print('The number of respondents who answered that they rarely use computing envirnments in courses is:', Teach_Use_Envir_Dist[1])
print('The number of respondents who answered that they sometimes use computing envirnments in courses is:', Teach_Use_Envir_Dist[2])
print('The number of respondents who answered that they often use computing envirnments in courses is:', Teach_Use_Envir_Dist[3])
Prop_Teach_Use_Envir_Dist = Teach_Use_Envir_Dist/(np.sum(Teach_Use_Envir_Dist))
print('The proportion of respondents who answered that they do not use computing envirnments in courses is:', Prop_Teach_Use_Envir_Dist[0])
print('The proportion of respondents who answered that they rarely use computing envirnments in courses is:', Prop_Teach_Use_Envir_Dist[1])
print('The proportion of respondents who answered that they sometimes use computing envirnments compiled in courses is:', Prop_Teach_Use_Envir_Dist[2])
print('The proportion of respondents who answered that they often use computing envirnments in courses is:', Prop_Teach_Use_Envir_Dist[3])
# Out:
# The number of respondents who answered that they do not use computing envirnments in courses is: 102
# The number of respondents who answered that they rarely use computing envirnments in courses is: 64
# The number of respondents who answered that they sometimes use computing envirnments in courses is: 220
# The number of respondents who answered that they often use computing envirnments in courses is: 223
# The proportion of respondents who answered that they do not use computing envirnments in courses is: 0.167487684729
# The proportion of respondents who answered that they rarely use computing envirnments in courses is: 0.105090311987
# The proportion of respondents who answered that they sometimes use computing envirnments compiled in courses is: 0.361247947455
# The proportion of respondents who answered that they often use computing envirnments in courses is: 0.366174055829

# %%
Ans10d = ['Not Used at All', 'Used Rarely', 'Used Sometimes', 'Used Often']
Tick10d = [1,2,3,4]
Ans10d_dist = Prop_Teach_Use_Envir_Dist
plt.xticks(Tick10d, Ans10d, rotation=45)
plt.bar(Tick10d, Ans10d_dist)
plt.title('Frequency of Computing Envirnments Used in Teaching')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %%
Teach_Use_Other_Freq = []
#Collumn BC
for row in data.values[:,54]:
    Teach_Use_Other_Freq.append(row)
#Number of responents who used some other program in the last class they taught
Teach_Use_Other_Not = Teach_Use_Other_Freq.count("Not used at all")
Teach_Use_Other_Rare = Teach_Use_Other_Freq.count("Used rarely")
Teach_Use_Other_Sometimes = Teach_Use_Other_Freq.count("Used sometimes")
Teach_Use_Other_Often = Teach_Use_Other_Freq.count("Used often")
Teach_Use_Other_Dist = [Teach_Use_Other_Not, Teach_Use_Other_Rare, Teach_Use_Other_Sometimes, Teach_Use_Other_Often]
print('The number of respondents who answered that they do not use some other program in courses is:', Teach_Use_Other_Dist[0])
print('The number of respondents who answered that they rarely use some other program in courses is:', Teach_Use_Other_Dist[1])
print('The number of respondents who answered that they sometimes use some other program in courses is:', Teach_Use_Other_Dist[2])
print('The number of respondents who answered that they often use some other program in courses is:', Teach_Use_Other_Dist[3])
Prop_Teach_Use_Other_Dist = Teach_Use_Other_Dist/(np.sum(Teach_Use_Other_Dist))
print('The proportion of respondents who answered that they do not use some other program in courses is:', Prop_Teach_Use_Other_Dist[0])
print('The proportion of respondents who answered that they rarely use some other program in courses is:', Prop_Teach_Use_Other_Dist[1])
print('The proportion of respondents who answered that they sometimes use some other program in courses is:', Prop_Teach_Use_Other_Dist[2])
print('The proportion of respondents who answered that they often use some other program in courses is:', Prop_Teach_Use_Other_Dist[3])
# Out:
# The number of respondents who answered that they do not use some other program in courses is: 56
# The number of respondents who answered that they rarely use some other program in courses is: 5
# The number of respondents who answered that they sometimes use some other program in courses is: 28
# The number of respondents who answered that they often use some other program in courses is: 25
# The proportion of respondents who answered that they do not use some other program in courses is: 0.491228070175
# The proportion of respondents who answered that they rarely use some other program in courses is: 0.0438596491228
# The proportion of respondents who answered that they sometimes use some other program in courses is: 0.245614035088
# The proportion of respondents who answered that they often use some other program in courses is: 0.219298245614

# %%
Ans10e = ['Not Used at All', 'Used Rarely', 'Used Sometimes', 'Used Often']
Tick10e = [1,2,3,4]
Ans10e_dist = Prop_Teach_Use_Other_Dist
plt.xticks(Tick10e, Ans10e, rotation=45)
plt.bar(Tick10e, Ans10e_dist)
plt.title('Frequency of Some other Program Used in Teaching')
plt.ylabel('Proportion')
plt.xlabel('Frequency')

# %% [markdown]
# ### NON-RESONSE MUST BE DONE FOR EACH INDIVIDUAL QUESTION, DO THIS LATER

# %% [markdown]
# ## Question 11
# Does your university/college/department have a site license for

# %%
# Column BE column 56 Matlab
Site_License_Matlab = []
for row in data.values[:,56]:
    Site_License_Matlab.append(row)
Site_License_Matlab_Y = Site_License_Matlab.count("Yes")
Percentage_Site_License_Matlab=100*Site_License_Matlab_Y/(Site_License_Matlab_Y+Site_License_Matlab.count("No"))
print("Of the",Site_License_Matlab_Y+Site_License_Matlab.count("No"),"people who answered this question",Percentage_Site_License_Matlab,"percent said the university has a site license for Matlab. That is",Site_License_Matlab_Y,"people.")
x=[1,2]
y=[Site_License_Matlab_Y,Site_License_Matlab.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('University has Site Liscense for Matlab?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 526 people who answered this question 82.12927756653993 percent said the university has a site license for Matlab. That is 432 people.
# ([<matplotlib.axis.XTick at 0xaf178d0>, <matplotlib.axis.XTick at 0xaf25e10>],
#  <a list of 2 Text xticklabel objects>)

# %%
# Column BF column 57 Mathematica
Site_License_Mathematica = []
for row in data.values[:,57]:
    Site_License_Mathematica.append(row)
Site_License_Mathematica_Y = Site_License_Mathematica.count("Yes")
Percentage_Site_License_Mathematica=100*Site_License_Mathematica_Y/(Site_License_Mathematica_Y+Site_License_Mathematica.count("No"))
print("Of the",Site_License_Mathematica_Y+Site_License_Mathematica.count("No"),"people who answered this question",Percentage_Site_License_Mathematica,"percent said the university has a site license for Mathematica. That is",Site_License_Mathematica_Y,"people.")
x=[1,2]
y=[Site_License_Mathematica_Y,Site_License_Mathematica.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('University has Site Liscense for Mathematica?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 538 people who answered this question 81.04089219330855 percent said the university has a site license for Mathematica. That is 436 people.
# ([<matplotlib.axis.XTick at 0xb03ada0>, <matplotlib.axis.XTick at 0xac392b0>],
#  <a list of 2 Text xticklabel objects>)

# %%
# Column BG column 58 Maple
Site_License_Maple = []
for row in data.values[:,58]:
    Site_License_Maple.append(row)
Site_License_Maple_Y = Site_License_Maple.count("Yes")
Percentage_Site_License_Maple=100*Site_License_Maple_Y/(Site_License_Maple_Y+Site_License_Maple.count("No"))
print("Of the",Site_License_Maple_Y+Site_License_Maple.count("No"),"people who answered this question",Percentage_Site_License_Maple,"percent said the university has a site license for Maple. That is",Site_License_Maple_Y,"people.")
x=[1,2]
y=[Site_License_Maple_Y,Site_License_Maple.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('University has Site Liscense for Maple?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 335 people who answered this question 44.17910447761194 percent said the university has a site license for Maple. That is 148 people.
# ([<matplotlib.axis.XTick at 0xb0b59e8>, <matplotlib.axis.XTick at 0xb07c2b0>],
#  <a list of 2 Text xticklabel objects>)

# %%
# Column BH column 59 Other
Site_License_Other = []
for row in data.values[:,59]:
    Site_License_Other.append(row)
Site_License_Other_Y = Site_License_Other.count("Yes")
Percentage_Site_License_Other=100*Site_License_Other_Y/(Site_License_Other_Y+Site_License_Other.count("No"))
print("Of the",Site_License_Other_Y+Site_License_Other.count("No"),"people who answered this question",Percentage_Site_License_Other,"percent said the university has a site license for something otherthan the options listed. That is",Site_License_Other_Y,"people.")
x=[1,2]
y=[Site_License_Other_Y,Site_License_Other.count("No")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('University has Site Liscense for something else?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#Matlab
Percentage_Site_License_Matlab
#Mathematica
Percentage_Site_License_Mathematica
#Maple
Percentage_Site_License_Maple
#Other
Percentage_Site_License_Other
x=[1,2,3,4]
y=[Percentage_Site_License_Matlab,Percentage_Site_License_Mathematica,Percentage_Site_License_Maple,Percentage_Site_License_Other]
fig=plt.figure(figsize=(10,6))
plt.bar(x,y,width=.5)
labels=['Matlab','Mathematica','Maple','Other']
plt.xticks(x,labels)
plt.title('Percentage that have a site license of the Ones that answered')
plt.ylabel('Percentage out of 100')

# %% [markdown]
# ## Question 13
# In your department, how well supported is computation by:
# Question 12 isleft out because it is free response.

# %%
# Column BK column 62 The university administration
Supported_University_Administration = []
for row in data.values[:,62]:
    Supported_University_Administration.append(row)
Supported_University_Administration_Very_Strong = Supported_University_Administration.count("Very strongly supported")
Supported_University_Administration_Strong= Supported_University_Administration.count("Strongly supported")
Supported_University_Administration_Somewhat= Supported_University_Administration.count("Somewhat supported")
Supported_University_Administration_Not= Supported_University_Administration.count("Not supported")
Supported_University_Administration_Unknown= Supported_University_Administration.count("I don't know")
Answered=Supported_University_Administration_Very_Strong+Supported_University_Administration_Strong+Supported_University_Administration_Somewhat+Supported_University_Administration_Not+Supported_University_Administration_Unknown
print(Answered,'This many people answered the question')
x=[1,2,3,4,5]
y=[Supported_University_Administration_Very_Strong,Supported_University_Administration_Strong,Supported_University_Administration_Somewhat,Supported_University_Administration_Not,Supported_University_Administration_Unknown]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Support by university administration for computation')
labels=['Supported University Administration Very Strong','Supported University Administration Strong','Supported University Administration Somewhat','Supported University Administration Not','Supported University Administration Unknown']
plt.xticks(x,labels,rotation=25)

# %%
# Column BL column 63 The department administration
Supported_department_Administration = []
for row in data.values[:,63]:
    Supported_department_Administration.append(row)
Supported_department_Administration_Very_Strong = Supported_department_Administration.count("Very strongly supported")
Supported_department_Administration_Strong= Supported_department_Administration.count("Strongly supported")
Supported_department_Administration_Somewhat= Supported_department_Administration.count("Somewhat supported")
Supported_department_Administration_Not= Supported_department_Administration.count("Not supported")
Supported_department_Administration_Unknown= Supported_department_Administration.count("I don't know")
Answered_2=Supported_department_Administration_Very_Strong+Supported_department_Administration_Strong+Supported_department_Administration_Somewhat+Supported_department_Administration_Not+Supported_department_Administration_Unknown
print(Answered_2,'This many people answered the question')
x=[1,2,3,4,5]
y=[Supported_department_Administration_Very_Strong,Supported_department_Administration_Strong,Supported_department_Administration_Somewhat,Supported_department_Administration_Not,Supported_department_Administration_Unknown]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Support by department administration for computation')
labels=['Supported department Administration Very Strong','Supported department Administration Strong','Supported department Administration Somewhat','Supported department Administration Not','Supported department Administration Unknown']
plt.xticks(x,labels,rotation=25)

# %%
# Column BM column 64 Physics faculty members
Supported_Faculty = []
for row in data.values[:,64]:
    Supported_Faculty.append(row)
Supported_Faculty_Very_Strong = Supported_Faculty.count("Very strongly supported")
Supported_Faculty_Strong= Supported_Faculty.count("Strongly supported")
Supported_Faculty_Somewhat= Supported_Faculty.count("Somewhat supported")
Supported_Faculty_Not= Supported_Faculty.count("Not supported")
Supported_Faculty_Unknown= Supported_Faculty.count("I don't know")
Answered_3=Supported_Faculty_Very_Strong+Supported_Faculty_Strong+Supported_Faculty_Somewhat+Supported_Faculty_Not+Supported_Faculty_Unknown
print(Answered_3,'This many people answered the question')
x=[1,2,3,4,5]
y=[Supported_Faculty_Very_Strong,Supported_Faculty_Strong,Supported_Faculty_Somewhat,Supported_Faculty_Not,Supported_Faculty_Unknown]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Support by faculty for computation')
labels=['Supported by faculty Very Strong','Supported by faculty Strong','Supported by faculty Somewhat','Supported by faculty Not','Supported by faculty Unknown']
plt.xticks(x,labels,rotation=25)

# %% [markdown]
# ## Question 14

# %%
Fac_Time_Dev_YN = []
#Collumn BN
for row in data.values[:,65]:
    Fac_Time_Dev_YN.append(row)
#Number of respondents who answered that their institution gives faculty release time to devolop or enhance the use of computational modeling in undergraduate courses
Fac_Time_Dev_Y = Fac_Time_Dev_YN.count("Checked") 
print('The number of responents who said thier institution gives falcuty release time to develop computing uses in courses is:', Fac_Time_Dev_Y)
#Proportion
Prop_Fac_Time_Dev_Y = Fac_Time_Dev_Y/(Fac_Time_Dev_Y+Fac_Time_Dev_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Fac_Time_Dev_Y)
# Out:
# The number of responents who said thier institution gives falcuty release time to develop computing uses in courses is: 54
# Of those who responded, The proportion who said this is: 0.08809135399673736

# %%
Fac_Stip_Dev_YN = []
#Collumn BO
for row in data.values[:,66]:
    Fac_Stip_Dev_YN.append(row)
#Number of respondents who answered that their institution gives faculty a stipend to devolop or enhance the use of computational modeling in undergraduate courses
Fac_Stip_Dev_Y = Fac_Stip_Dev_YN.count("Checked") 
print('The number of responents who said thier institution gives falcuty a stipend to develop computing uses in courses is:', Fac_Stip_Dev_Y)
#Proportion
Prop_Fac_Stip_Dev_Y = Fac_Stip_Dev_Y/(Fac_Stip_Dev_Y+Fac_Stip_Dev_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Fac_Stip_Dev_Y)
# Out:
# The number of responents who said thier institution gives falcuty a stipend to develop computing uses in courses is: 36
# Of those who responded, The proportion who said this is: 0.058919803600654665

# %%
TA_Comp_YN = []
#Collumn BP
for row in data.values[:,67]:
    TA_Comp_YN.append(row)
#Number of respondents who answered that their institution utilizes TAs to teach of computational modeling in undergraduate courses
TA_Comp_Y = TA_Comp_YN.count("Checked") 
print('The number of responents who said thier institution utilizes TAs to teach of computational modeling in undergraduate courses is:', TA_Comp_Y)
#Proportion
Prop_TA_Comp_Y = TA_Comp_Y/(TA_Comp_Y+TA_Comp_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_TA_Comp_Y)
# Out:
# The number of responents who said thier institution utilizes TAs to teach of computational modeling in undergraduate courses is: 62
# Of those who responded, The proportion who said this is: 0.10147299509001637

# %%
Fac_Dis_YN = []
#Collumn BQ
for row in data.values[:,68]:
    Fac_Dis_YN.append(row)
#Number of respondents who answered that their institution discourages the use of computational modeling in undergraduate courses
Fac_Dis_Y = Fac_Dis_YN.count("Checked") 
print('The number of responents who said thier institution discourages the use of computational modeling in undergraduate courses is:', Fac_Dis_Y)
#Proportion
Prop_Fac_Dis_Y = Fac_Dis_Y/(Fac_Dis_Y+Fac_Dis_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Fac_Dis_Y)
# Out:
# The number of responents who said thier institution discourages the use of computational modeling in undergraduate courses is: 6
# Of those who responded, The proportion who said this is: 0.009819967266775777

# %%
Dep_Apa_YN = []
#Collumn BR
for row in data.values[:,69]:
    Dep_Apa_YN.append(row)
#Number of respondents who answered that their institution is apathetic about computational modeling
Dep_Apa_Y = Dep_Apa_YN.count("Checked") 
print('The number of responents who said thier institution is apathetic about computational modeling is:', Dep_Apa_Y)
#Proportion
Prop_Dep_Apa_Y = Dep_Apa_Y/(Dep_Apa_Y+Dep_Apa_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Dep_Apa_Y)
# Out:
# The number of responents who said thier institution is apathetic about computational modeling is: 145
# Of those who responded, The proportion who said this is: 0.23731587561374795

# %%
Ans14 = ['Time Release', 'Stipend Given', 'TAs Used', 'Discouraged', 'Apathetic']
Tick14 = [1,2,3,4,5]
Ans14_dist = [Prop_Fac_Time_Dev_Y, Prop_Fac_Stip_Dev_Y, Prop_TA_Comp_Y, Prop_Fac_Dis_Y, Prop_Dep_Apa_Y]
plt.xticks(Tick14, Ans14, rotation=45)
plt.bar(Tick14, Ans14_dist)
plt.title('Distribution of Departnmental Approach Towards Computing')
plt.ylabel('Proportion')
plt.xlabel('Approach')

# %%
Non_Ans_14 = []
for row in data_uncleaned.values[:,65]:
    Non_Ans_14.append(row)
Non_Ans_14_num = 1246 - Non_Ans_14.count("Valid Skip") - Fac_Time_Dev_YN.count("Checked") - Fac_Time_Dev_YN.count("Unchecked")
print('The Number of non-responses for question 14 is:', Non_Ans_14_num)
Prop_Non_Ans_14 = Non_Ans_9_num/(1246 - Non_Ans_14.count("Valid Skip"))
print('The Proportion of non-responses for question 14 is:', Prop_Non_Ans_14)
# Out:
# The Number of non-responses for question 14 is: 138
# The Proportion of non-responses for question 14 is: 0.14380825565912117

# %% [markdown]
# ## Question 15
# Which of the following resources are provided by your institution to support faculty to include computational physics in your undergraduate curriculum?

# %%
#This is for column BS 70 Access to a lab
Resource_Provided_Lab_Access = []
for row in data.values[:,70]:
    Resource_Provided_Lab_Access.append(row)
Resource_Provided_Lab_Access_Y = Resource_Provided_Lab_Access.count("Checked") 
Percentage_Resource_Provided_Lab_Access=100*Resource_Provided_Lab_Access_Y/(Resource_Provided_Lab_Access_Y+Resource_Provided_Lab_Access.count("Unchecked"))
print("Of the",Resource_Provided_Lab_Access_Y+Resource_Provided_Lab_Access.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Lab_Access,"percent said they have lab access provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Lab_Access_Y,"people.")
x=[1,2]
y=[Resource_Provided_Lab_Access_Y,Resource_Provided_Lab_Access.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Lab?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 30.528052805280527 percent said they have lab access provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 185 people.
# ([<matplotlib.axis.XTick at 0xb13a0b8>, <matplotlib.axis.XTick at 0xb148be0>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BT 71 Access to specialized software
Resource_Provided_Software = []
for row in data.values[:,71]:
    Resource_Provided_Software.append(row)
Resource_Provided_Software_Y = Resource_Provided_Software.count("Checked") 
Percentage_Resource_Provided_Software=100*Resource_Provided_Software_Y/(Resource_Provided_Software_Y+Resource_Provided_Software.count("Unchecked"))
print("Of the",Resource_Provided_Software_Y+Resource_Provided_Software.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Software,"percent said they have specialized software provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Software_Y,"people.")
x=[1,2]
y=[Resource_Provided_Software_Y,Resource_Provided_Software.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Software?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 70.95709570957095 percent said they have specialized software provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 430 people.
# ([<matplotlib.axis.XTick at 0xae0a278>, <matplotlib.axis.XTick at 0xafaf6a0>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BU 72 Access to specialized hardware
Resource_Provided_Hardware = []
for row in data.values[:,72]:
    Resource_Provided_Hardware.append(row)
Resource_Provided_Hardware_Y = Resource_Provided_Hardware.count("Checked") 
Percentage_Resource_Provided_Hardware=100*Resource_Provided_Hardware_Y/(Resource_Provided_Hardware_Y+Resource_Provided_Hardware.count("Unchecked"))
print("Of the",Resource_Provided_Hardware_Y+Resource_Provided_Hardware.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Hardware,"percent said they have specialized hardware provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Hardware_Y,"people.")
x=[1,2]
y=[Resource_Provided_Hardware_Y,Resource_Provided_Hardware.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Hardware?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 29.372937293729372 percent said they have specialized hardware provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 178 people.
# ([<matplotlib.axis.XTick at 0xb24e710>, <matplotlib.axis.XTick at 0xb23e6d8>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BV 73 Additional research funds
Resource_Provided_Research_Funds = []
for row in data.values[:,73]:
    Resource_Provided_Research_Funds.append(row)
Resource_Provided_Research_Funds_Y = Resource_Provided_Research_Funds.count("Checked") 
Percentage_Resource_Provided_Research_Funds=100*Resource_Provided_Research_Funds_Y/(Resource_Provided_Research_Funds_Y+Resource_Provided_Research_Funds.count("Unchecked"))
print("Of the",Resource_Provided_Research_Funds_Y+Resource_Provided_Research_Funds.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Research_Funds,"percent said they have research funds provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Research_Funds_Y,"people.")
x=[1,2]
y=[Resource_Provided_Research_Funds_Y,Resource_Provided_Research_Funds.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Research Funds?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 9.405940594059405 percent said they have research funds provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 57 people.
# ([<matplotlib.axis.XTick at 0xb2fe208>, <matplotlib.axis.XTick at 0xb2c0358>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BW 74 Release time to learn new computer methods and/or tools
Resource_Provided_Release_Time_Methods = []
for row in data.values[:,74]:
    Resource_Provided_Release_Time_Methods.append(row)
Resource_Provided_Release_Time_Methods_Y = Resource_Provided_Release_Time_Methods.count("Checked") 
Percentage_Resource_Provided_Release_Time_Methods=100*Resource_Provided_Release_Time_Methods_Y/(Resource_Provided_Release_Time_Methods_Y+Resource_Provided_Release_Time_Methods.count("Unchecked"))
print("Of the",Resource_Provided_Release_Time_Methods_Y+Resource_Provided_Release_Time_Methods.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Release_Time_Methods,"percent said they have release time to learn computer methods provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Release_Time_Methods_Y,"people.")
x=[1,2]
y=[Resource_Provided_Release_Time_Methods_Y,Resource_Provided_Release_Time_Methods.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Release Time to Learn Computer Methods?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 1.4851485148514851 percent said they have release time to learn computer methods provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 9 people.
# ([<matplotlib.axis.XTick at 0xb3607f0>, <matplotlib.axis.XTick at 0xb1be278>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BX 75 Training on integrating computational physics in the curriculum
Resource_Provided_Training = []
for row in data.values[:,75]:
    Resource_Provided_Training.append(row)
Resource_Provided_Training_Y = Resource_Provided_Training.count("Checked") 
Percentage_Resource_Provided_Training=100*Resource_Provided_Training_Y/(Resource_Provided_Training_Y+Resource_Provided_Training.count("Unchecked"))
print("Of the",Resource_Provided_Training_Y+Resource_Provided_Training.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Training,"percent said they have training provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Training_Y,"people.")
x=[1,2]
y=[Resource_Provided_Training_Y,Resource_Provided_Training.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Training?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 6.930693069306931 percent said they have training provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 42 people.
# ([<matplotlib.axis.XTick at 0xb381550>, <matplotlib.axis.XTick at 0xb35a710>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BY 76 Credit towards tenure and promotion
Resource_Provided_Credit = []
for row in data.values[:,76]:
    Resource_Provided_Credit.append(row)
Resource_Provided_Credit_Y = Resource_Provided_Credit.count("Checked") 
Percentage_Resource_Provided_Credit=100*Resource_Provided_Credit_Y/(Resource_Provided_Credit_Y+Resource_Provided_Credit.count("Unchecked"))
print("Of the",Resource_Provided_Credit_Y+Resource_Provided_Credit.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Credit,"percent said they have credit provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Credit_Y,"people.")
x=[1,2]
y=[Resource_Provided_Credit_Y,Resource_Provided_Credit.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Credit?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 18.316831683168317 percent said they have credit provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 111 people.
# ([<matplotlib.axis.XTick at 0xb45d240>, <matplotlib.axis.XTick at 0xb2eb940>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column BZ 77 Stipends
Resource_Provided_Stipends = []
for row in data.values[:,77]:
    Resource_Provided_Stipends.append(row)
Resource_Provided_Stipends_Y = Resource_Provided_Stipends.count("Checked") 
Percentage_Resource_Provided_Stipends=100*Resource_Provided_Stipends_Y/(Resource_Provided_Stipends_Y+Resource_Provided_Stipends.count("Unchecked"))
print("Of the",Resource_Provided_Stipends_Y+Resource_Provided_Stipends.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Stipends,"percent said they have stipends provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Stipends_Y,"people.")
x=[1,2]
y=[Resource_Provided_Stipends_Y,Resource_Provided_Stipends.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Stipends?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 4.785478547854786 percent said they have stipends provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 29 people.
# ([<matplotlib.axis.XTick at 0xacfd898>, <matplotlib.axis.XTick at 0xb38deb8>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column CA 78 Release time to develop computational exercises
Resource_Provided_Release_Time_Exercises = []
for row in data.values[:,78]:
    Resource_Provided_Release_Time_Exercises.append(row)
Resource_Provided_Release_Time_Exercises_Y = Resource_Provided_Release_Time_Exercises.count("Checked") 
Percentage_Resource_Provided_Release_Time_Exercises=100*Resource_Provided_Release_Time_Exercises_Y/(Resource_Provided_Release_Time_Exercises_Y+Resource_Provided_Release_Time_Exercises.count("Unchecked"))
print("Of the",Resource_Provided_Release_Time_Exercises_Y+Resource_Provided_Release_Time_Exercises.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Release_Time_Exercises,"percent said they have Release time to develop computational exercises provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Release_Time_Exercises_Y,"people.")
x=[1,2]
y=[Resource_Provided_Release_Time_Exercises_Y,Resource_Provided_Release_Time_Exercises.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Release time to develop computational exercises?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 2.31023102310231 percent said they have Release time to develop computational exercises provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 14 people.
# ([<matplotlib.axis.XTick at 0xade40f0>, <matplotlib.axis.XTick at 0xb5626a0>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column CB 79 Other
Resource_Provided_Other = []
for row in data.values[:,79]:
    Resource_Provided_Other.append(row)
Resource_Provided_Other_Y = Resource_Provided_Other.count("Checked") 
Percentage_Resource_Provided_Other=100*Resource_Provided_Other_Y/(Resource_Provided_Other_Y+Resource_Provided_Other.count("Unchecked"))
print("Of the",Resource_Provided_Other_Y+Resource_Provided_Other.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_Other,"percent said they have Other things provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_Other_Y,"people.")
x=[1,2]
y=[Resource_Provided_Other_Y,Resource_Provided_Other.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access to Other?')
labels=['yes','no']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 4.125412541254126 percent said they have Other things provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 25 people.
# ([<matplotlib.axis.XTick at 0xb2fe048>, <matplotlib.axis.XTick at 0xb5d78d0>],
#  <a list of 2 Text xticklabel objects>)

# %%
#This is for column CC 80 None
Resource_Provided_None = []
for row in data.values[:,80]:
    Resource_Provided_None.append(row)
Resource_Provided_None_Y = Resource_Provided_None.count("Checked") 
Percentage_Resource_Provided_None=100*Resource_Provided_None_Y/(Resource_Provided_None_Y+Resource_Provided_None.count("Unchecked"))
print("Of the",Resource_Provided_None_Y+Resource_Provided_None.count("Unchecked"),"people who answered this question",Percentage_Resource_Provided_None,"percent said they don't have things provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is",Resource_Provided_None_Y,"people.")
x=[1,2]
y=[Resource_Provided_None_Y,Resource_Provided_None.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Access?')
labels=['no','yes']
plt.xticks(x,labels)
# Out:
# Of the 606 people who answered this question 20.957095709570957 percent said they don't have things provided by the institution to support faculty to include computational physics in the undergraduate curriculum. That is 127 people.
# ([<matplotlib.axis.XTick at 0xb65d160>, <matplotlib.axis.XTick at 0xb55e668>],
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# ## Question 16

# %%
Stu_Comp_Lab_YN = []
#Collumn CE
for row in data.values[:,82]:
    Stu_Comp_Lab_YN.append(row)
#Number of respondents who answered that their institution has computer lab space for students
Stu_Comp_Lab_Y = Stu_Comp_Lab_YN.count("Yes") 
print('The number of responents who said thier institution has computer lab space for students is:', Stu_Comp_Lab_Y)
#Proportion
Prop_Stu_Comp_Lab_Y = Stu_Comp_Lab_Y/(Stu_Comp_Lab_Y+Stu_Comp_Lab_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Stu_Comp_Lab_Y)
# Out:
# The number of responents who said thier institution has computer lab space for students is: 503
# Of those who responded, The proportion who said this is: 0.813915857605178

# %%
Stu_Prov_PC_YN = []
#Collumn CF
for row in data.values[:,83]:
    Stu_Prov_PC_YN.append(row)
#Number of respondents who answered that their institution provides PCs for students
Stu_Prov_PC_Y = Stu_Prov_PC_YN.count("Yes") 
print('The number of responents who said thier institution provides PCs for students is:', Stu_Prov_PC_Y)
#Proportion
Prop_Prov_PC_Lab_Y = Stu_Prov_PC_Y/(Stu_Prov_PC_Y+Stu_Prov_PC_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Prov_PC_Lab_Y)
# Out:
# The number of responents who said thier institution provides PCs for students is: 116
# Of those who responded, The proportion who said this is: 0.18770226537216828

# %%
Stu_Comp_Power_YN = []
#Collumn CG
for row in data.values[:,84]:
    Stu_Comp_Power_YN.append(row)
#Number of respondents who answered that their institution provides adequate computing power to students 
Stu_Comp_Power_Y = Stu_Comp_Power_YN.count("Yes") 
print('The number of responents who said thier institution provides adequate computing power to students is:', Stu_Comp_Power_Y)
#Proportion
Prop_Comp_Power_Y = Stu_Comp_Power_Y/(Stu_Comp_Power_Y+Stu_Comp_Power_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Comp_Power_Y)
# Out:
# The number of responents who said thier institution provides adequate computing power to students is: 481
# Of those who responded, The proportion who said this is: 0.7783171521035599

# %%
Stu_Res_Funds_YN = []
#Collumn CH
for row in data.values[:,85]:
    Stu_Res_Funds_YN.append(row)
#Number of respondents who answered that their institution provides research funds to students for computation
Stu_Res_Funds_Y = Stu_Res_Funds_YN.count("Yes") 
print('The number of responents who said thier institution provides research funds to students for computation is:', Stu_Res_Funds_Y)
#Proportion
Prop_Res_Funds_Y = Stu_Res_Funds_Y/(Stu_Res_Funds_Y+Stu_Res_Funds_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Res_Funds_Y)
# Out:
# The number of responents who said thier institution provides research funds to students for computation is: 165
# Of those who responded, The proportion who said this is: 0.2669902912621359

# %%
Stu_Res_Opp_YN = []
#Collumn CI
for row in data.values[:,86]:
    Stu_Res_Opp_YN.append(row)
#Number of respondents who answered that their institution provides research expiernce opportunitues to students for computation
Stu_Res_Opp_Y = Stu_Res_Opp_YN.count("Yes") 
print('The number of responents who said thier institution provides research expiernce opportunitues to students for computation is:', Stu_Res_Opp_Y)
#Proportion
Prop_Res_Opp_Y = Stu_Res_Opp_Y/(Stu_Res_Opp_Y+Stu_Res_Opp_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Res_Opp_Y)
# Out:
# The number of responents who said thier institution provides research expiernce opportunitues to students for computation is: 526
# Of those who responded, The proportion who said this is: 0.8511326860841424

# %%
Stu_Ind_Stu_YN = []
#Collumn CJ
for row in data.values[:,87]:
    Stu_Ind_Stu_YN.append(row)
#Number of respondents who answered that their institution independent studies to students in computation
Stu_Ind_Stu_Y = Stu_Ind_Stu_YN.count("Yes") 
print('The number of responents who said thier institution provides research independent studies to students in computation is:', Stu_Ind_Stu_Y)
#Proportion
Prop_Ind_Stu_Y = Stu_Ind_Stu_Y/(Stu_Ind_Stu_Y+Stu_Ind_Stu_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Ind_Stu_Y)
# Out:
# The number of responents who said thier institution provides research independent studies to students in computation is: 356
# Of those who responded, The proportion who said this is: 0.5760517799352751

# %%
Oth_Res_YN = []
#Collumn CK
for row in data.values[:,88]:
    Oth_Res_YN.append(row)
#Number of respondents who answered that their institution offers some other resource for computational support to students
Oth_Res_Y = Oth_Res_YN.count("Yes") 
print('The number of responents who said thier institution offers some other resource for computational support to students is:', Oth_Res_Y)
#Proportion
Prop_Oth_Res_Y = Oth_Res_Y/(Oth_Res_Y+Oth_Res_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Oth_Res_Y)
# Out:
# The number of responents who said thier institution offers some other resource for computational support to students is: 22
# Of those who responded, The proportion who said this is: 0.03559870550161812

# %%
Non_Above_Res_YN = []
#Collumn CL
for row in data.values[:,89]:
    Non_Above_Res_YN.append(row)
#Number of respondents who answered that their institution offers some other resource for computational support to students
Non_Above_Res_Y = Non_Above_Res_YN.count("Yes") 
print('The number of responents who said thier institution offers some other resource for computational support to students is:', Non_Above_Res_Y)
#Proportion
Prop_Non_Above_Res_Y = Non_Above_Res_Y/(Non_Above_Res_Y+Oth_Res_YN.count("No"))
print('Of those who responded, The proportion who said this is:', Prop_Non_Above_Res_Y)
# Out:
# The number of responents who said thier institution offers some other resource for computational support to students is: 5
# Of those who responded, The proportion who said this is: 0.008319467554076539

# %%
Ans16 = ['Computer Lab', 'Personal Computers', 'Adequate Computing Power', 'Accessable Research Funds', 'Research Experience Opportunities', 'Independent Studies', 'Other Resource', 'None of the Above']
Tick16 = [1,2,3,4,5,6,7,8]
Ans16_dist = [Prop_Stu_Comp_Lab_Y, Prop_Prov_PC_Lab_Y, Prop_Comp_Power_Y, Prop_Res_Funds_Y, Prop_Res_Opp_Y, Prop_Ind_Stu_Y, Prop_Oth_Res_Y, Prop_Non_Above_Res_Y]
plt.xticks(Tick16, Ans16, rotation=80)
plt.bar(Tick16, Ans16_dist)
plt.title('Supprot Resources Alocated for Students to Learn Computation')
plt.ylabel('Proportion')
plt.xlabel('Type of Support')

# %% [markdown]
# ## Question 17

# %%
Teach_Mot_Res_Int_YN = []
#Collumn CN
for row in data.values[:,91]:
    Teach_Mot_Res_Int_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is personal research interest
Teach_Mot_Res_Int_Y = Teach_Mot_Res_Int_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is research interest is:', Teach_Mot_Res_Int_Y)
#Proportion
Prop_Teach_Mot_Res_Int_Y = Teach_Mot_Res_Int_Y/(Teach_Mot_Res_Int_Y+Teach_Mot_Res_Int_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Res_Int_Y)
Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Res_Int_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is research interest is: 401
# Of those who responded, The proportion who said this is: 0.6478190630048465

# %%
Teach_Mot_Work_Skill_YN = []
#Collumn CO
for row in data.values[:,92]:
    Teach_Mot_Work_Skill_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is providing workforce skills
Teach_Mot_Work_Skill_Y = Teach_Mot_Work_Skill_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is providing workforce skills is:', Teach_Mot_Work_Skill_Y)
#Proportion
Prop_Teach_Mot_Work_Skill_Y = Teach_Mot_Work_Skill_Y/(Teach_Mot_Work_Skill_Y+Teach_Mot_Work_Skill_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Work_Skill_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Work_Skill_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is providing workforce skills is: 531
# Of those who responded, The proportion who said this is: 0.8578352180936996

# %%
Teach_Mot_Fut_Phy_YN = []
#Collumn CP
for row in data.values[:,93]:
    Teach_Mot_Fut_Phy_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is that it is the future of physics
Teach_Mot_Fut_Phy_Y = Teach_Mot_Fut_Phy_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is is that it is the future of physics is:', Teach_Mot_Fut_Phy_Y)
#Proportion
Prop_Teach_Mot_Fut_Phy_Y = Teach_Mot_Fut_Phy_Y/(Teach_Mot_Fut_Phy_Y+Teach_Mot_Fut_Phy_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Fut_Phy_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Fut_Phy_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is is that it is the future of physics is: 279
# Of those who responded, The proportion who said this is: 0.4507269789983845

# %%
Teach_Mot_Uni_Man_YN = []
#Collumn CQ
for row in data.values[:,94]:
    Teach_Mot_Uni_Man_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is that it is a university mandate
Teach_Mot_Uni_Man_Y = Teach_Mot_Uni_Man_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is is that it is university mandate is:', Teach_Mot_Uni_Man_Y)
#Proportion
Prop_Teach_Mot_Uni_Man_Y = Teach_Mot_Uni_Man_Y/(Teach_Mot_Uni_Man_Y+Teach_Mot_Uni_Man_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Uni_Man_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Uni_Man_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is is that it is university mandate is: 0
# Of those who responded, The proportion who said this is: 0.0

# %%
Teach_Mot_Dep_Man_YN = []
#Collumn CR
for row in data.values[:,95]:
    Teach_Mot_Dep_Man_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is that it is a department mandate
Teach_Mot_Dep_Man_Y = Teach_Mot_Dep_Man_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is is that it is department mandate is:', Teach_Mot_Dep_Man_Y)
#Proportion
Prop_Teach_Mot_Dep_Man_Y = Teach_Mot_Dep_Man_Y/(Teach_Mot_Dep_Man_Y+Teach_Mot_Dep_Man_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Dep_Man_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Dep_Man_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is is that it is department mandate is: 53
# Of those who responded, The proportion who said this is: 0.08562197092084006

# %%
Teach_Mot_Dep_Rew_YN = []
#Collumn CT
for row in data.values[:,96]:
    Teach_Mot_Dep_Rew_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation are department rewards
Teach_Mot_Dep_Rew_Y = Teach_Mot_Dep_Rew_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation are department rewards is:', Teach_Mot_Dep_Rew_Y)
#Proportion
Prop_Teach_Mot_Dep_Rew_Y = Teach_Mot_Dep_Rew_Y/(Teach_Mot_Dep_Rew_Y+Teach_Mot_Dep_Rew_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Dep_Rew_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Dep_Rew_Y)
# Out:
# The number of responents who said thier motivation for teaching computation are department rewards is: 7
# Of those who responded, The proportion who said this is: 0.011308562197092083

# %%
Teach_Mot_Best_Met_YN = []
#Collumn CU
for row in data.values[:,97]:
    Teach_Mot_Best_Met_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is that it's the best way to learn physics
Teach_Mot_Best_Met_Y = Teach_Mot_Best_Met_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is that it is the best way to learn physics is:', Teach_Mot_Best_Met_Y)
#Proportion
Prop_Teach_Mot_Best_Met_Y = Teach_Mot_Best_Met_Y/(Teach_Mot_Best_Met_Y+Teach_Mot_Best_Met_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Best_Met_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Best_Met_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is that it is the best way to learn physics is: 122
# Of those who responded, The proportion who said this is: 0.19709208400646203

# %%
Teach_Mot_Oth_YN = []
#Collumn CV
for row in data.values[:,98]:
    Teach_Mot_Oth_YN.append(row)
#Number of respondents who answered that their motivation for teaching computation is some other reason
Teach_Mot_Oth_Y = Teach_Mot_Oth_YN.count("Checked") 
print('The number of responents who said thier motivation for teaching computation is some other reason is:', Teach_Mot_Oth_Y)
#Proportion
Prop_Teach_Mot_Oth_Y = Teach_Mot_Oth_Y/(Teach_Mot_Oth_Y+Teach_Mot_Oth_YN.count("Unchecked"))
print('Of those who responded, The proportion who said this is:', Prop_Teach_Mot_Oth_Y)
#Ans17_Dist = []
Ans17_Dist.append(Prop_Teach_Mot_Oth_Y)
# Out:
# The number of responents who said thier motivation for teaching computation is some other reason is: 100
# Of those who responded, The proportion who said this is: 0.16155088852988692

# %%
#To ensure there are no mistakes
print(Ans17_Dist)
# Out:
# [0.6478190630048465, 0.8578352180936996, 0.4507269789983845, 0.0, 0.08562197092084006, 0.011308562197092083, 0.19709208400646203, 0.16155088852988692]

# %%
Ans17 = ['Personal Research Interest', 'Providing Workforce Skills', 'Computation is the Future of Physics', 'Accessable Research Funds', 'University Mandate', 'Department Mandate', 'Department Rewards', 'Some Other Motivation']
Tick17 = [1,2,3,4,5,6,7,8]
plt.xticks(Tick17, Ans17, rotation=80)
plt.bar(Tick17, Ans17_Dist)
plt.title('Motivation for Teaching Computation')
plt.ylabel('Proportion')
#plt.xlabel('Type of Motivation')

# %% [markdown]
# ## Question 18

# %%
Dept_Trans_Adq_Res_AGDS = []
#Collumn CW
for row in data.values[:,100]:
    Dept_Trans_Adq_Res_AGDS.append(row)
#Agreement with the statement of having adequate resources to handle the transition
Ans18a_Tot = Dept_Trans_Adq_Res_AGDS.count("Strongly agree")+Dept_Trans_Adq_Res_AGDS.count("Agree")+Dept_Trans_Adq_Res_AGDS.count("Neither agree nor disagree")+Dept_Trans_Adq_Res_AGDS.count("Disagree")+Dept_Trans_Adq_Res_AGDS.count("Strongly disgaree")+Dept_Trans_Adq_Res_AGDS.count("I Don't Know")
Dept_Trans_Adq_Res_Dist = []
Dept_Trans_Adq_Res_Str_Ag = Dept_Trans_Adq_Res_AGDS.count("Strongly agree")
Prop_Dept_Trans_Adq_Res_Str_Ag = Dept_Trans_Adq_Res_Str_Ag/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_Str_Ag)
Dept_Trans_Adq_Res_Ag = Dept_Trans_Adq_Res_AGDS.count("Agree")
Prop_Dept_Trans_Adq_Res_Ag = Dept_Trans_Adq_Res_Ag/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_Ag)
Dept_Trans_Adq_Res_Neither = Dept_Trans_Adq_Res_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Adq_Res_Neither = Dept_Trans_Adq_Res_Neither/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_Neither)
Dept_Trans_Adq_Res_Ds = Dept_Trans_Adq_Res_AGDS.count("Disagree")
Prop_Dept_Trans_Adq_Res_Ds = Dept_Trans_Adq_Res_Ds/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_Ds)
#disgaree is a typo in the results
Dept_Trans_Adq_Res_Str_Ds = Dept_Trans_Adq_Res_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Adq_Res_Str_Ds = Dept_Trans_Adq_Res_Str_Ds/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_Str_Ds)
Dept_Trans_Adq_Res_DK = Dept_Trans_Adq_Res_AGDS.count("I Don't Know")
Prop_Dept_Trans_Adq_Res_DK = Dept_Trans_Adq_Res_DK/(Ans18a_Tot)
Dept_Trans_Adq_Res_Dist.append(Prop_Dept_Trans_Adq_Res_DK)
print(Dept_Trans_Adq_Res_Dist)
# Out:
# [0.11260504201680673, 0.4016806722689076, 0.22857142857142856, 0.13445378151260504, 0.058823529411764705, 0.06386554621848739]

# %%
Ans18a = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18a = [1,2,3,4,5,6]
Ans18a_dist = Dept_Trans_Adq_Res_Dist
plt.xticks(Tick18a, Ans18a, rotation=45)
plt.bar(Tick18a, Ans18a_dist)
plt.title('During the Transition to Teaching Computation, the You had Adequate Resources')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Work_Adntl_AGDS = []
#Collumn CX
for row in data.values[:,101]:
    Dept_Trans_Work_Adntl_AGDS.append(row)
#Agreement with the statement Had to work with aditional faculty
Ans18b_Tot = Dept_Trans_Work_Adntl_AGDS.count("Strongly agree")+Dept_Trans_Work_Adntl_AGDS.count("Agree")+Dept_Trans_Work_Adntl_AGDS.count("Neither agree nor disagree")+Dept_Trans_Work_Adntl_AGDS.count("Disagree")+Dept_Trans_Work_Adntl_AGDS.count("Strongly disgaree")+Dept_Trans_Work_Adntl_AGDS.count("I Don't Know")
Dept_Trans_Work_Adntl_Dist = []
Dept_Trans_Work_Adntl_Str_Ag = Dept_Trans_Work_Adntl_AGDS.count("Strongly agree")
Prop_Dept_Trans_Work_Adntl_Str_Ag = Dept_Trans_Work_Adntl_Str_Ag/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_Str_Ag)
Dept_Trans_Work_Adntl_Ag = Dept_Trans_Work_Adntl_AGDS.count("Agree")
Prop_Dept_Trans_Work_Adntl_Ag = Dept_Trans_Work_Adntl_Ag/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_Ag)
Dept_Trans_Work_Adntl_Neither = Dept_Trans_Work_Adntl_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Work_Adntl_Neither = Dept_Trans_Work_Adntl_Neither/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_Neither)
Dept_Trans_Work_Adntl_Ds = Dept_Trans_Work_Adntl_AGDS.count("Disagree")
Prop_Dept_Trans_Work_Adntl_Ds = Dept_Trans_Work_Adntl_Ds/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_Ds)
#disgaree is a typo in the results
Dept_Trans_Work_Adntl_Str_Ds = Dept_Trans_Work_Adntl_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Work_Adntl_Str_Ds = Dept_Trans_Work_Adntl_Str_Ds/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_Str_Ds)
Dept_Trans_Work_Adntl_DK = Dept_Trans_Work_Adntl_AGDS.count("I Don't Know")
Prop_Dept_Trans_Work_Adntl_DK = Dept_Trans_Work_Adntl_DK/(Ans18b_Tot)
Dept_Trans_Work_Adntl_Dist.append(Prop_Dept_Trans_Work_Adntl_DK)
print(Dept_Trans_Work_Adntl_Dist)
# Out:
# [0.013745704467353952, 0.10309278350515463, 0.21477663230240548, 0.3316151202749141, 0.2646048109965636, 0.07216494845360824]

# %%
Ans18b = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18b = [1,2,3,4,5,6]
Ans18b_dist = Dept_Trans_Work_Adntl_Dist
plt.xticks(Tick18b, Ans18b, rotation=45)
plt.bar(Tick18b, Ans18b_dist)
plt.title('During the Transition to Teaching Computation, the You had to Work with Additional Faculty')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Conv_Dept_AGDS = []
#Collumn CY
for row in data.values[:,102]:
    Dept_Trans_Conv_Dept_AGDS.append(row)
#Agreement with the statement Had to work with aditional faculty
Ans18c_Tot = Dept_Trans_Conv_Dept_AGDS.count("Strongly agree")+Dept_Trans_Conv_Dept_AGDS.count("Agree")+Dept_Trans_Conv_Dept_AGDS.count("Neither agree nor disagree")+Dept_Trans_Conv_Dept_AGDS.count("Disagree")+Dept_Trans_Conv_Dept_AGDS.count("Strongly disgaree")+Dept_Trans_Conv_Dept_AGDS.count("I Don't Know")
Dept_Trans_Conv_Dept_Dist = []
Dept_Trans_Conv_Dept_Str_Ag = Dept_Trans_Conv_Dept_AGDS.count("Strongly agree")
Prop_Dept_Trans_Conv_Dept_Str_Ag = Dept_Trans_Conv_Dept_Str_Ag/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_Str_Ag)
Dept_Trans_Conv_Dept_Ag = Dept_Trans_Conv_Dept_AGDS.count("Agree")
Prop_Dept_Trans_Conv_Dept_Ag = Dept_Trans_Conv_Dept_Ag/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_Ag)
Dept_Trans_Conv_Dept_Neither = Dept_Trans_Conv_Dept_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Conv_Dept_Neither = Dept_Trans_Conv_Dept_Neither/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_Neither)
Dept_Trans_Conv_Dept_Ds = Dept_Trans_Conv_Dept_AGDS.count("Disagree")
Prop_Dept_Trans_Conv_Dept_Ds = Dept_Trans_Conv_Dept_Ds/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_Ds)
#disgaree is a typo in the results
Dept_Trans_Conv_Dept_Str_Ds = Dept_Trans_Conv_Dept_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Conv_Dept_Str_Ds = Dept_Trans_Conv_Dept_Str_Ds/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_Str_Ds)
Dept_Trans_Conv_Dept_DK = Dept_Trans_Conv_Dept_AGDS.count("I Don't Know")
Prop_Dept_Trans_Conv_Dept_DK = Dept_Trans_Conv_Dept_DK/(Ans18c_Tot)
Dept_Trans_Conv_Dept_Dist.append(Prop_Dept_Trans_Conv_Dept_DK)
print(Dept_Trans_Conv_Dept_Dist)
# Out:
# [0.021996615905245348, 0.077834179357022, 0.14213197969543148, 0.37055837563451777, 0.3248730964467005, 0.06260575296108291]

# %%
Ans18c = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18c = [1,2,3,4,5,6]
Ans18c_dist = Dept_Trans_Conv_Dept_Dist
plt.xticks(Tick18c, Ans18c, rotation=45)
plt.bar(Tick18c, Ans18c_dist)
plt.title('During the Transition to Teaching Computation, the You had to Convince the Department of its Merits')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Fac_Res_AGDS = []
#Collumn CZ
for row in data.values[:,103]:
    Dept_Trans_Fac_Res_AGDS.append(row)
#Agreement with the statement There was resistence from other faculty
Ans18d_Tot = Dept_Trans_Fac_Res_AGDS.count("Strongly agree")+Dept_Trans_Fac_Res_AGDS.count("Agree")+Dept_Trans_Fac_Res_AGDS.count("Neither agree nor disagree")+Dept_Trans_Fac_Res_AGDS.count("Disagree")+Dept_Trans_Fac_Res_AGDS.count("Strongly disgaree")+Dept_Trans_Fac_Res_AGDS.count("I Don't Know")
Dept_Trans_Fac_Res_Dist = []
Dept_Trans_Fac_Res_Str_Ag = Dept_Trans_Fac_Res_AGDS.count("Strongly agree")
Prop_Dept_Trans_Fac_Res_Str_Ag = Dept_Trans_Fac_Res_Str_Ag/(Ans18d_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_Str_Ag)
Dept_Trans_Fac_Res_Ag = Dept_Trans_Fac_Res_AGDS.count("Agree")
Prop_Dept_Trans_Fac_Res_Ag = Dept_Trans_Fac_Res_Ag/(Ans18d_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_Ag)
Dept_Trans_Fac_Res_Neither = Dept_Trans_Fac_Res_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Fac_Res_Neither = Dept_Trans_Fac_Res_Neither/(Ans18d_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_Neither)
Dept_Trans_Fac_Res_Ds = Dept_Trans_Fac_Res_AGDS.count("Disagree")
Prop_Dept_Trans_Fac_Res_Ds = Dept_Trans_Fac_Res_Ds/(Ans18d_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_Ds)
#disgaree is a typo in the results
Dept_Trans_Fac_Res_Str_Ds = Dept_Trans_Fac_Res_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Fac_Res_Str_Ds = Dept_Trans_Fac_Res_Str_Ds/(Ans18c_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_Str_Ds)
Dept_Trans_Fac_Res_DK = Dept_Trans_Fac_Res_AGDS.count("I Don't Know")
Prop_Dept_Trans_Fac_Res_DK = Dept_Trans_Fac_Res_DK/(Ans18c_Tot)
Dept_Trans_Fac_Res_Dist.append(Prop_Dept_Trans_Fac_Res_DK)
print(Dept_Trans_Fac_Res_Dist)
# Out:
# [0.027257240204429302, 0.08858603066439523, 0.12095400340715502, 0.3594548551959114, 0.34348561759729274, 0.05752961082910321]

# %%
Ans18d = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18d = [1,2,3,4,5,6]
Ans18d_dist = Dept_Trans_Fac_Res_Dist
plt.xticks(Tick18d, Ans18d, rotation=45)
plt.bar(Tick18d, Ans18d_dist)
plt.title('Other Faculty Resisted the Transition to Teaching Computation')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Stu_Res_AGDS = []
#Collumn DA
for row in data.values[:,104]:
    Dept_Trans_Stu_Res_AGDS.append(row)
#Agreement with the statement There was resistence from students
Ans18e_Tot = Dept_Trans_Stu_Res_AGDS.count("Strongly agree")+Dept_Trans_Stu_Res_AGDS.count("Agree")+Dept_Trans_Stu_Res_AGDS.count("Neither agree nor disagree")+Dept_Trans_Stu_Res_AGDS.count("Disagree")+Dept_Trans_Stu_Res_AGDS.count("Strongly disgaree")+Dept_Trans_Stu_Res_AGDS.count("I Don't Know")
Dept_Trans_Stu_Res_Dist = []
Dept_Trans_Stu_Res_Str_Ag = Dept_Trans_Stu_Res_AGDS.count("Strongly agree")
Prop_Dept_Trans_Stu_Res_Str_Ag = Dept_Trans_Stu_Res_Str_Ag/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_Str_Ag)
Dept_Trans_Stu_Res_Ag = Dept_Trans_Stu_Res_AGDS.count("Agree")
Prop_Dept_Trans_Stu_Res_Ag = Dept_Trans_Stu_Res_Ag/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_Ag)
Dept_Trans_Stu_Res_Neither = Dept_Trans_Stu_Res_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Stu_Res_Neither = Dept_Trans_Stu_Res_Neither/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_Neither)
Dept_Trans_Stu_Res_Ds = Dept_Trans_Stu_Res_AGDS.count("Disagree")
Prop_Dept_Trans_Stu_Res_Ds = Dept_Trans_Stu_Res_Ds/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_Ds)
#disgaree is a typo in the results
Dept_Trans_Stu_Res_Str_Ds = Dept_Trans_Stu_Res_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Stu_Res_Str_Ds = Dept_Trans_Stu_Res_Str_Ds/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_Str_Ds)
Dept_Trans_Stu_Res_DK = Dept_Trans_Stu_Res_AGDS.count("I Don't Know")
Prop_Dept_Trans_Stu_Res_DK = Dept_Trans_Stu_Res_DK/(Ans18e_Tot)
Dept_Trans_Stu_Res_Dist.append(Prop_Dept_Trans_Stu_Res_DK)
print(Dept_Trans_Stu_Res_Dist)
# Out:
# [0.013605442176870748, 0.1717687074829932, 0.20578231292517007, 0.3078231292517007, 0.24149659863945577, 0.05952380952380952]

# %%
Ans18e = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18e = [1,2,3,4,5,6]
Ans18e_dist = Dept_Trans_Stu_Res_Dist
plt.xticks(Tick18e, Ans18e, rotation=45)
plt.bar(Tick18e, Ans18e_dist)
plt.title('Students Resisted the Transition to Teaching Computation')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Oth_Res_AGDS = []
#Collumn DB
for row in data.values[:,105]:
    Dept_Trans_Oth_Res_AGDS.append(row)
#Agreement with the statement There was resistence from other departments
Ans18f_Tot = Dept_Trans_Oth_Res_AGDS.count("Strongly agree")+Dept_Trans_Oth_Res_AGDS.count("Agree")+Dept_Trans_Oth_Res_AGDS.count("Neither agree nor disagree")+Dept_Trans_Oth_Res_AGDS.count("Disagree")+Dept_Trans_Oth_Res_AGDS.count("Strongly disgaree")+Dept_Trans_Oth_Res_AGDS.count("I Don't Know")
Dept_Trans_Oth_Res_Dist = []
Dept_Trans_Oth_Res_Str_Ag = Dept_Trans_Oth_Res_AGDS.count("Strongly agree")
Prop_Dept_Trans_Oth_Res_Str_Ag = Dept_Trans_Oth_Res_Str_Ag/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_Str_Ag)
Dept_Trans_Oth_Res_Ag = Dept_Trans_Oth_Res_AGDS.count("Agree")
Prop_Dept_Trans_Oth_Res_Ag = Dept_Trans_Oth_Res_Ag/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_Ag)
Dept_Trans_Oth_Res_Neither = Dept_Trans_Oth_Res_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Oth_Res_Neither = Dept_Trans_Oth_Res_Neither/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_Neither)
Dept_Trans_Oth_Res_Ds = Dept_Trans_Oth_Res_AGDS.count("Disagree")
Prop_Dept_Trans_Oth_Res_Ds = Dept_Trans_Oth_Res_Ds/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_Ds)
#disgaree is a typo in the results
Dept_Trans_Oth_Res_Str_Ds = Dept_Trans_Oth_Res_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Oth_Res_Str_Ds = Dept_Trans_Oth_Res_Str_Ds/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_Str_Ds)
Dept_Trans_Oth_Res_DK = Dept_Trans_Oth_Res_AGDS.count("I Don't Know")
Prop_Dept_Trans_Oth_Res_DK = Dept_Trans_Oth_Res_DK/(Ans18f_Tot)
Dept_Trans_Oth_Res_Dist.append(Prop_Dept_Trans_Oth_Res_DK)
print(Dept_Trans_Oth_Res_Dist)
# Out:
# [0.01020408163265306, 0.03231292517006803, 0.13435374149659865, 0.33843537414965985, 0.3554421768707483, 0.1292517006802721]

# %%
Ans18f = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18f = [1,2,3,4,5,6]
Ans18f_dist = Dept_Trans_Oth_Res_Dist
plt.xticks(Tick18f, Ans18f, rotation=45)
plt.bar(Tick18f, Ans18f_dist)
plt.title('Other Departments Resisted the Transition to Teaching Computation')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Dept_Trans_Adm_Res_AGDS = []
#Collumn DC
for row in data.values[:,106]:
    Dept_Trans_Adm_Res_AGDS.append(row)
#Agreement with the statement There was resistence from other departments
Ans18g_Tot = Dept_Trans_Adm_Res_AGDS.count("Strongly agree")+Dept_Trans_Adm_Res_AGDS.count("Agree")+Dept_Trans_Adm_Res_AGDS.count("Neither agree nor disagree")+Dept_Trans_Adm_Res_AGDS.count("Disagree")+Dept_Trans_Adm_Res_AGDS.count("Strongly disgaree")+Dept_Trans_Adm_Res_AGDS.count("I Don't Know")
Dept_Trans_Adm_Res_Dist = []
Dept_Trans_Adm_Res_Str_Ag = Dept_Trans_Adm_Res_AGDS.count("Strongly agree")
Prop_Dept_Trans_Adm_Res_Str_Ag = Dept_Trans_Adm_Res_Str_Ag/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_Str_Ag)
Dept_Trans_Adm_Res_Ag = Dept_Trans_Adm_Res_AGDS.count("Agree")
Prop_Dept_Trans_Adm_Res_Ag = Dept_Trans_Adm_Res_Ag/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_Ag)
Dept_Trans_Adm_Res_Neither = Dept_Trans_Adm_Res_AGDS.count("Neither agree nor disagree")
Prop_Dept_Trans_Adm_Res_Neither = Dept_Trans_Adm_Res_Neither/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_Neither)
Dept_Trans_Adm_Res_Ds = Dept_Trans_Adm_Res_AGDS.count("Disagree")
Prop_Dept_Trans_Adm_Res_Ds = Dept_Trans_Adm_Res_Ds/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_Ds)
#disgaree is a typo in the results
Dept_Trans_Adm_Res_Str_Ds = Dept_Trans_Adm_Res_AGDS.count("Strongly disgaree")
Prop_Dept_Trans_Adm_Res_Str_Ds = Dept_Trans_Adm_Res_Str_Ds/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_Str_Ds)
Dept_Trans_Adm_Res_DK = Dept_Trans_Adm_Res_AGDS.count("I Don't Know")
Prop_Dept_Trans_Adm_Res_DK = Dept_Trans_Adm_Res_DK/(Ans18g_Tot)
Dept_Trans_Adm_Res_Dist.append(Prop_Dept_Trans_Adm_Res_DK)
print(Dept_Trans_Adm_Res_Dist)
# Out:
# [0.013628620102214651, 0.022146507666098807, 0.1465076660988075, 0.34582623509369675, 0.35604770017035775, 0.11584327086882454]

# %%
Ans18g = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree', 'I Do Not Know']
Tick18g = [1,2,3,4,5,6]
Ans18g_dist = Dept_Trans_Adm_Res_Dist
plt.xticks(Tick18g, Ans18g, rotation=45)
plt.bar(Tick18g, Ans18g_dist)
plt.title('The Administration Resisted the Transition to Teaching Computation')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %% [markdown]
# ## Question 19
# The following experiences have enabled me to include computation in the undergraduate courses I teach:

# %%
# Column DD column 107 Department and/or colleagues gave support to personalize and alter individual courses.
Colleague_Support_Alter_Course = []
for row in data.values[:,107]:
    Colleague_Support_Alter_Course.append(row)
Colleague_Support_Alter_Course_Strongly_Agree = Colleague_Support_Alter_Course.count("Strongly agree")
Colleague_Support_Alter_Course_Agree= Colleague_Support_Alter_Course.count("Agree")
Colleague_Support_Alter_Course_Neither= Colleague_Support_Alter_Course.count("Neither agree nor disagree")
Colleague_Support_Alter_Course_Disagree= Colleague_Support_Alter_Course.count("Disagree")
Colleague_Support_Alter_Course_Strongly_Disagree= Colleague_Support_Alter_Course.count("Strongly disgaree")
Answered_4=Colleague_Support_Alter_Course_Strongly_Agree+Colleague_Support_Alter_Course_Agree+Colleague_Support_Alter_Course_Neither+Colleague_Support_Alter_Course_Disagree+Colleague_Support_Alter_Course_Strongly_Disagree
print(Answered_4,'This many people answered the question')
x=[1,2,3,4,5]
y=[Colleague_Support_Alter_Course_Strongly_Agree,Colleague_Support_Alter_Course_Agree,Colleague_Support_Alter_Course_Neither,Colleague_Support_Alter_Course_Disagree,Colleague_Support_Alter_Course_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Colleague gave support to alter class to include computation in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DE column 108 Computational work fits into broader academic profile (e.g., major sequences).
Broader_Academic_Profile = []
for row in data.values[:,108]:
    Broader_Academic_Profile.append(row)
Broader_Academic_Profile_Strongly_Agree = Broader_Academic_Profile.count("Strongly agree")
Broader_Academic_Profile_Agree= Broader_Academic_Profile.count("Agree")
Broader_Academic_Profile_Neither= Broader_Academic_Profile.count("Neither agree nor disagree")
Broader_Academic_Profile_Disagree= Broader_Academic_Profile.count("Disagree")
Broader_Academic_Profile_Strongly_Disagree= Broader_Academic_Profile.count("Strongly disgaree")
Answered_5=Broader_Academic_Profile_Strongly_Agree+Broader_Academic_Profile_Agree+Broader_Academic_Profile_Neither+Broader_Academic_Profile_Disagree+Broader_Academic_Profile_Strongly_Disagree
print(Answered_5,'This many people answered the question')
x=[1,2,3,4,5]
y=[Broader_Academic_Profile_Strongly_Agree,Broader_Academic_Profile_Agree,Broader_Academic_Profile_Neither,Broader_Academic_Profile_Disagree,Broader_Academic_Profile_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computational work fits into broader academic profile to include computation in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DF column 109  I received pedagogical support to learn best practices for teaching computation.
Pedagogical_Support = []
for row in data.values[:,109]:
    Pedagogical_Support.append(row)
Pedagogical_Support_Strongly_Agree = Pedagogical_Support.count("Strongly agree")
Pedagogical_Support_Agree= Pedagogical_Support.count("Agree")
Pedagogical_Support_Neither= Pedagogical_Support.count("Neither agree nor disagree")
Pedagogical_Support_Disagree= Pedagogical_Support.count("Disagree")
Pedagogical_Support_Strongly_Disagree= Pedagogical_Support.count("Strongly disgaree")
Answered_6=Pedagogical_Support_Strongly_Agree+Pedagogical_Support_Agree+Pedagogical_Support_Neither+Pedagogical_Support_Disagree+Pedagogical_Support_Strongly_Disagree
print(Answered_6,'This many people answered the question')
x=[1,2,3,4,5]
y=[Pedagogical_Support_Strongly_Agree,Pedagogical_Support_Agree,Pedagogical_Support_Neither,Pedagogical_Support_Disagree,Pedagogical_Support_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('received pedagogical support to include computation in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DG column 110  Undergraduate students are prepared and have experience in computation.
Undergrads_Prepared = []
for row in data.values[:,110]:
    Undergrads_Prepared.append(row)
Undergrads_Prepared_Strongly_Agree = Undergrads_Prepared.count("Strongly agree")
Undergrads_Prepared_Agree= Undergrads_Prepared.count("Agree")
Undergrads_Prepared_Neither= Undergrads_Prepared.count("Neither agree nor disagree")
Undergrads_Prepared_Disagree= Undergrads_Prepared.count("Disagree")
Undergrads_Prepared_Strongly_Disagree= Undergrads_Prepared.count("Strongly disgaree")
Answered_7=Undergrads_Prepared_Strongly_Agree+Undergrads_Prepared_Agree+Undergrads_Prepared_Neither+Undergrads_Prepared_Disagree+Undergrads_Prepared_Strongly_Disagree
print(Answered_7,'This many people answered the question')
x=[1,2,3,4,5]
y=[Undergrads_Prepared_Strongly_Agree,Undergrads_Prepared_Agree,Undergrads_Prepared_Neither,Undergrads_Prepared_Disagree,Undergrads_Prepared_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Undergraduate students are prepared and have experience in computation in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DH column 111  Students are requesting more computational skills in the curriculum.
Students_Request_More_Computation = []
for row in data.values[:,111]:
    Students_Request_More_Computation.append(row)
Students_Request_More_Computation_Strongly_Agree = Students_Request_More_Computation.count("Strongly agree")
Students_Request_More_Computation_Agree= Students_Request_More_Computation.count("Agree")
Students_Request_More_Computation_Neither= Students_Request_More_Computation.count("Neither agree nor disagree")
Students_Request_More_Computation_Disagree= Students_Request_More_Computation.count("Disagree")
Students_Request_More_Computation_Strongly_Disagree= Students_Request_More_Computation.count("Strongly disgaree")
Answered_8=Students_Request_More_Computation_Strongly_Agree+Students_Request_More_Computation_Agree+Students_Request_More_Computation_Neither+Students_Request_More_Computation_Disagree+Students_Request_More_Computation_Strongly_Disagree
print(Answered_8,'This many people answered the question')
x=[1,2,3,4,5]
y=[Students_Request_More_Computation_Strongly_Agree,Students_Request_More_Computation_Agree,Students_Request_More_Computation_Neither,Students_Request_More_Computation_Disagree,Students_Request_More_Computation_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Students are requesting more computational skills in the curriculum in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DI column 112   There is institutional support for computation in the undergraduate curriculum (e.g., curricula reform, faculty, programs, college, etc.).
Institutional_Support = []
for row in data.values[:,112]:
    Institutional_Support.append(row)
Institutional_Support_Strongly_Agree = Institutional_Support.count("Strongly agree")
Institutional_Support_Agree= Institutional_Support.count("Agree")
Institutional_Support_Neither= Institutional_Support.count("Neither agree nor disagree")
Institutional_Support_Disagree= Institutional_Support.count("Disagree")
Institutional_Support_Strongly_Disagree= Institutional_Support.count("Strongly disgaree")
Answered_9=Institutional_Support_Strongly_Agree+Institutional_Support_Agree+Institutional_Support_Neither+Institutional_Support_Disagree+Institutional_Support_Strongly_Disagree
print(Answered_9,'This many people answered the question')
x=[1,2,3,4,5]
y=[Institutional_Support_Strongly_Agree,Institutional_Support_Agree,Institutional_Support_Neither,Institutional_Support_Disagree,Institutional_Support_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('There is institutional support for computation in the undergraduate curriculum in the course I teach')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 21
# 20 is free response

# %%
Teach_Comp_Phy_Diff_AGDS = []
#Collumn DL
for row in data.values[:,115]:
    Teach_Comp_Phy_Diff_AGDS.append(row)
#Agreement with the statement Computational Physics is hard to teach in the classroom
Ans21a_Tot = Teach_Comp_Phy_Diff_AGDS.count("Strongly agree")+Teach_Comp_Phy_Diff_AGDS.count("Agree")+Teach_Comp_Phy_Diff_AGDS.count("Neither agree nor disagree")+Teach_Comp_Phy_Diff_AGDS.count("Disagree")+Teach_Comp_Phy_Diff_AGDS.count("Strongly disgaree")
Teach_Comp_Phy_Diff_Dist = []
Teach_Comp_Phy_Diff_Str_Ag = Teach_Comp_Phy_Diff_AGDS.count("Strongly agree")
Prop_Teach_Comp_Phy_Diff_Str_Ag = Teach_Comp_Phy_Diff_Str_Ag/(Ans21a_Tot)
Teach_Comp_Phy_Diff_Dist.append(Prop_Teach_Comp_Phy_Diff_Str_Ag)
Teach_Comp_Phy_Diff_Ag = Teach_Comp_Phy_Diff_AGDS.count("Agree")
Prop_Teach_Comp_Phy_Diff_Ag = Teach_Comp_Phy_Diff_Ag/(Ans21a_Tot)
Teach_Comp_Phy_Diff_Dist.append(Prop_Teach_Comp_Phy_Diff_Ag)
Teach_Comp_Phy_Diff_Neither = Teach_Comp_Phy_Diff_AGDS.count("Neither agree nor disagree")
Prop_Teach_Comp_Phy_Diff_Neither = Teach_Comp_Phy_Diff_Neither/(Ans21a_Tot)
Teach_Comp_Phy_Diff_Dist.append(Prop_Teach_Comp_Phy_Diff_Neither)
Teach_Comp_Phy_Diff_Ds = Teach_Comp_Phy_Diff_AGDS.count("Disagree")
Prop_Teach_Comp_Phy_Diff_Ds = Teach_Comp_Phy_Diff_Ds/(Ans21a_Tot)
Teach_Comp_Phy_Diff_Dist.append(Prop_Teach_Comp_Phy_Diff_Ds)
#disgaree is a typo in the results
Teach_Comp_Phy_Diff_Ds = Teach_Comp_Phy_Diff_AGDS.count("Strongly disgaree")
Prop_Teach_Comp_Phy_Diff_Ds = Teach_Comp_Phy_Diff_Ds/(Ans21a_Tot)
Teach_Comp_Phy_Diff_Dist.append(Prop_Teach_Comp_Phy_Diff_Ds)
print(Teach_Comp_Phy_Diff_Dist)
# Out:
# [0.03694581280788178, 0.17733990147783252, 0.4630541871921182, 0.2512315270935961, 0.07142857142857142]

# %%
Ans21a = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21a = [1,2,3,4,5]
Ans21a_dist = Teach_Comp_Phy_Diff_Dist
plt.xticks(Tick21a, Ans21a, rotation=45)
plt.bar(Tick21a, Ans21a_dist)
plt.title('Computational Physics is Hard to Teach in the Classroom')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Comp_Phi_Qui_Cha_AGDS = []
#Collumn DM
for row in data.values[:,116]:
    Comp_Phi_Qui_Cha_AGDS.append(row)
#Agreement with the statement Computational Physics is quickly changing
Ans21b_Tot = Comp_Phi_Qui_Cha_AGDS.count("Strongly agree")+Comp_Phi_Qui_Cha_AGDS.count("Agree")+Comp_Phi_Qui_Cha_AGDS.count("Neither agree nor disagree")+Comp_Phi_Qui_Cha_AGDS.count("Disagree")+Comp_Phi_Qui_Cha_AGDS.count("Strongly disgaree")
Comp_Phi_Qui_Cha_Dist = []
Comp_Phi_Qui_Cha_Str_Ag = Comp_Phi_Qui_Cha_AGDS.count("Strongly agree")
Prop_Comp_Phi_Qui_Cha_Str_Ag = Comp_Phi_Qui_Cha_Str_Ag/(Ans21b_Tot)
Comp_Phi_Qui_Cha_Dist.append(Prop_Comp_Phi_Qui_Cha_Str_Ag)
Comp_Phi_Qui_Cha_Ag = Comp_Phi_Qui_Cha_AGDS.count("Agree")
Prop_Comp_Phi_Qui_Cha_Ag = Comp_Phi_Qui_Cha_Ag/(Ans21b_Tot)
Comp_Phi_Qui_Cha_Dist.append(Prop_Comp_Phi_Qui_Cha_Ag)
Comp_Phi_Qui_Cha_Neither = Comp_Phi_Qui_Cha_AGDS.count("Neither agree nor disagree")
Prop_Comp_Phi_Qui_Cha_Neither = Comp_Phi_Qui_Cha_Neither/(Ans21b_Tot)
Comp_Phi_Qui_Cha_Dist.append(Prop_Comp_Phi_Qui_Cha_Neither)
Comp_Phi_Qui_Cha_Ds = Comp_Phi_Qui_Cha_AGDS.count("Disagree")
Prop_Comp_Phi_Qui_Cha_Ds = Comp_Phi_Qui_Cha_Ds/(Ans21b_Tot)
Comp_Phi_Qui_Cha_Dist.append(Prop_Comp_Phi_Qui_Cha_Ds)
#disgaree is a typo in the results
Comp_Phi_Qui_Cha_Ds = Comp_Phi_Qui_Cha_AGDS.count("Strongly disgaree")
Prop_Comp_Phi_Qui_Cha_Ds = Comp_Phi_Qui_Cha_Ds/(Ans21b_Tot)
Comp_Phi_Qui_Cha_Dist.append(Prop_Comp_Phi_Qui_Cha_Ds)
print(Comp_Phi_Qui_Cha_Dist)
# Out:
# [0.062034739454094295, 0.3225806451612903, 0.41687344913151364, 0.12903225806451613, 0.06947890818858561]

# %%
Ans21b = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21b = [1,2,3,4,5]
Ans21b_dist = Comp_Phi_Qui_Cha_Dist
plt.xticks(Tick21b, Ans21b, rotation=45)
plt.bar(Tick21b, Ans21b_dist)
plt.title('Computational Physics is Quickly Changing')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
No_Back_Comp_AGDS = []
#Collumn DN
for row in data.values[:,117]:
    No_Back_Comp_AGDS.append(row)
#Agreement with the statement I do not have the background to teach computational physics
Ans21c_Tot = No_Back_Comp_AGDS.count("Strongly agree")+No_Back_Comp_AGDS.count("Agree")+No_Back_Comp_AGDS.count("Neither agree nor disagree")+No_Back_Comp_AGDS.count("Disagree")+No_Back_Comp_AGDS.count("Strongly disgaree")
No_Back_Comp_Dist = []
No_Back_Comp_Str_Ag = No_Back_Comp_AGDS.count("Strongly agree")
Prop_No_Back_Comp_Str_Ag = No_Back_Comp_Str_Ag/(Ans21c_Tot)
No_Back_Comp_Dist.append(Prop_No_Back_Comp_Str_Ag)
No_Back_Comp_Ag = No_Back_Comp_AGDS.count("Agree")
Prop_No_Back_Comp_Ag = No_Back_Comp_Ag/(Ans21c_Tot)
No_Back_Comp_Dist.append(Prop_No_Back_Comp_Ag)
No_Back_Comp_Neither = No_Back_Comp_AGDS.count("Neither agree nor disagree")
Prop_No_Back_Comp_Neither = No_Back_Comp_Neither/(Ans21c_Tot)
No_Back_Comp_Dist.append(Prop_No_Back_Comp_Neither)
No_Back_Comp_Ds = No_Back_Comp_AGDS.count("Disagree")
Prop_No_Back_Comp_Ds = No_Back_Comp_Ds/(Ans21c_Tot)
No_Back_Comp_Dist.append(Prop_No_Back_Comp_Ds)
#disgaree is a typo in the results
No_Back_Comp_Ds = No_Back_Comp_AGDS.count("Strongly disgaree")
Prop_No_Back_Comp_Ds = No_Back_Comp_Ds/(Ans21c_Tot)
No_Back_Comp_Dist.append(Prop_No_Back_Comp_Ds)
print(No_Back_Comp_Dist)
# Out:
# [0.11519607843137254, 0.31862745098039214, 0.17401960784313725, 0.25245098039215685, 0.13970588235294118]

# %%
Ans21c = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21c = [1,2,3,4,5]
Ans21c_dist = No_Back_Comp_Dist
plt.xticks(Tick21c, Ans21c, rotation=45)
plt.bar(Tick21c, Ans21c_dist)
plt.title('I do not Have the Backgroung to teach Computational Physics')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
No_Int_Comp_AGDS = []
#Collumn DO
for row in data.values[:,118]:
    No_Int_Comp_AGDS.append(row)
#Agreement with the statement I have no interest in computational physics
Ans21d_Tot = No_Int_Comp_AGDS.count("Strongly agree")+No_Int_Comp_AGDS.count("Agree")+No_Int_Comp_AGDS.count("Neither agree nor disagree")+No_Int_Comp_AGDS.count("Disagree")+No_Int_Comp_AGDS.count("Strongly disgaree")
No_Int_Comp_Dist = []
No_Int_Comp_Str_Ag = No_Int_Comp_AGDS.count("Strongly agree")
Prop_No_Int_Comp_Str_Ag = No_Int_Comp_Str_Ag/(Ans21d_Tot)
No_Int_Comp_Dist.append(Prop_No_Int_Comp_Str_Ag)
No_Int_Comp_Ag = No_Int_Comp_AGDS.count("Agree")
Prop_No_Int_Comp_Ag = No_Int_Comp_Ag/(Ans21d_Tot)
No_Int_Comp_Dist.append(Prop_No_Int_Comp_Ag)
No_Int_Comp_Neither = No_Int_Comp_AGDS.count("Neither agree nor disagree")
Prop_No_Int_Comp_Neither = No_Int_Comp_Neither/(Ans21d_Tot)
No_Int_Comp_Dist.append(Prop_No_Int_Comp_Neither)
No_Int_Comp_Ds = No_Int_Comp_AGDS.count("Disagree")
Prop_No_Int_Comp_Ds = No_Int_Comp_Ds/(Ans21d_Tot)
No_Int_Comp_Dist.append(Prop_No_Int_Comp_Ds)
#disgaree is a typo in the results
No_Int_Comp_Ds = No_Int_Comp_AGDS.count("Strongly disgaree")
Prop_No_Int_Comp_Ds = No_Back_Comp_Ds/(Ans21d_Tot)
No_Int_Comp_Dist.append(Prop_No_Int_Comp_Ds)
print(No_Int_Comp_Dist)
# Out:
# [0.02702702702702703, 0.06633906633906633, 0.21621621621621623, 0.40294840294840295, 0.14004914004914004]

# %%
Ans21d = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21d = [1,2,3,4,5]
Ans21d_dist = No_Int_Comp_Dist
plt.xticks(Tick21d, Ans21d, rotation=45)
plt.bar(Tick21d, Ans21d_dist)
plt.title('I Have No Interest in Computational Physics')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
No_Rm_Comp_AGDS = []
#Collumn DP
for row in data.values[:,119]:
    No_Rm_Comp_AGDS.append(row)
#Agreement with the statement I have no interest in computational physics
Ans21e_Tot = No_Rm_Comp_AGDS.count("Strongly agree")+No_Rm_Comp_AGDS.count("Agree")+No_Rm_Comp_AGDS.count("Neither agree nor disagree")+No_Rm_Comp_AGDS.count("Disagree")+No_Rm_Comp_AGDS.count("Strongly disgaree")
No_Rm_Comp_Dist = []
No_Rm_Comp_Str_Ag = No_Rm_Comp_AGDS.count("Strongly agree")
Prop_No_Rm_Comp_Str_Ag = No_Rm_Comp_Str_Ag/(Ans21e_Tot)
No_Rm_Comp_Dist.append(Prop_No_Rm_Comp_Str_Ag)
No_Rm_Comp_Ag = No_Rm_Comp_AGDS.count("Agree")
Prop_No_Rm_Comp_Ag = No_Rm_Comp_Ag/(Ans21e_Tot)
No_Rm_Comp_Dist.append(Prop_No_Rm_Comp_Ag)
No_Rm_Comp_Neither = No_Rm_Comp_AGDS.count("Neither agree nor disagree")
Prop_No_Rm_Comp_Neither = No_Rm_Comp_Neither/(Ans21e_Tot)
No_Rm_Comp_Dist.append(Prop_No_Rm_Comp_Neither)
No_Rm_Comp_Ds = No_Rm_Comp_AGDS.count("Disagree")
Prop_No_Rm_Comp_Ds = No_Rm_Comp_Ds/(Ans21e_Tot)
No_Rm_Comp_Dist.append(Prop_No_Rm_Comp_Ds)
#disgaree is a typo in the results
No_Rm_Comp_Ds = No_Rm_Comp_AGDS.count("Strongly disgaree")
Prop_No_Rm_Comp_Ds = No_Rm_Comp_Ds/(Ans21e_Tot)
No_Rm_Comp_Dist.append(Prop_No_Rm_Comp_Ds)
print(No_Rm_Comp_Dist)
# Out:
# [0.22303921568627452, 0.34068627450980393, 0.2426470588235294, 0.14705882352941177, 0.04656862745098039]

# %%
Ans21e = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21e = [1,2,3,4,5]
Ans21e_dist = No_Rm_Comp_Dist
plt.xticks(Tick21e, Ans21e, rotation=45)
plt.bar(Tick21e, Ans21e_dist)
plt.title('There is not Enough Space for Computational Modeling')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
No_Sup_Comp_AGDS = []
#Collumn DQ
for row in data.values[:,120]:
    No_Sup_Comp_AGDS.append(row)
#Agreement with the statement There is no institutional support for me to learn computational methods.
Ans21f_Tot = No_Sup_Comp_AGDS.count("Strongly agree")+No_Sup_Comp_AGDS.count("Agree")+No_Sup_Comp_AGDS.count("Neither agree nor disagree")+No_Sup_Comp_AGDS.count("Disagree")+No_Sup_Comp_AGDS.count("Strongly disgaree")
No_Sup_Comp_Dist = []
No_Sup_Comp_Str_Ag = No_Sup_Comp_AGDS.count("Strongly agree")
Prop_No_Sup_Comp_Str_Ag = No_Sup_Comp_Str_Ag/(Ans21f_Tot)
No_Sup_Comp_Dist.append(Prop_No_Sup_Comp_Str_Ag)
No_Sup_Comp_Ag = No_Sup_Comp_AGDS.count("Agree")
Prop_No_Sup_Comp_Ag = No_Sup_Comp_Ag/(Ans21f_Tot)
No_Sup_Comp_Dist.append(Prop_No_Sup_Comp_Ag)
No_Sup_Comp_Neither = No_Sup_Comp_AGDS.count("Neither agree nor disagree")
Prop_No_Sup_Comp_Neither = No_Sup_Comp_Neither/(Ans21f_Tot)
No_Sup_Comp_Dist.append(Prop_No_Sup_Comp_Neither)
No_Sup_Comp_Ds = No_Sup_Comp_AGDS.count("Disagree")
Prop_No_Sup_Comp_Ds = No_Sup_Comp_Ds/(Ans21f_Tot)
No_Sup_Comp_Dist.append(Prop_No_Sup_Comp_Ds)
#disgaree is a typo in the results
No_Sup_Comp_Ds = No_Sup_Comp_AGDS.count("Strongly disgaree")
Prop_No_Sup_Comp_Ds = No_Sup_Comp_Ds/(Ans21f_Tot)
No_Sup_Comp_Dist.append(Prop_No_Sup_Comp_Ds)
print(No_Sup_Comp_Dist)
# Out:
# [0.10591133004926108, 0.19950738916256158, 0.3817733990147783, 0.22660098522167488, 0.08620689655172414]

# %%
Ans21f = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21f = [1,2,3,4,5]
Ans21f_dist = No_Sup_Comp_Dist
plt.xticks(Tick21f, Ans21f, rotation=45)
plt.bar(Tick21f, Ans21f_dist)
plt.title('There is Institutional Support to learn Computational Modeling')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Ins_Res_Comp_AGDS = []
#Collumn DR
for row in data.values[:,121]:
    Ins_Res_Comp_AGDS.append(row)
#Agreement with the statement There is institutional resistance to computational physics
Ans21g_Tot = Ins_Res_Comp_AGDS.count("Strongly agree")+Ins_Res_Comp_AGDS.count("Agree")+Ins_Res_Comp_AGDS.count("Neither agree nor disagree")+Ins_Res_Comp_AGDS.count("Disagree")+Ins_Res_Comp_AGDS.count("Strongly disgaree")
Ins_Res_Comp_Dist = []
Ins_Res_Comp_Str_Ag = Ins_Res_Comp_AGDS.count("Strongly agree")
Prop_Ins_Res_Comp_Str_Ag = Ins_Res_Comp_Str_Ag/(Ans21g_Tot)
Ins_Res_Comp_Dist.append(Prop_Ins_Res_Comp_Str_Ag)
Ins_Res_Comp_Ag = Ins_Res_Comp_AGDS.count("Agree")
Prop_Ins_Res_Comp_Ag = Ins_Res_Comp_Ag/(Ans21g_Tot)
Ins_Res_Comp_Dist.append(Prop_Ins_Res_Comp_Ag)
Ins_Res_Comp_Neither = Ins_Res_Comp_AGDS.count("Neither agree nor disagree")
Prop_Ins_Res_Comp_Neither = Ins_Res_Comp_Neither/(Ans21g_Tot)
Ins_Res_Comp_Dist.append(Prop_Ins_Res_Comp_Neither)
Ins_Res_Comp_Ds = Ins_Res_Comp_AGDS.count("Disagree")
Prop_Ins_Res_Comp_Ds = Ins_Res_Comp_Ds/(Ans21g_Tot)
Ins_Res_Comp_Dist.append(Prop_Ins_Res_Comp_Ds)
#disgaree is a typo in the results
Ins_Res_Comp_Ds = Ins_Res_Comp_AGDS.count("Strongly disgaree")
Prop_Ins_Res_Comp_Ds = Ins_Res_Comp_Ds/(Ans21g_Tot)
Ins_Res_Comp_Dist.append(Prop_Ins_Res_Comp_Ds)
print(Ins_Res_Comp_Dist)
# Out:
# [0.012437810945273632, 0.04228855721393035, 0.32587064676616917, 0.4129353233830846, 0.2064676616915423]

# %%
Ans21g = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21g = [1,2,3,4,5]
Ans21g_dist = Ins_Res_Comp_Dist
plt.xticks(Tick21g, Ans21g, rotation=45)
plt.bar(Tick21g, Ans21g_dist)
plt.title('There is Institutional Resistence to Computational Modeling')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Und_Res_Comp_AGDS = []
#Collumn DS
for row in data.values[:,122]:
    Und_Res_Comp_AGDS.append(row)
#Agreement with the statement There is resistance from undergraduate students to including computation in physics
Ans21h_Tot = Und_Res_Comp_AGDS.count("Strongly agree")+Und_Res_Comp_AGDS.count("Agree")+Und_Res_Comp_AGDS.count("Neither agree nor disagree")+Und_Res_Comp_AGDS.count("Disagree")+Und_Res_Comp_AGDS.count("Strongly disgaree")
Und_Res_Comp_Dist = []
Und_Res_Comp_Str_Ag = Und_Res_Comp_AGDS.count("Strongly agree")
Prop_Und_Res_Comp_Str_Ag = Und_Res_Comp_Str_Ag/(Ans21h_Tot)
Und_Res_Comp_Dist.append(Prop_Und_Res_Comp_Str_Ag)
Und_Res_Comp_Ag = Und_Res_Comp_AGDS.count("Agree")
Prop_Und_Res_Comp_Ag = Und_Res_Comp_Ag/(Ans21h_Tot)
Und_Res_Comp_Dist.append(Prop_Und_Res_Comp_Ag)
Und_Res_Comp_Neither = Und_Res_Comp_AGDS.count("Neither agree nor disagree")
Prop_Und_Res_Comp_Neither = Und_Res_Comp_Neither/(Ans21h_Tot)
Und_Res_Comp_Dist.append(Prop_Und_Res_Comp_Neither)
Und_Res_Comp_Ds = Und_Res_Comp_AGDS.count("Disagree")
Prop_Und_Res_Comp_Ds = Und_Res_Comp_Ds/(Ans21h_Tot)
Und_Res_Comp_Dist.append(Prop_Und_Res_Comp_Ds)
#disgaree is a typo in the results
Und_Res_Comp_Ds = Und_Res_Comp_AGDS.count("Strongly disgaree")
Prop_Und_Res_Comp_Ds = Und_Res_Comp_Ds/(Ans21h_Tot)
Und_Res_Comp_Dist.append(Prop_Und_Res_Comp_Ds)
print(Und_Res_Comp_Dist)
# Out:
# [0.0225, 0.0975, 0.3925, 0.3425, 0.145]

# %%
Ans21h = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21h = [1,2,3,4,5]
Ans21h_dist = Und_Res_Comp_Dist
plt.xticks(Tick21h, Ans21h, rotation=45)
plt.bar(Tick21h, Ans21h_dist)
plt.title('There is Resistence from Undergraduate Students to Computational Modeling')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %%
Stu_Learn_Else_AGDS = []
#Collumn DT
for row in data.values[:,123]:
    Stu_Learn_Else_AGDS.append(row)
#Agreement with the statement Students learn computational physics elsewhere
Ans21i_Tot = Stu_Learn_Else_AGDS.count("Strongly agree")+Stu_Learn_Else_AGDS.count("Agree")+Stu_Learn_Else_AGDS.count("Neither agree nor disagree")+Stu_Learn_Else_AGDS.count("Disagree")+Stu_Learn_Else_AGDS.count("Strongly disgaree")
Stu_Learn_Else_Dist = []
Stu_Learn_Else_Str_Ag = Stu_Learn_Else_AGDS.count("Strongly agree")
Prop_Stu_Learn_Else_Str_Ag = Stu_Learn_Else_Str_Ag/(Ans21i_Tot)
Stu_Learn_Else_Dist.append(Prop_Stu_Learn_Else_Str_Ag)
Stu_Learn_Else_Ag = Stu_Learn_Else_AGDS.count("Agree")
Prop_Stu_Learn_Else_Ag = Stu_Learn_Else_Ag/(Ans21i_Tot)
Stu_Learn_Else_Dist.append(Prop_Stu_Learn_Else_Ag)
Stu_Learn_Else_Neither = Stu_Learn_Else_AGDS.count("Neither agree nor disagree")
Prop_Stu_Learn_Else_Neither = Stu_Learn_Else_Neither/(Ans21i_Tot)
Stu_Learn_Else_Dist.append(Prop_Stu_Learn_Else_Neither)
Stu_Learn_Else_Ds = Stu_Learn_Else_AGDS.count("Disagree")
Prop_Stu_Learn_Else_Ds = Stu_Learn_Else_Ds/(Ans21i_Tot)
Stu_Learn_Else_Dist.append(Prop_Stu_Learn_Else_Ds)
#disgaree is a typo in the results
Stu_Learn_Else_Ds = Stu_Learn_Else_AGDS.count("Strongly disgaree")
Prop_Stu_Learn_Else_Ds = Stu_Learn_Else_Ds/(Ans21i_Tot)
Stu_Learn_Else_Dist.append(Prop_Und_Res_Comp_Ds)
print(Stu_Learn_Else_Dist)
# Out:
# [0.05392156862745098, 0.2696078431372549, 0.3627450980392157, 0.2181372549019608, 0.145]

# %%
Ans21i = ['Strongly Agree', 'Agree', 'Neither', 'Disagree', 'Strongly Disagree']
Tick21i = [1,2,3,4,5]
Ans21i_dist = Stu_Learn_Else_Dist
plt.xticks(Tick21i, Ans21i, rotation=45)
plt.bar(Tick21i, Ans21i_dist)
plt.title('Students Learn Computational Modeling Elsewhere')
plt.ylabel('Proportion')
plt.xlabel('Agreement with Statement')

# %% [markdown]
# ## Question 22
# Rate the degree to which you agree or disagree with the following statements. For the following questions we would like to understand your personal perspective of the role of computation in physics.

# %%
# Column DU column 124   I think that computation is important for undergraduate physics research.
Computation_Important_Research = []
for row in data.values[:,124]:
    Computation_Important_Research.append(row)
Computation_Important_Research_Strongly_Agree = Computation_Important_Research.count("Strongly agree")
Computation_Important_Research_Agree= Computation_Important_Research.count("Agree")
Computation_Important_Research_Neither= Computation_Important_Research.count("Neither agree nor disagree")
Computation_Important_Research_Disagree= Computation_Important_Research.count("Disagree")
Computation_Important_Research_Strongly_Disagree= Computation_Important_Research.count("Strongly disgaree")
Answered_10=Computation_Important_Research_Strongly_Agree+Computation_Important_Research_Agree+Computation_Important_Research_Neither+Computation_Important_Research_Disagree+Computation_Important_Research_Strongly_Disagree
print(Answered_10,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Important_Research_Strongly_Agree,Computation_Important_Research_Agree,Computation_Important_Research_Neither,Computation_Important_Research_Disagree,Computation_Important_Research_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('I think that computation is important for undergraduate physics research')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DV column 125   I think that learning computation is important for undergraduate physics majors.
Computation_Important_Physics_Majors = []
for row in data.values[:,125]:
    Computation_Important_Physics_Majors.append(row)
Computation_Important_Physics_Majors_Strongly_Agree = Computation_Important_Physics_Majors.count("Strongly agree")
Computation_Important_Physics_Majors_Agree= Computation_Important_Physics_Majors.count("Agree")
Computation_Important_Physics_Majors_Neither= Computation_Important_Physics_Majors.count("Neither agree nor disagree")
Computation_Important_Physics_Majors_Disagree= Computation_Important_Physics_Majors.count("Disagree")
Computation_Important_Physics_Majors_Strongly_Disagree= Computation_Important_Physics_Majors.count("Strongly disgaree")
Answered_11=Computation_Important_Physics_Majors_Strongly_Agree+Computation_Important_Physics_Majors_Agree+Computation_Important_Physics_Majors_Neither+Computation_Important_Physics_Majors_Disagree+Computation_Important_Physics_Majors_Strongly_Disagree
print(Answered_11,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Important_Physics_Majors_Strongly_Agree,Computation_Important_Physics_Majors_Agree,Computation_Important_Physics_Majors_Neither,Computation_Important_Physics_Majors_Disagree,Computation_Important_Physics_Majors_Strongly_Disagree]
fig = plt.figure(figsize=(15,9))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('I think that learning computation is important for undergraduate physics majors.')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DW column 126  The undergraduate program in my department values instructing undergraduate physics majors in computation.
Department_Values_Computation = []
for row in data.values[:,126]:
    Department_Values_Computation.append(row)
Department_Values_Computation_Strongly_Agree = Department_Values_Computation.count("Strongly agree")
Department_Values_Computation_Agree= Department_Values_Computation.count("Agree")
Department_Values_Computation_Neither= Department_Values_Computation.count("Neither agree nor disagree")
Department_Values_Computation_Disagree= Department_Values_Computation.count("Disagree")
Department_Values_Computation_Strongly_Disagree= Department_Values_Computation.count("Strongly disgaree")
Answered_12=Department_Values_Computation_Strongly_Agree+Department_Values_Computation_Agree+Department_Values_Computation_Neither+Department_Values_Computation_Disagree+Department_Values_Computation_Strongly_Disagree
print(Answered_12,'This many people answered the question')
x=[1,2,3,4,5]
y=[Department_Values_Computation_Strongly_Agree,Department_Values_Computation_Agree,Department_Values_Computation_Neither,Department_Values_Computation_Disagree,Department_Values_Computation_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('undergraduate program in my department values instructing undergraduate physics majors in computation')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 23
# With regard to your personal research, rate the degree to which you agree or disagree with the following statements:

# %%
# Column DX column 127  Computation can solve unsolvable (analytical) problems.
Computation_Solves_Unsolvable = []
for row in data.values[:,127]:
    Computation_Solves_Unsolvable.append(row)
Computation_Solves_Unsolvable_Strongly_Agree = Computation_Solves_Unsolvable.count("Strongly agree")
Computation_Solves_Unsolvable_Agree= Computation_Solves_Unsolvable.count("Agree")
Computation_Solves_Unsolvable_Neither= Computation_Solves_Unsolvable.count("Neither agree nor disagree")
Computation_Solves_Unsolvable_Disagree= Computation_Solves_Unsolvable.count("Disagree")
Computation_Solves_Unsolvable_Strongly_Disagree= Computation_Solves_Unsolvable.count("Strongly disgaree")
Answered_13=Computation_Solves_Unsolvable_Strongly_Agree+Computation_Solves_Unsolvable_Agree+Computation_Solves_Unsolvable_Neither+Computation_Solves_Unsolvable_Disagree+Computation_Solves_Unsolvable_Strongly_Disagree
print(Answered_13,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Solves_Unsolvable_Strongly_Agree,Computation_Solves_Unsolvable_Agree,Computation_Solves_Unsolvable_Neither,Computation_Solves_Unsolvable_Disagree,Computation_Solves_Unsolvable_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation can solve unsolvable (analytical) problems')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DY column 128  Computation is generalizable to many different kinds of problems.
Computation_Generalized = []
for row in data.values[:,128]:
    Computation_Generalized.append(row)
Computation_Generalized_Strongly_Agree = Computation_Generalized.count("Strongly agree")
Computation_Generalized_Agree= Computation_Generalized.count("Agree")
Computation_Generalized_Neither= Computation_Generalized.count("Neither agree nor disagree")
Computation_Generalized_Disagree= Computation_Generalized.count("Disagree")
Computation_Generalized_Strongly_Disagree= Computation_Generalized.count("Strongly disgaree")
Answered_14=Computation_Generalized_Strongly_Agree+Computation_Generalized_Agree+Computation_Generalized_Neither+Computation_Generalized_Disagree+Computation_Generalized_Strongly_Disagree
print(Answered_14,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Generalized_Strongly_Agree,Computation_Generalized_Agree,Computation_Generalized_Neither,Computation_Generalized_Disagree,Computation_Generalized_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation is generalizable to many different kinds of problems.')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column DZ column 129  Computation affords visualization (graphs, animations) of solutions.
Computation_Affords_Visualization = []
for row in data.values[:,129]:
    Computation_Affords_Visualization.append(row)
Computation_Affords_Visualization_Strongly_Agree = Computation_Affords_Visualization.count("Strongly agree")
Computation_Affords_Visualization_Agree= Computation_Affords_Visualization.count("Agree")
Computation_Affords_Visualization_Neither= Computation_Affords_Visualization.count("Neither agree nor disagree")
Computation_Affords_Visualization_Disagree= Computation_Affords_Visualization.count("Disagree")
Computation_Affords_Visualization_Strongly_Disagree= Computation_Affords_Visualization.count("Strongly disgaree")
Answered_15=Computation_Affords_Visualization_Strongly_Agree+Computation_Affords_Visualization_Agree+Computation_Affords_Visualization_Neither+Computation_Affords_Visualization_Disagree+Computation_Affords_Visualization_Strongly_Disagree
print(Answered_15,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Affords_Visualization_Strongly_Agree,Computation_Affords_Visualization_Agree,Computation_Affords_Visualization_Neither,Computation_Affords_Visualization_Disagree,Computation_Affords_Visualization_Strongly_Disagree]
fig = plt.figure(figsize=(15,9))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation affords visualization (graphs, animations) of solutions')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EA column 130  Computational research is attractive to funding agencies.
Computation_Attractive = []
for row in data.values[:,130]:
    Computation_Attractive.append(row)
Computation_Attractive_Strongly_Agree = Computation_Attractive.count("Strongly agree")
Computation_Attractive_Agree= Computation_Attractive.count("Agree")
Computation_Attractive_Neither= Computation_Attractive.count("Neither agree nor disagree")
Computation_Attractive_Disagree= Computation_Attractive.count("Disagree")
Computation_Attractive_Strongly_Disagree= Computation_Attractive.count("Strongly disgaree")
Answered_15=Computation_Attractive_Strongly_Agree+Computation_Attractive_Agree+Computation_Attractive_Neither+Computation_Attractive_Disagree+Computation_Attractive_Strongly_Disagree
print(Answered_15,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Attractive_Strongly_Agree,Computation_Attractive_Agree,Computation_Attractive_Neither,Computation_Attractive_Disagree,Computation_Attractive_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computational research is attractive to funding agencies.')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 24
# Rate the degree to which you agree or disagree with the following aspects of learning computation:

# %%
# Column EB column 131  Computation is used in many science and engineering applications.
Computation_Science_Applications = []
for row in data.values[:,131]:
    Computation_Science_Applications.append(row)
Computation_Science_Applications_Strongly_Agree = Computation_Science_Applications.count("Strongly agree")
Computation_Science_Applications_Agree= Computation_Science_Applications.count("Agree")
Computation_Science_Applications_Neither= Computation_Science_Applications.count("Neither agree nor disagree")
Computation_Science_Applications_Disagree= Computation_Science_Applications.count("Disagree")
Computation_Science_Applications_Strongly_Disagree= Computation_Science_Applications.count("Strongly disgaree")
Answered_16=Computation_Science_Applications_Strongly_Agree+Computation_Science_Applications_Agree+Computation_Science_Applications_Neither+Computation_Science_Applications_Disagree+Computation_Science_Applications_Strongly_Disagree
print(Answered_16,'This many people answered the question')
x=[1,2,3,4,5]
y=[Computation_Science_Applications_Strongly_Agree,Computation_Science_Applications_Agree,Computation_Science_Applications_Neither,Computation_Science_Applications_Disagree,Computation_Science_Applications_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation is used in many science and engineering applications')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EC column 132  Computation can solve unsolvable (analytical) problems.
Learning_Computation_Solve_Unsolvable = []
for row in data.values[:,132]:
    Learning_Computation_Solve_Unsolvable.append(row)
Learning_Computation_Solve_Unsolvable_Strongly_Agree = Learning_Computation_Solve_Unsolvable.count("Strongly agree")
Learning_Computation_Solve_Unsolvable_Agree= Learning_Computation_Solve_Unsolvable.count("Agree")
Learning_Computation_Solve_Unsolvable_Neither= Learning_Computation_Solve_Unsolvable.count("Neither agree nor disagree")
Learning_Computation_Solve_Unsolvable_Disagree= Learning_Computation_Solve_Unsolvable.count("Disagree")
Learning_Computation_Solve_Unsolvable_Strongly_Disagree= Learning_Computation_Solve_Unsolvable.count("Strongly disgaree")
Answered_17=Learning_Computation_Solve_Unsolvable_Strongly_Agree+Learning_Computation_Solve_Unsolvable_Agree+Learning_Computation_Solve_Unsolvable_Neither+Learning_Computation_Solve_Unsolvable_Disagree+Learning_Computation_Solve_Unsolvable_Strongly_Disagree
print(Answered_17,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_Solve_Unsolvable_Strongly_Agree,Learning_Computation_Solve_Unsolvable_Agree,Learning_Computation_Solve_Unsolvable_Neither,Learning_Computation_Solve_Unsolvable_Disagree,Learning_Computation_Solve_Unsolvable_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation can solve unsolvable (analytical) problems')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column ED column 133  Computation is generalizable to many different kinds of problems.
Learning_Computation_Generalizable = []
for row in data.values[:,133]:
    Learning_Computation_Generalizable.append(row)
Learning_Computation_Generalizable_Strongly_Agree = Learning_Computation_Generalizable.count("Strongly agree")
Learning_Computation_Generalizable_Agree= Learning_Computation_Generalizable.count("Agree")
Learning_Computation_Generalizable_Neither= Learning_Computation_Generalizable.count("Neither agree nor disagree")
Learning_Computation_Generalizable_Disagree= Learning_Computation_Generalizable.count("Disagree")
Learning_Computation_Generalizable_Strongly_Disagree= Learning_Computation_Generalizable.count("Strongly disgaree")
Answered_18=Learning_Computation_Generalizable_Strongly_Agree+Learning_Computation_Generalizable_Agree+Learning_Computation_Generalizable_Neither+Learning_Computation_Generalizable_Disagree+Learning_Computation_Generalizable_Strongly_Disagree
print(Answered_18,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_Generalizable_Strongly_Agree,Learning_Computation_Generalizable_Agree,Learning_Computation_Generalizable_Neither,Learning_Computation_Generalizable_Disagree,Learning_Computation_Generalizable_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation is generalizable to many different kinds of problems.')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EE column 134  Computation affords visualization (graphs, animations) of solutions.
Learning_Computation_Affords_Visualization = []
for row in data.values[:,134]:
    Learning_Computation_Affords_Visualization.append(row)
Learning_Computation_Affords_Visualization_Strongly_Agree = Learning_Computation_Affords_Visualization.count("Strongly agree")
Learning_Computation_Affords_Visualization_Agree= Learning_Computation_Affords_Visualization.count("Agree")
Learning_Computation_Affords_Visualization_Neither= Learning_Computation_Affords_Visualization.count("Neither agree nor disagree")
Learning_Computation_Affords_Visualization_Disagree= Learning_Computation_Affords_Visualization.count("Disagree")
Learning_Computation_Affords_Visualization_Strongly_Disagree= Learning_Computation_Affords_Visualization.count("Strongly disgaree")
Answered_19=Learning_Computation_Affords_Visualization_Strongly_Agree+Learning_Computation_Affords_Visualization_Agree+Learning_Computation_Affords_Visualization_Neither+Learning_Computation_Affords_Visualization_Disagree+Learning_Computation_Affords_Visualization_Strongly_Disagree
print(Answered_19,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_Affords_Visualization_Strongly_Agree,Learning_Computation_Affords_Visualization_Agree,Learning_Computation_Affords_Visualization_Neither,Learning_Computation_Affords_Visualization_Disagree,Learning_Computation_Affords_Visualization_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation affords visualization (graphs, animations) of solutions')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EF column 135  Computation focuses student's attention on modeling the important physics of a problem.
Learning_Computation_Important = []
for row in data.values[:,135]:
    Learning_Computation_Important.append(row)
Learning_Computation_Important_Strongly_Agree = Learning_Computation_Important.count("Strongly agree")
Learning_Computation_Important_Agree= Learning_Computation_Important.count("Agree")
Learning_Computation_Important_Neither= Learning_Computation_Important.count("Neither agree nor disagree")
Learning_Computation_Important_Disagree= Learning_Computation_Important.count("Disagree")
Learning_Computation_Important_Strongly_Disagree= Learning_Computation_Important.count("Strongly disgaree")
Answered_20=Learning_Computation_Important_Strongly_Agree+Learning_Computation_Important_Agree+Learning_Computation_Important_Neither+Learning_Computation_Important_Disagree+Learning_Computation_Important_Strongly_Disagree
print(Answered_20,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_Important_Strongly_Agree,Learning_Computation_Important_Agree,Learning_Computation_Important_Neither,Learning_Computation_Important_Disagree,Learning_Computation_Important_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation focuses students attention on modeling the important physics of a problem.')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EG column 136  Learning computation prepares students for the modern scientific workforce.
Learning_Computation_Workforce = []
for row in data.values[:,136]:
    Learning_Computation_Workforce.append(row)
Learning_Computation_Workforce_Strongly_Agree = Learning_Computation_Workforce.count("Strongly agree")
Learning_Computation_Workforce_Agree= Learning_Computation_Workforce.count("Agree")
Learning_Computation_Workforce_Neither= Learning_Computation_Workforce.count("Neither agree nor disagree")
Learning_Computation_Workforce_Disagree= Learning_Computation_Workforce.count("Disagree")
Learning_Computation_Workforce_Strongly_Disagree= Learning_Computation_Workforce.count("Strongly disgaree")
Answered_21=Learning_Computation_Workforce_Strongly_Agree+Learning_Computation_Workforce_Agree+Learning_Computation_Workforce_Neither+Learning_Computation_Workforce_Disagree+Learning_Computation_Workforce_Strongly_Disagree
print(Answered_21,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_Workforce_Strongly_Agree,Learning_Computation_Workforce_Agree,Learning_Computation_Workforce_Neither,Learning_Computation_Workforce_Disagree,Learning_Computation_Workforce_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Learning computation prepares students for the modern scientific workforce')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EH column 137  Computation allows me to bring new physics into the classroom that I otherwise couldn't.
Learning_Computation_New_Physics = []
for row in data.values[:,137]:
    Learning_Computation_New_Physics.append(row)
Learning_Computation_New_Physics_Strongly_Agree = Learning_Computation_New_Physics.count("Strongly agree")
Learning_Computation_New_Physics_Agree= Learning_Computation_New_Physics.count("Agree")
Learning_Computation_New_Physics_Neither= Learning_Computation_New_Physics.count("Neither agree nor disagree")
Learning_Computation_New_Physics_Disagree= Learning_Computation_New_Physics.count("Disagree")
Learning_Computation_New_Physics_Strongly_Disagree= Learning_Computation_New_Physics.count("Strongly disgaree")
Answered_22=Learning_Computation_New_Physics_Strongly_Agree+Learning_Computation_New_Physics_Agree+Learning_Computation_New_Physics_Neither+Learning_Computation_New_Physics_Disagree+Learning_Computation_New_Physics_Strongly_Disagree
print(Answered_22,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_New_Physics_Strongly_Agree,Learning_Computation_New_Physics_Agree,Learning_Computation_New_Physics_Neither,Learning_Computation_New_Physics_Disagree,Learning_Computation_New_Physics_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation allows me to bring new physics into the classroom that I otherwise couldnt')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %%
# Column EI column 138   Computation allows me to bring new problems into the classroom that I otherwise couldn't.
Learning_Computation_New_Problems = []
for row in data.values[:,138]:
    Learning_Computation_New_Problems.append(row)
Learning_Computation_New_Problems_Strongly_Agree = Learning_Computation_New_Problems.count("Strongly agree")
Learning_Computation_New_Problems_Agree= Learning_Computation_New_Problems.count("Agree")
Learning_Computation_New_Problems_Neither= Learning_Computation_New_Problems.count("Neither agree nor disagree")
Learning_Computation_New_Problems_Disagree= Learning_Computation_New_Problems.count("Disagree")
Learning_Computation_New_Problems_Strongly_Disagree= Learning_Computation_New_Problems.count("Strongly disgaree")
Answered_23=Learning_Computation_New_Problems_Strongly_Agree+Learning_Computation_New_Problems_Agree+Learning_Computation_New_Problems_Neither+Learning_Computation_New_Problems_Disagree+Learning_Computation_New_Problems_Strongly_Disagree
print(Answered_23,'This many people answered the question')
x=[1,2,3,4,5]
y=[Learning_Computation_New_Problems_Strongly_Agree,Learning_Computation_New_Problems_Agree,Learning_Computation_New_Problems_Neither,Learning_Computation_New_Problems_Disagree,Learning_Computation_New_Problems_Strongly_Disagree]
fig = plt.figure(figsize=(15,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Computation allows me to bring new problems into the classroom that I otherwise couldnt')
labels=['Strongly Agree','Agree','Neither Agree Nor Disagree','Disagree','Strongly Disgaree']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 25
# What level of consideration does your department give to undergraduate instruction in computation when making decisions regarding:

# %%
# Column EJ column 139  Hiring new faculty members
Consideration_Hiring = []
for row in data.values[:,139]:
    Consideration_Hiring.append(row)
Consideration_Hiring_Very_Strong = Consideration_Hiring.count("Very strong consideration")
Consideration_Hiring_Strong= Consideration_Hiring.count("Strong consideration")
Consideration_Hiring_Some= Consideration_Hiring.count("Some consideration")
Consideration_Hiring_None= Consideration_Hiring.count("No consideration")
Answered_24=Consideration_Hiring_Very_Strong+Consideration_Hiring_Strong+Consideration_Hiring_Some+Consideration_Hiring_None
print(Answered_24,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Hiring_Very_Strong,Consideration_Hiring_Strong,Consideration_Hiring_Some,Consideration_Hiring_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for hiring new faculty members')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EK column 140  Tenure and promotion decisions
Consideration_Tenure = []
for row in data.values[:,140]:
    Consideration_Tenure.append(row)
Consideration_Tenure_Very_Strong = Consideration_Tenure.count("Very strong consideration")
Consideration_Tenure_Strong= Consideration_Tenure.count("Strong consideration")
Consideration_Tenure_Some= Consideration_Tenure.count("Some consideration")
Consideration_Tenure_None= Consideration_Tenure.count("No consideration")
Answered_25=Consideration_Tenure_Very_Strong+Consideration_Tenure_Strong+Consideration_Tenure_Some+Consideration_Tenure_None
print(Answered_25,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Tenure_Very_Strong,Consideration_Tenure_Strong,Consideration_Tenure_Some,Consideration_Tenure_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Tenure and promotion decisions')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EL column 141  Allocating resources for programs or tracks within the undergraduate major
Consideration_Resources_Programs = []
for row in data.values[:,141]:
    Consideration_Resources_Programs.append(row)
Consideration_Resources_Programs_Very_Strong = Consideration_Resources_Programs.count("Very strong consideration")
Consideration_Resources_Programs_Strong= Consideration_Resources_Programs.count("Strong consideration")
Consideration_Resources_Programs_Some= Consideration_Resources_Programs.count("Some consideration")
Consideration_Resources_Programs_None= Consideration_Resources_Programs.count("No consideration")
Answered_26=Consideration_Resources_Programs_Very_Strong+Consideration_Resources_Programs_Strong+Consideration_Resources_Programs_Some+Consideration_Resources_Programs_None
print(Answered_26,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Resources_Programs_Very_Strong,Consideration_Resources_Programs_Strong,Consideration_Resources_Programs_Some,Consideration_Resources_Programs_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Allocating resources for programs')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EM column 142  Allocating resources for individual undergraduate courses
Consideration_Resources_Individual = []
for row in data.values[:,142]:
    Consideration_Resources_Individual.append(row)
Consideration_Resources_Individual_Very_Strong = Consideration_Resources_Individual.count("Very strong consideration")
Consideration_Resources_Individual_Strong= Consideration_Resources_Individual.count("Strong consideration")
Consideration_Resources_Individual_Some= Consideration_Resources_Individual.count("Some consideration")
Consideration_Resources_Individual_None= Consideration_Resources_Individual.count("No consideration")
Answered_27=Consideration_Resources_Individual_Very_Strong+Consideration_Resources_Individual_Strong+Consideration_Resources_Individual_Some+Consideration_Resources_Individual_None
print(Answered_27,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Resources_Individual_Very_Strong,Consideration_Resources_Individual_Strong,Consideration_Resources_Individual_Some,Consideration_Resources_Individual_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Allocating resources for individual courses')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EN column 143  Changing undergraduate service courses
Consideration_Service_Courses = []
for row in data.values[:,143]:
    Consideration_Service_Courses.append(row)
Consideration_Service_Courses_Very_Strong = Consideration_Service_Courses.count("Very strong consideration")
Consideration_Service_Courses_Strong= Consideration_Service_Courses.count("Strong consideration")
Consideration_Service_Courses_Some= Consideration_Service_Courses.count("Some consideration")
Consideration_Service_Courses_None= Consideration_Service_Courses.count("No consideration")
Answered_28=Consideration_Service_Courses_Very_Strong+Consideration_Service_Courses_Strong+Consideration_Service_Courses_Some+Consideration_Service_Courses_None
print(Answered_28,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Service_Courses_Very_Strong,Consideration_Service_Courses_Strong,Consideration_Service_Courses_Some,Consideration_Service_Courses_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Changing undergraduate service courses')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EO column 144  Changing courses for undergraduate majors
Consideration_Major_Courses = []
for row in data.values[:,144]:
    Consideration_Major_Courses.append(row)
Consideration_Major_Courses_Very_Strong = Consideration_Major_Courses.count("Very strong consideration")
Consideration_Major_Courses_Strong= Consideration_Major_Courses.count("Strong consideration")
Consideration_Major_Courses_Some= Consideration_Major_Courses.count("Some consideration")
Consideration_Major_Courses_None= Consideration_Major_Courses.count("No consideration")
Answered_29=Consideration_Major_Courses_Very_Strong+Consideration_Major_Courses_Strong+Consideration_Major_Courses_Some+Consideration_Major_Courses_None
print(Answered_29,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Major_Courses_Very_Strong,Consideration_Major_Courses_Strong,Consideration_Major_Courses_Some,Consideration_Major_Courses_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Changing courses for undergraduate majors')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EP column 145  Releasing time for faculty to develop computation in undergraduate courses
Consideration_Releasing_Time = []
for row in data.values[:,145]:
    Consideration_Releasing_Time.append(row)
Consideration_Releasing_Time_Very_Strong = Consideration_Releasing_Time.count("Very strong consideration")
Consideration_Releasing_Time_Strong= Consideration_Releasing_Time.count("Strong consideration")
Consideration_Releasing_Time_Some= Consideration_Releasing_Time.count("Some consideration")
Consideration_Releasing_Time_None= Consideration_Releasing_Time.count("No consideration")
Answered_30=Consideration_Releasing_Time_Very_Strong+Consideration_Releasing_Time_Strong+Consideration_Releasing_Time_Some+Consideration_Releasing_Time_None
print(Answered_30,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Releasing_Time_Very_Strong,Consideration_Releasing_Time_Strong,Consideration_Releasing_Time_Some,Consideration_Releasing_Time_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Releasing time for faculty')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column EQ column 146  Pursuing university funding
Consideration_University_Funding = []
for row in data.values[:,146]:
    Consideration_University_Funding.append(row)
Consideration_University_Funding_Very_Strong = Consideration_University_Funding.count("Very strong consideration")
Consideration_University_Funding_Strong= Consideration_University_Funding.count("Strong consideration")
Consideration_University_Funding_Some= Consideration_University_Funding.count("Some consideration")
Consideration_University_Funding_None= Consideration_University_Funding.count("No consideration")
Answered_31=Consideration_University_Funding_Very_Strong+Consideration_University_Funding_Strong+Consideration_University_Funding_Some+Consideration_University_Funding_None
print(Answered_31,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_University_Funding_Very_Strong,Consideration_University_Funding_Strong,Consideration_University_Funding_Some,Consideration_University_Funding_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Pursuing university funding')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %%
# Column ER column 147  Pursuing grant funding
Consideration_Grant_Funding = []
for row in data.values[:,147]:
    Consideration_Grant_Funding.append(row)
Consideration_Grant_Funding_Very_Strong = Consideration_Grant_Funding.count("Very strong consideration")
Consideration_Grant_Funding_Strong= Consideration_Grant_Funding.count("Strong consideration")
Consideration_Grant_Funding_Some= Consideration_Grant_Funding.count("Some consideration")
Consideration_Grant_Funding_None= Consideration_Grant_Funding.count("No consideration")
Answered_32=Consideration_Grant_Funding_Very_Strong+Consideration_Grant_Funding_Strong+Consideration_Grant_Funding_Some+Consideration_Grant_Funding_None
print(Answered_32,'This many people answered the question')
x=[1,2,3,4]
y=[Consideration_Grant_Funding_Very_Strong,Consideration_Grant_Funding_Strong,Consideration_Grant_Funding_Some,Consideration_Grant_Funding_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Consideration for Pursuing grant funding')
labels=['Very Strong','Strong','Some','None']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 26
# Do you have concrete and actionable plans to increase your use of computation in your own undergraduate physics teaching in the next year?

# %%
#This is for column ES 148 
Plan_To_Increase_Computation = []
for row in data.values[:,148]:
    Plan_To_Increase_Computation.append(row)
Plan_To_Increase_Computation_Y = Plan_To_Increase_Computation.count("Yes") 
Percentage_Plan_To_Increase_Computation=100*Plan_To_Increase_Computation_Y/(Plan_To_Increase_Computation_Y+Plan_To_Increase_Computation.count("No"))
print("Of the",Plan_To_Increase_Computation_Y+Plan_To_Increase_Computation.count("No"),"people who answered this question",Percentage_Plan_To_Increase_Computation,"percent said they have a plan to implement computational modeling. That is",Plan_To_Increase_Computation_Y,"people.")
x=[1,2]
y=[Plan_To_Increase_Computation_Y,Plan_To_Increase_Computation.count("No")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Plans to increase computation in teaching?')
labels=['yes','no']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 27
# Please tell us about your perspective on the department's collective plans for the use of computational work in its undergraduate program:

# %%
# Column EU column 150  department plans
Department_Plans_Computation= []
for row in data.values[:,150]:
    Department_Plans_Computation.append(row)
Department_Plans_Computation_significant_Amount = Department_Plans_Computation.count("We are planning to add a significant amount of computation into our undergraduate program.")
Department_Plans_Computation_Some= Department_Plans_Computation.count("We are planning to add some computation into our undergraduate program.")
Department_Plans_Computation_Decrease= Department_Plans_Computation.count("We are planning to decrease the amount of computation in our undergraduate program.")
Department_Plans_Computation_None= Department_Plans_Computation.count("We have no plans to change how or whether we are using computation in our undergraduate program.")
Answered_33=Department_Plans_Computation_significant_Amount+Department_Plans_Computation_Some+Department_Plans_Computation_Decrease+Department_Plans_Computation_None
print(Answered_33,'This many people answered the question')
x=[1,2,3,4]
y=[Department_Plans_Computation_significant_Amount,Department_Plans_Computation_Some,Department_Plans_Computation_Decrease,Department_Plans_Computation_None]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('department plans on use of computational work')
labels=['Add significant amount','Add some','Decrease it','No plans']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 29
# What is your highest degree? 28 is free response

# %%
# Column EW column 152  highest degree?
Highest_Degree= []
for row in data.values[:,152]:
    Highest_Degree.append(row)
Highest_Degree_Masters= Highest_Degree.count("Masters")
Highest_Degree_PhD= Highest_Degree.count("PhD")
Highest_Degree_Other= Highest_Degree.count("Other")
Answered_34=Highest_Degree_Masters+Highest_Degree_PhD+Highest_Degree_Other
print(Answered_34,'This many people answered the question')
x=[1,2,3]
y=[Highest_Degree_Masters,Highest_Degree_PhD,Highest_Degree_Other]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Highest degree')
labels=['Masters','PhD','Other']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 30

# %%
Feild_High_Deg = []
#Collumn EX
for row in data.values[:,153]:
    Feild_High_Deg.append(row)
#In what Feild did you recieve your highest degree
Ans30_Tot = Feild_High_Deg.count("Mathematics")+Feild_High_Deg.count("Other")+Feild_High_Deg.count("Physics")+Feild_High_Deg.count("Physics Education")+Feild_High_Deg.count("Engineering")+Feild_High_Deg.count("Computer Science")+Feild_High_Deg.count("Materials Science")
Feild_High_Deg_Dist = []                                                                                                                                                                          
Feild_High_Deg_Phy = Feild_High_Deg.count("Physics")
Prop_Feild_High_Deg_Phy = Feild_High_Deg_Phy/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_Phy)
Feild_High_Deg_PhyEd = Feild_High_Deg.count("Physics Education")
Prop_Feild_High_Deg_PhyEd = Feild_High_Deg_PhyEd/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_PhyEd)
Feild_High_Deg_Eng = Feild_High_Deg.count("Engineering")
Prop_Feild_High_Deg_Eng = Feild_High_Deg_Eng/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_Eng)
Feild_High_Deg_CompSci = Feild_High_Deg.count("Computer Science")
Prop_Feild_High_Deg_CompSci = Feild_High_Deg_CompSci/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_CompSci)
Feild_High_Deg_MatSci = Feild_High_Deg.count("Materials Science")
Prop_Feild_High_Deg_MatSci = Feild_High_Deg_MatSci/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_MatSci)
Feild_High_Deg_Math = Feild_High_Deg.count("Mathematics")
Prop_Feild_High_Deg_Math = Feild_High_Deg_Math/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_Math)
Feild_High_Deg_Oth = Feild_High_Deg.count("Other")
Prop_Feild_High_Deg_Oth = Feild_High_Deg_Oth/(Ans30_Tot)
Feild_High_Deg_Dist.append(Prop_Feild_High_Deg_Oth)
print(Feild_High_Deg_Dist)
# Out:
# [0.82259767687434, 0.027455121436114043, 0.04118268215417107, 0.0, 0.0, 0.005279831045406547, 0.10348468848996832]

# %%
Ans30 = ['Physics', 'Physics Education', 'Engineering', 'Computer Science', 'Materials Science', 'Mathematics', 'Other']
Tick30 = [1,2,3,4,5,6,7]
Ans30_dist = Feild_High_Deg_Dist
plt.xticks(Tick30, Ans30, rotation=45)
plt.bar(Tick30, Ans30_dist)
plt.title('Highest Degree')
plt.ylabel('Proportion')
plt.xlabel('Feild')

# %% [markdown]
# ## Question 32
# How did you come to learn computation? 31 is sort of free response

# %%
#This is for column FA 156 Self Taught
Self_Taught = []
for row in data.values[:,156]:
    Self_Taught.append(row)
Self_Taught_Y = Self_Taught.count("Checked") 
Percentage_Self_Taught=100*Self_Taught_Y/(Self_Taught_Y+Self_Taught.count("Unchecked"))
print("Of the",Self_Taught_Y+Self_Taught.count("Unchecked"),"people who answered this question",Percentage_Self_Taught,"percent said they taught themself computation. That is",Self_Taught_Y,"people.")
x=[1,2]
y=[Self_Taught_Y,Self_Taught.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Self Taught?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FB 157 Informal on-the-job
Taught_On_Job = []
for row in data.values[:,157]:
    Taught_On_Job.append(row)
Taught_On_Job_Y = Taught_On_Job.count("Checked") 
Percentage_Taught_On_Job=100*Taught_On_Job_Y/(Taught_On_Job_Y+Taught_On_Job.count("Unchecked"))
print("Of the",Taught_On_Job_Y+Taught_On_Job.count("Unchecked"),"people who answered this question",Percentage_Taught_On_Job,"percent said they were taught on the job about computation. That is",Taught_On_Job_Y,"people.")
x=[1,2]
y=[Taught_On_Job_Y,Taught_On_Job.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Taught on job?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FC 158 Formal course(s)
Taught_Formally = []
for row in data.values[:,158]:
    Taught_Formally.append(row)
Taught_Formally_Y = Taught_Formally.count("Checked") 
Percentage_Taught_Formally=100*Taught_Formally_Y/(Taught_Formally_Y+Taught_Formally.count("Unchecked"))
print("Of the",Taught_Formally_Y+Taught_Formally.count("Unchecked"),"people who answered this question",Percentage_Taught_Formally,"percent said they were taught formally about computation. That is",Taught_Formally_Y,"people.")
x=[1,2]
y=[Taught_Formally_Y,Taught_Formally.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Taught formally?')
labels=['yes','no']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 33
# How do you personally use computation?

# %%
#This is for column FE 160 Exclusively for personal enrichment/use
Use_Exclusive = []
for row in data.values[:,160]:
    Use_Exclusive.append(row)
Use_Exclusive_Y = Use_Exclusive.count("Checked") 
Percentage_Use_Exclusive=100*Use_Exclusive_Y/(Use_Exclusive_Y+Use_Exclusive.count("Unchecked"))
print("Of the",Use_Exclusive_Y+Use_Exclusive.count("Unchecked"),"people who answered this question",Percentage_Use_Exclusive,"percent said they use computation exclusively for personal use. That is",Use_Exclusive_Y,"people.")
x=[1,2]
y=[Use_Exclusive_Y,Use_Exclusive.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Use exclusively personally?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FF 161 To enrich my courses for my undergraduate students
Enrich_Courses = []
for row in data.values[:,161]:
    Enrich_Courses.append(row)
Enrich_Courses_Y = Enrich_Courses.count("Checked") 
Percentage_Enrich_Courses=100*Enrich_Courses_Y/(Enrich_Courses_Y+Enrich_Courses.count("Unchecked"))
print("Of the",Enrich_Courses_Y+Enrich_Courses.count("Unchecked"),"people who answered this question",Percentage_Enrich_Courses,"percent said they use computation to enrich their undergraduate class. That is",Enrich_Courses_Y,"people.")
x=[1,2]
y=[Enrich_Courses_Y,Enrich_Courses.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Use to enrich classroom?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FG 162  In my research work
Personal_Research = []
for row in data.values[:,162]:
    Personal_Research.append(row)
Personal_Research_Y = Personal_Research.count("Checked") 
Percentage_Personal_Research=100*Personal_Research_Y/(Personal_Research_Y+Personal_Research.count("Unchecked"))
print("Of the",Personal_Research_Y+Personal_Research.count("Unchecked"),"people who answered this question",Percentage_Personal_Research,"percent said they use computation for personal research. That is",Personal_Research_Y,"people.")
x=[1,2]
y=[Personal_Research_Y,Personal_Research.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Personal research?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FH 163  To provide research experiences for my undergraduate students
Research_Experience = []
for row in data.values[:,163]:
    Research_Experience.append(row)
Research_Experience_Y = Research_Experience.count("Checked") 
Percentage_Research_Experience=100*Research_Experience_Y/(Research_Experience_Y+Research_Experience.count("Unchecked"))
print("Of the",Research_Experience_Y+Research_Experience.count("Unchecked"),"people who answered this question",Percentage_Research_Experience,"percent said they use computation for research experience for students. That is",Research_Experience_Y,"people.")
x=[1,2]
y=[Research_Experience_Y,Research_Experience.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('undergraduate research?')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#This is for column FI 164  I do not use computation
Not_Use_Computation = []
for row in data.values[:,164]:
    Not_Use_Computation.append(row)
Not_Use_Computation_Y = Not_Use_Computation.count("Checked") 
Percentage_Not_Use_Computation=100*Not_Use_Computation_Y/(Not_Use_Computation_Y+Not_Use_Computation.count("Unchecked"))
print("Of the",Not_Use_Computation_Y+Not_Use_Computation.count("Unchecked"),"people who answered this question",Percentage_Not_Use_Computation,"percent said they do not use computation. That is",Not_Use_Computation_Y,"people.")
x=[1,2]
y=[Not_Use_Computation_Y,Not_Use_Computation.count("Unchecked")]
fig = plt.figure(figsize=(4,4))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('People who do not use computation')
labels=['do not','do']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 34

# %%
Fac_Rank = []
#Collumn FP
for row in data.values[:,166]:
    Fac_Rank.append(row)
#What is your faculty rank
Ans34_Tot = Fac_Rank.count("Adjunct faculty")+Fac_Rank.count("Instructor/Lecturer")+Fac_Rank.count("Visiting Professor")+Fac_Rank.count("Research Faculty")+Fac_Rank.count("Assistant Professor")+Fac_Rank.count("Associate Professor")+Fac_Rank.count("Full Professor")+Fac_Rank.count("Other")
Fac_Rank_Dist = []                                                                                                                                                                          
Fac_Rank_Adj = Fac_Rank.count("Adjunct faculty")
Prop_Fac_Rank_Adj = Fac_Rank_Adj/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_Adj)
Fac_Rank_InsLec = Fac_Rank.count("Instructor/Lecturer")
Prop_Fac_Rank_InsLec = Fac_Rank_InsLec/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_InsLec)
#Visiting Professor in data, Visiting faculty in question
Fac_Rank_VisFac = Fac_Rank.count("Visiting Professor")
Prop_Fac_Rank_VisFac = Fac_Rank_VisFac/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_VisFac)
#Research Professor in data, Research faculty in question
Fac_Rank_ReasFac = Fac_Rank.count("Research Professor")
Prop_Fac_Rank_ReasFac = Fac_Rank_ReasFac/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_ReasFac)
Fac_Rank_AssProf = Fac_Rank.count("Assistant Professor")
Prop_Fac_Rank_AssProf = Fac_Rank_AssProf/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_AssProf)
Fac_Rank_AscProf = Fac_Rank.count("Associate Professor")
Prop_Fac_Rank_AscProf = Fac_Rank_AscProf/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_AscProf)
Fac_Rank_Prof = Fac_Rank.count("Full Professor")
Prop_Fac_Rank_Prof = Fac_Rank_Prof/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_Prof)
Fac_Rank_Oth = Fac_Rank.count("Other")
Prop_Fac_Rank_Oth = Fac_Rank_Oth/(Ans34_Tot)
Fac_Rank_Dist.append(Prop_Fac_Rank_Oth)
print(Fac_Rank_Dist)
# Out:
# [0.04184549356223176, 0.11266094420600858, 0.012875536480686695, 0.01072961373390558, 0.16738197424892703, 0.22317596566523606, 0.4259656652360515, 0.016094420600858368]

# %%
Ans34 = ['Adjunct faculty', 'Instructor/Lecturer', 'Visiting Faculty', 'Research Faculty', 'Assistant Professor', 'Associate Professor', 'Full Professor', 'Other']
Tick34 = [1,2,3,4,5,6,7,8]
Ans34_dist = Fac_Rank_Dist
plt.xticks(Tick34, Ans34, rotation=45)
plt.bar(Tick34, Ans34_dist)
plt.title('Faculty Rank')
plt.ylabel('Proportion')
plt.xlabel('Rank')

# %% [markdown]
# ## Question 35

# %%
Emp_Stat = []
#Collumn FM
for row in data.values[:,168]:
    Emp_Stat.append(row)
#As of the Spring 2016 term, were you employed (Full-time, Part-time, Course by course)
Ans35_Tot = Emp_Stat.count("Full-time")+Emp_Stat.count("Part-time")+Emp_Stat.count("Course by course")
Emp_Stat_Dist = []                                                                             
Emp_Stat_Full = Emp_Stat.count("Full-time")
Prop_Emp_Stat_Full = Emp_Stat_Full/(Ans35_Tot)
Emp_Stat_Dist.append(Prop_Emp_Stat_Full)
Emp_Stat_Part = Emp_Stat.count("Part-time")
Prop_Emp_Stat_Part = Emp_Stat_Part/(Ans35_Tot)
Emp_Stat_Dist.append(Prop_Emp_Stat_Part)
Emp_Stat_Cbc = Emp_Stat.count("Course by course")
Prop_Emp_Stat_Cbc = Emp_Stat_Cbc/(Ans35_Tot)
Emp_Stat_Dist.append(Prop_Emp_Stat_Cbc)
print(Emp_Stat_Dist)
# Out:
# [0.926829268292683, 0.04665959703075292, 0.026511134676564158]

# %%
Ans35 = ['Full-time', 'Part-time', 'Course by Course']
Tick35 = [1,2,3]
Ans35_dist = Emp_Stat_Dist
plt.xticks(Tick35, Ans35, rotation=45)
plt.bar(Tick35, Ans35_dist)
plt.title('Distribution of Employment Type')
plt.ylabel('Proportion')
plt.xlabel('Empliyment Type')

# %% [markdown]
# ## Question 36
# Are you currently:

# %%
# Column FN column 169  currently
Current_Job_Standing= []
for row in data.values[:,169]:
    Current_Job_Standing.append(row)
Current_Job_Standing_Tenured= Current_Job_Standing.count("Tenured")
Current_Job_Standing_Tenure_Tracked= Current_Job_Standing.count("Tenure-tracked")
Current_Job_Standing_Tenure_Untracked= Current_Job_Standing.count("Non-tenure tracked")
Answered_35=Current_Job_Standing_Tenured+Current_Job_Standing_Tenure_Tracked+Current_Job_Standing_Tenure_Untracked
print(Answered_35,'This many people answered the question')
x=[1,2,3]
y=[Current_Job_Standing_Tenured,Current_Job_Standing_Tenure_Tracked,Current_Job_Standing_Tenure_Untracked]
fig = plt.figure(figsize=(12,6))
plt.bar(x,y,width=.5)
plt.ylabel('Number of people')
plt.title('Current Job Standing')
labels=['Tenured','Tenure Tracked','Non Tenure Tracked']
plt.xticks(x,labels)

# %% [markdown]
# ## Question 37

# %%
Gender = []
#Collumn FO
for row in data.values[:,170]:
    Gender.append(row)
#What is your Gender
Ans37_Tot = Gender.count("Male")+Gender.count("Female")+Gender.count("Prefer not to respond")
Gender_Dist = []
Gender_Male = Gender.count("Male")
Prop_Gender_Male = Gender_Male/(Ans37_Tot)
Gender_Dist.append(Prop_Gender_Male)
Gender_Female = Gender.count("Female")
Prop_Gender_Female = Gender_Female/(Ans37_Tot)
Gender_Dist.append(Prop_Gender_Female)
Gender_Pref_NA = Gender.count("Prefer not to respond")
Prop_Gender_Pref_NA = Gender_Pref_NA/(Ans37_Tot)
Gender_Dist.append(Prop_Gender_Pref_NA)
print(Gender_Dist)
# Out:
# [0.7910447761194029, 0.17803837953091683, 0.03091684434968017]

# %%
Ans37 = ['Male', 'Female', 'Prefer not to Respond']
Tick37 = [1,2,3]
Ans37_dist = Gender_Dist
plt.xticks(Tick37, Ans37, rotation=45)
plt.bar(Tick37, Ans37_dist)
plt.title('Distribution of Gender')
plt.ylabel('Proportion')
plt.xlabel('Gender')

# %% [markdown]
# ## Question 38
# What is your race or ethnicity?

# %%
# Column FP column 171 American Indian or Native Alaskan
American_Indian = []
for row in data.values[:,171]:
    American_Indian.append(row)
American_Indian_Y = American_Indian.count("Checked")
Percentage_American_Indian=100*American_Indian_Y/(American_Indian_Y+American_Indian.count("Unchecked"))
print("Of the",American_Indian_Y+American_Indian.count("Unchecked"),"people who answered this question",Percentage_American_Indian,"percent said they are Native Alaskan. That is",American_Indian_Y,"people.")
x=[1,2]
y=[American_Indian_Y,American_Indian.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('American Indian or Native Alaskan')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FQ column 172  Black or African American
African_American = []
for row in data.values[:,172]:
    African_American.append(row)
African_American_Y = African_American.count("Checked")
Percentage_African_American=100*African_American_Y/(African_American_Y+African_American.count("Unchecked"))
print("Of the",African_American_Y+African_American.count("Unchecked"),"people who answered this question",Percentage_African_American,"percent said they are black. That is",African_American_Y,"people.")
x=[1,2]
y=[African_American_Y,African_American.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('African American or Black')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FR column 173  Native Hawaiian or other Pacific Islander
Hawaiian = []
for row in data.values[:,173]:
    Hawaiian.append(row)
Hawaiian_Y = Hawaiian.count("Checked")
Percentage_Hawaiian=100*Hawaiian_Y/(Hawaiian_Y+Hawaiian.count("Unchecked"))
print("Of the",Hawaiian_Y+Hawaiian.count("Unchecked"),"people who answered this question",Percentage_Hawaiian,"percent said they are native hawaiian. That is",Hawaiian_Y,"people.")
x=[1,2]
y=[Hawaiian_Y,Hawaiian.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Native Hawaiian or Other Pacific Islander')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FS column 174  Asian
Asian = []
for row in data.values[:,174]:
    Asian.append(row)
Asian_Y = Asian.count("Checked")
Percentage_Asian=100*Asian_Y/(Asian_Y+Asian.count("Unchecked"))
print("Of the",Asian_Y+Asian.count("Unchecked"),"people who answered this question",Percentage_Asian,"percent said they are Asian. That is",Asian_Y,"people.")
x=[1,2]
y=[Asian_Y,Asian.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Asian')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FT column 175  White
White = []
for row in data.values[:,175]:
    White.append(row)
White_Y = White.count("Checked")
Percentage_White=100*White_Y/(White_Y+White.count("Unchecked"))
print("Of the",White_Y+White.count("Unchecked"),"people who answered this question",Percentage_White,"percent said they are white. That is",White_Y,"people.")
x=[1,2]
y=[White_Y,White.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('White')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FU column 176  Hispanic or Latino/Latina
Hispanic = []
for row in data.values[:,176]:
    Hispanic.append(row)
Hispanic_Y = Hispanic.count("Checked")
Percentage_Hispanic=100*Hispanic_Y/(Hispanic_Y+Hispanic.count("Unchecked"))
print("Of the",Hispanic_Y+Hispanic.count("Unchecked"),"people who answered this question",Percentage_Hispanic,"percent said they are Hispanic. That is",Hispanic_Y,"people.")
x=[1,2]
y=[Hispanic_Y,Hispanic.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Hispanic or LAtino/Latina')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FV column 177  Other
Other_Race = []
for row in data.values[:,177]:
    Other_Race.append(row)
Other_Race_Y = Other_Race.count("Checked")
Percentage_Other_Race=100*Other_Race_Y/(Other_Race_Y+Other_Race.count("Unchecked"))
print("Of the",Other_Race_Y+Other_Race.count("Unchecked"),"people who answered this question",Percentage_Other_Race,"percent said they are another race. That is",Other_Race_Y,"people.")
x=[1,2]
y=[Other_Race_Y,Other_Race.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Other Race')
labels=['yes','no']
plt.xticks(x,labels)

# %%
# Column FW column 178  Prefer Not to Respond
Race_Prefer_No_Response = []
for row in data.values[:,178]:
    Race_Prefer_No_Response.append(row)
Race_Prefer_No_Response_Y = Race_Prefer_No_Response.count("Checked")
Percentage_Race_Prefer_No_Response=100*Race_Prefer_No_Response_Y/(Race_Prefer_No_Response_Y+Race_Prefer_No_Response.count("Unchecked"))
print("Of the",Race_Prefer_No_Response_Y+Race_Prefer_No_Response.count("Unchecked"),"people who answered this question",Percentage_Race_Prefer_No_Response,"percent said they prefer not to respond. That is",Race_Prefer_No_Response_Y,"people.")
x=[1,2]
y=[Race_Prefer_No_Response_Y,Race_Prefer_No_Response.count("Unchecked")]
fig = plt.figure(figsize=(4,6))
plt.bar(x,y,width=.25)
plt.ylabel('Number of people')
plt.title('Prefer Not to Respond')
labels=['yes','no']
plt.xticks(x,labels)

# %%
#Native alaskan
Percentage_American_Indian
#Black
Percentage_African_American
#Hawaiian
Percentage_Hawaiian
#asian
Percentage_Asian
#white
Percentage_White
#hispanic
Percentage_Hispanic
#Other
Percentage_Other_Race
#prefer not to respond
Percentage_Race_Prefer_No_Response
x=[1,2,3,4,5,6,7,8]
y=[Percentage_American_Indian,Percentage_African_American,Percentage_Hawaiian,Percentage_Asian,Percentage_White,Percentage_Hispanic,Percentage_Other_Race,Percentage_Race_Prefer_No_Response]
fig=plt.figure(figsize=(18,7))
plt.bar(x,y)
labels=['American Indian or Native Alaskan','African American or Black','Native Hawaiian or other Pacific Islander','Asian','White','Hispanic or Latino/Latina','Other','Prefer not to Respond']
plt.xticks(x,labels,rotation=20)
plt.title('Race Chart')
plt.ylabel('Percentage out of 100')
